# %% [markdown]
# ## **CNN Draft 2**
# #### **lr=1*10^(-3), epochs=30, Accuracy = 62% (approx) at (25, 30) epochs range**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find suitable learning rate and epoch value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                data.append([resized_arr, class_num])
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1423942192299756461
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11321147392
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6963156742320733429
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 30
l_rate = 0.001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 3000)              1731000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 1,915,439
# Trainable params: 1,915,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/30
# 71/71 [==============================] - 16s 91ms/step - loss: 2.7118 - accuracy: 0.0556 - val_loss: 2.7080 - val_accuracy: 0.0667
# Epoch 2/30
# 71/71 [==============================] - 6s 78ms/step - loss: 2.7092 - accuracy: 0.0573 - val_loss: 2.6977 - val_accuracy: 0.0700
# Epoch 3/30
# 71/71 [==============================] - 5s 77ms/step - loss: 2.7119 - accuracy: 0.0538 - val_loss: 2.7081 - val_accuracy: 0.0733
# Epoch 4/30
# 71/71 [==============================] - 5s 77ms/step - loss: 2.7095 - accuracy: 0.0680 - val_loss: 2.7082 - val_accuracy: 0.0667
# Epoch 5/30
# 71/71 [==============================] - 6s 78ms/step - loss: 2.7093 - accuracy: 0.0609 - val_loss: 2.7053 - val_accuracy: 0.0833
# Epoch 6/30
# 71/71 [==============================] - 6s 78ms/step - loss: 2.7089 - accuracy: 0.0600 - val_loss: 2.7020 - val_accuracy: 0.0733
# Epoch 7/30
# 71/71 [==============================] - 5s 77ms/step - loss: 2.7009 - accuracy: 0.0724 - val_loss: 2.6902 - val_accuracy: 0.1167
# Epoch 8/30
# 71/71 [==============================] - 5s 77ms/step - loss: 2.6814 - accuracy: 0.0889 - val_loss: 2.6682 - val_accuracy: 0.0933
# Epoch 9/30
# 71/71 [==============================] - 6s 78ms/step - loss: 2.5147 - accuracy: 0.1862 - val_loss: 2.1000 - val_accuracy: 0.2933
# Epoch 10/30
# 71/71 [==============================] - 6s 79ms/step - loss: 2.2675 - accuracy: 0.2676 - val_loss: 1.9249 - val_accuracy: 0.3467
# Epoch 11/30
# 71/71 [==============================] - 5s 77ms/step - loss: 2.1184 - accuracy: 0.3129 - val_loss: 1.7981 - val_accuracy: 0.4333
# Epoch 12/30
# 71/71 [==============================] - 6s 78ms/step - loss: 1.9572 - accuracy: 0.3742 - val_loss: 1.6046 - val_accuracy: 0.4967
# Epoch 13/30
# 71/71 [==============================] - 6s 78ms/step - loss: 1.7856 - accuracy: 0.4311 - val_loss: 1.6168 - val_accuracy: 0.4900
# Epoch 14/30
# 71/71 [==============================] - 5s 77ms/step - loss: 1.6259 - accuracy: 0.4876 - val_loss: 1.4936 - val_accuracy: 0.5367
# Epoch 15/30
# 71/71 [==============================] - 6s 78ms/step - loss: 1.4309 - accuracy: 0.5462 - val_loss: 1.5024 - val_accuracy: 0.5333
# Epoch 16/30
# 71/71 [==============================] - 6s 78ms/step - loss: 1.2550 - accuracy: 0.5956 - val_loss: 1.4810 - val_accuracy: 0.5600
# Epoch 17/30
# 71/71 [==============================] - 5s 77ms/step - loss: 1.0820 - accuracy: 0.6444 - val_loss: 1.5496 - val_accuracy: 0.5567
# Epoch 18/30
# 71/71 [==============================] - 6s 78ms/step - loss: 0.9095 - accuracy: 0.7076 - val_loss: 1.5785 - val_accuracy: 0.5867
# Epoch 19/30
# 71/71 [==============================] - 5s 77ms/step - loss: 0.7308 - accuracy: 0.7680 - val_loss: 1.6348 - val_accuracy: 0.5700
# Epoch 20/30
# 71/71 [==============================] - 6s 78ms/step - loss: 0.5833 - accuracy: 0.8062 - val_loss: 1.9153 - val_accuracy: 0.5700
# Epoch 21/30
# 71/71 [==============================] - 6s 78ms/step - loss: 0.4392 - accuracy: 0.8587 - val_loss: 2.1313 - val_accuracy: 0.5933
# Epoch 22/30
# 71/71 [==============================] - 6s 79ms/step - loss: 0.3558 - accuracy: 0.8844 - val_loss: 2.1416 - val_accuracy: 0.6000
# Epoch 23/30
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2987 - accuracy: 0.8996 - val_loss: 2.4915 - val_accuracy: 0.5867
# Epoch 24/30
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2601 - accuracy: 0.9204 - val_loss: 2.4594 - val_accuracy: 0.6100
# Epoch 25/30
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2201 - accuracy: 0.9324 - val_loss: 2.5033 - val_accuracy: 0.6200
# Epoch 26/30
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1922 - accuracy: 0.9413 - val_loss: 2.6558 - val_accuracy: 0.6267
# Epoch 27/30
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1592 - accuracy: 0.9498 - val_loss: 2.8521 - val_accuracy: 0.6233
# Epoch 28/30
# 71/71 [==============================] - 6s 78ms/step - loss: 0.2812 - accuracy: 0.9200 - val_loss: 2.5026 - val_accuracy: 0.6033
# Epoch 29/30
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1089 - accuracy: 0.9680 - val_loss: 2.8224 - val_accuracy: 0.6100
# Epoch 30/30
# 71/71 [==============================] - 6s 78ms/step - loss: 0.1075 - accuracy: 0.9693 - val_loss: 2.9271 - val_accuracy: 0.6200

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.86      0.60      0.71        20
#             Garuda       0.61      0.55      0.58        20
#      Goddess_Durga       0.71      0.85      0.77        20
#    Goddess_Lakshmi       0.48      0.60      0.53        20
# Goddess_Saraswathi       0.60      0.60      0.60        20
#        Lord_Ganesh       0.70      0.35      0.47        20
#       Lord_Hanuman       0.33      0.25      0.29        20
#     Lord_Hayagriva       0.48      0.50      0.49        20
#         Lord_Indra       0.77      1.00      0.87        20
#       Lord_Krishna       0.56      0.90      0.69        20
#        Lord_Muruga       0.60      0.45      0.51        20
#              Nandi       0.70      0.70      0.70        20
#            Nataraj       0.70      0.95      0.81        20
#    Shirdi_Sai_Baba       0.56      0.50      0.53        20
#           Shivling       0.67      0.50      0.57        20
#
#           accuracy                           0.62       300
#          macro avg       0.62      0.62      0.61       300
#       weighted avg       0.62      0.62      0.61       300
#
#
# Accuracy = 62.0%

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-3) and 30 iterations, the highest accuracy obtained is 62%(approx) at (25, 30).**
