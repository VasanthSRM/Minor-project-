# %% [markdown]
# ## **CNN Draft 2**
# #### **lr=1*10^(-4), epochs=70, Accuracy = 69.33% (approx) at (65, 70) epochs range**
# #### **Test run - 2**

# %% [markdown]
# #### **Aim: To find suitable learning rate and epoch value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                data.append([resized_arr, class_num])
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5451397068605997378
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11320098816
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6650605465749302740
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 70
l_rate = 0.0001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 224, 224, 32)      896
#
#  max_pooling2d_12 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 112, 112, 32)      9248
#
#  max_pooling2d_13 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 56, 56, 64)        18496
#
#  max_pooling2d_14 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_15 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 64)        36928
#
#  max_pooling2d_16 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 7, 7, 64)          36928
#
#  max_pooling2d_17 (MaxPoolin  (None, 3, 3, 64)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 576)               0
#
#  dense_4 (Dense)             (None, 3000)              1731000
#
#  dropout_2 (Dropout)         (None, 3000)              0
#
#  dense_5 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 1,915,439
# Trainable params: 1,915,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/70
# 71/71 [==============================] - 7s 88ms/step - loss: 2.7084 - accuracy: 0.0644 - val_loss: 2.7013 - val_accuracy: 0.1133
# Epoch 2/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6846 - accuracy: 0.1018 - val_loss: 2.5872 - val_accuracy: 0.1467
# Epoch 3/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.5662 - accuracy: 0.1498 - val_loss: 2.3660 - val_accuracy: 0.2700
# Epoch 4/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.4320 - accuracy: 0.2164 - val_loss: 2.0971 - val_accuracy: 0.3467
# Epoch 5/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.2817 - accuracy: 0.2787 - val_loss: 1.9403 - val_accuracy: 0.3700
# Epoch 6/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1682 - accuracy: 0.3098 - val_loss: 1.7888 - val_accuracy: 0.4367
# Epoch 7/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.0847 - accuracy: 0.3364 - val_loss: 1.7061 - val_accuracy: 0.4567
# Epoch 8/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.9828 - accuracy: 0.3809 - val_loss: 1.6297 - val_accuracy: 0.5100
# Epoch 9/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.8911 - accuracy: 0.4071 - val_loss: 1.5642 - val_accuracy: 0.5100
# Epoch 10/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.7771 - accuracy: 0.4569 - val_loss: 1.4521 - val_accuracy: 0.5467
# Epoch 11/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.6884 - accuracy: 0.4724 - val_loss: 1.3575 - val_accuracy: 0.5900
# Epoch 12/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.5990 - accuracy: 0.5040 - val_loss: 1.3567 - val_accuracy: 0.5767
# Epoch 13/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.4802 - accuracy: 0.5511 - val_loss: 1.3352 - val_accuracy: 0.6067
# Epoch 14/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3772 - accuracy: 0.5698 - val_loss: 1.2468 - val_accuracy: 0.6433
# Epoch 15/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.2608 - accuracy: 0.6067 - val_loss: 1.2368 - val_accuracy: 0.6133
# Epoch 16/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.1566 - accuracy: 0.6409 - val_loss: 1.2921 - val_accuracy: 0.6133
# Epoch 17/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.1087 - accuracy: 0.6631 - val_loss: 1.2507 - val_accuracy: 0.6300
# Epoch 18/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.9514 - accuracy: 0.7107 - val_loss: 1.3222 - val_accuracy: 0.6133
# Epoch 19/70
# 71/71 [==============================] - 6s 81ms/step - loss: 0.8817 - accuracy: 0.7311 - val_loss: 1.2130 - val_accuracy: 0.6300
# Epoch 20/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.7526 - accuracy: 0.7733 - val_loss: 1.2437 - val_accuracy: 0.6533
# Epoch 21/70
# 71/71 [==============================] - 6s 78ms/step - loss: 0.6754 - accuracy: 0.7969 - val_loss: 1.2690 - val_accuracy: 0.6367
# Epoch 22/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.5969 - accuracy: 0.8164 - val_loss: 1.2003 - val_accuracy: 0.6567
# Epoch 23/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.4927 - accuracy: 0.8458 - val_loss: 1.2682 - val_accuracy: 0.6533
# Epoch 24/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.4493 - accuracy: 0.8627 - val_loss: 1.3058 - val_accuracy: 0.6533
# Epoch 25/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.3332 - accuracy: 0.8951 - val_loss: 1.3039 - val_accuracy: 0.6800
# Epoch 26/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2936 - accuracy: 0.9124 - val_loss: 1.5183 - val_accuracy: 0.6667
# Epoch 27/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2426 - accuracy: 0.9289 - val_loss: 1.4206 - val_accuracy: 0.6633
# Epoch 28/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2043 - accuracy: 0.9378 - val_loss: 1.5117 - val_accuracy: 0.6467
# Epoch 29/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1529 - accuracy: 0.9600 - val_loss: 1.5681 - val_accuracy: 0.6633
# Epoch 30/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1632 - accuracy: 0.9524 - val_loss: 1.6542 - val_accuracy: 0.6633
# Epoch 31/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1418 - accuracy: 0.9613 - val_loss: 1.6237 - val_accuracy: 0.6800
# Epoch 32/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1410 - accuracy: 0.9658 - val_loss: 1.6329 - val_accuracy: 0.6900
# Epoch 33/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1237 - accuracy: 0.9627 - val_loss: 1.6998 - val_accuracy: 0.6633
# Epoch 34/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1029 - accuracy: 0.9733 - val_loss: 1.7376 - val_accuracy: 0.6600
# Epoch 35/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1022 - accuracy: 0.9769 - val_loss: 1.6539 - val_accuracy: 0.6667
# Epoch 36/70
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0898 - accuracy: 0.9751 - val_loss: 1.8179 - val_accuracy: 0.6700
# Epoch 37/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0833 - accuracy: 0.9787 - val_loss: 1.7411 - val_accuracy: 0.6767
# Epoch 38/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0559 - accuracy: 0.9889 - val_loss: 1.7751 - val_accuracy: 0.6567
# Epoch 39/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0780 - accuracy: 0.9778 - val_loss: 1.8194 - val_accuracy: 0.6733
# Epoch 40/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0592 - accuracy: 0.9809 - val_loss: 1.8551 - val_accuracy: 0.6600
# Epoch 41/70
# 71/71 [==============================] - 6s 78ms/step - loss: 0.0580 - accuracy: 0.9844 - val_loss: 1.9983 - val_accuracy: 0.6700
# Epoch 42/70
# 71/71 [==============================] - 6s 78ms/step - loss: 0.0433 - accuracy: 0.9898 - val_loss: 1.8570 - val_accuracy: 0.6900
# Epoch 43/70
# 71/71 [==============================] - 6s 78ms/step - loss: 0.0551 - accuracy: 0.9862 - val_loss: 1.8610 - val_accuracy: 0.6600
# Epoch 44/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0538 - accuracy: 0.9893 - val_loss: 1.8866 - val_accuracy: 0.6600
# Epoch 45/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0317 - accuracy: 0.9933 - val_loss: 1.9363 - val_accuracy: 0.6767
# Epoch 46/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0300 - accuracy: 0.9920 - val_loss: 1.9762 - val_accuracy: 0.6733
# Epoch 47/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0549 - accuracy: 0.9849 - val_loss: 1.9400 - val_accuracy: 0.6667
# Epoch 48/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0534 - accuracy: 0.9858 - val_loss: 1.9882 - val_accuracy: 0.6633
# Epoch 49/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0531 - accuracy: 0.9831 - val_loss: 1.9552 - val_accuracy: 0.6533
# Epoch 50/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0610 - accuracy: 0.9804 - val_loss: 2.1905 - val_accuracy: 0.6700
# Epoch 51/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0511 - accuracy: 0.9862 - val_loss: 2.0408 - val_accuracy: 0.6633
# Epoch 52/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0365 - accuracy: 0.9938 - val_loss: 1.9394 - val_accuracy: 0.6800
# Epoch 53/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0290 - accuracy: 0.9933 - val_loss: 2.1888 - val_accuracy: 0.6700
# Epoch 54/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0706 - accuracy: 0.9804 - val_loss: 2.0970 - val_accuracy: 0.6600
# Epoch 55/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0490 - accuracy: 0.9853 - val_loss: 2.1776 - val_accuracy: 0.6667
# Epoch 56/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0451 - accuracy: 0.9867 - val_loss: 2.2544 - val_accuracy: 0.6500
# Epoch 57/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0599 - accuracy: 0.9840 - val_loss: 2.2805 - val_accuracy: 0.6533
# Epoch 58/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0422 - accuracy: 0.9902 - val_loss: 2.0596 - val_accuracy: 0.6867
# Epoch 59/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0384 - accuracy: 0.9889 - val_loss: 2.0937 - val_accuracy: 0.6700
# Epoch 60/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0305 - accuracy: 0.9942 - val_loss: 2.1443 - val_accuracy: 0.6600
# Epoch 61/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0277 - accuracy: 0.9924 - val_loss: 2.1722 - val_accuracy: 0.6567
# Epoch 62/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0181 - accuracy: 0.9978 - val_loss: 2.1133 - val_accuracy: 0.6767
# Epoch 63/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0304 - accuracy: 0.9947 - val_loss: 2.1261 - val_accuracy: 0.6500
# Epoch 64/70
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0342 - accuracy: 0.9929 - val_loss: 2.2131 - val_accuracy: 0.6600
# Epoch 65/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0197 - accuracy: 0.9951 - val_loss: 2.2924 - val_accuracy: 0.6667
# Epoch 66/70
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0255 - accuracy: 0.9920 - val_loss: 2.3255 - val_accuracy: 0.6833
# Epoch 67/70
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0294 - accuracy: 0.9911 - val_loss: 2.2731 - val_accuracy: 0.6533
# Epoch 68/70
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0354 - accuracy: 0.9911 - val_loss: 2.2224 - val_accuracy: 0.6567
# Epoch 69/70
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 2.2724 - val_accuracy: 0.6733
# Epoch 70/70
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0311 - accuracy: 0.9907 - val_loss: 2.1259 - val_accuracy: 0.6933

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.67      0.90      0.77        20
#             Garuda       0.94      0.75      0.83        20
#      Goddess_Durga       0.79      0.75      0.77        20
#    Goddess_Lakshmi       0.36      0.45      0.40        20
# Goddess_Saraswathi       0.47      0.45      0.46        20
#        Lord_Ganesh       0.43      0.30      0.35        20
#       Lord_Hanuman       0.58      0.55      0.56        20
#     Lord_Hayagriva       0.75      0.75      0.75        20
#         Lord_Indra       0.87      1.00      0.93        20
#       Lord_Krishna       0.79      0.75      0.77        20
#        Lord_Muruga       0.71      0.60      0.65        20
#              Nandi       0.76      0.80      0.78        20
#            Nataraj       0.95      0.90      0.92        20
#    Shirdi_Sai_Baba       0.67      0.70      0.68        20
#           Shivling       0.71      0.75      0.73        20
#
#           accuracy                           0.69       300
#          macro avg       0.70      0.69      0.69       300
#       weighted avg       0.70      0.69      0.69       300
#
#
# Accuracy = 69.33333333333334%

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-4) and 70 iterations, the highest accuracy obtained is 69%(approx) at (65, 70).**
# #### **Note Accuracy is also high at 32 and 42 iterations**
