# %% [markdown]
# ## **CNN Draft 4**
# #### **lr=1*10^(-4), epochs=70, Accuracy = 66.33%**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find the accuracy by increasing the number of dense layers.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                data.append([resized_arr, class_num])
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16850663460030639763
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11320098816
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8168480348770959990
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 70
l_rate = 0.0001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 3000)              1731000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 3000)              9003000
#
#  dropout_1 (Dropout)         (None, 3000)              0
#
#  dense_2 (Dense)             (None, 3000)              9003000
#
#  dropout_2 (Dropout)         (None, 3000)              0
#
#  dense_3 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 19,921,439
# Trainable params: 19,921,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/70
# 71/71 [==============================] - 10s 101ms/step - loss: 2.7105 - accuracy: 0.0520 - val_loss: 2.7073 - val_accuracy: 0.1100
# Epoch 2/70
# 71/71 [==============================] - 6s 86ms/step - loss: 2.7080 - accuracy: 0.0627 - val_loss: 2.7054 - val_accuracy: 0.1067
# Epoch 3/70
# 71/71 [==============================] - 6s 87ms/step - loss: 2.7064 - accuracy: 0.0800 - val_loss: 2.6938 - val_accuracy: 0.0767
# Epoch 4/70
# 71/71 [==============================] - 6s 88ms/step - loss: 2.6676 - accuracy: 0.1084 - val_loss: 2.5407 - val_accuracy: 0.1733
# Epoch 5/70
# 71/71 [==============================] - 6s 87ms/step - loss: 2.5280 - accuracy: 0.1716 - val_loss: 2.3161 - val_accuracy: 0.2333
# Epoch 6/70
# 71/71 [==============================] - 6s 87ms/step - loss: 2.4158 - accuracy: 0.1991 - val_loss: 2.1158 - val_accuracy: 0.2467
# Epoch 7/70
# 71/71 [==============================] - 6s 87ms/step - loss: 2.3282 - accuracy: 0.2373 - val_loss: 2.0009 - val_accuracy: 0.3500
# Epoch 8/70
# 71/71 [==============================] - 6s 88ms/step - loss: 2.2208 - accuracy: 0.2582 - val_loss: 1.8723 - val_accuracy: 0.3967
# Epoch 9/70
# 71/71 [==============================] - 6s 87ms/step - loss: 2.1350 - accuracy: 0.2889 - val_loss: 1.8087 - val_accuracy: 0.4033
# Epoch 10/70
# 71/71 [==============================] - 6s 87ms/step - loss: 2.0509 - accuracy: 0.3347 - val_loss: 1.6706 - val_accuracy: 0.4100
# Epoch 11/70
# 71/71 [==============================] - 6s 87ms/step - loss: 1.9541 - accuracy: 0.3662 - val_loss: 1.6190 - val_accuracy: 0.4467
# Epoch 12/70
# 71/71 [==============================] - 6s 88ms/step - loss: 1.8756 - accuracy: 0.3773 - val_loss: 1.5328 - val_accuracy: 0.4800
# Epoch 13/70
# 71/71 [==============================] - 6s 87ms/step - loss: 1.7332 - accuracy: 0.4253 - val_loss: 1.4501 - val_accuracy: 0.4933
# Epoch 14/70
# 71/71 [==============================] - 6s 87ms/step - loss: 1.6595 - accuracy: 0.4622 - val_loss: 1.4103 - val_accuracy: 0.5400
# Epoch 15/70
# 71/71 [==============================] - 6s 88ms/step - loss: 1.5721 - accuracy: 0.4827 - val_loss: 1.3746 - val_accuracy: 0.5567
# Epoch 16/70
# 71/71 [==============================] - 6s 88ms/step - loss: 1.4247 - accuracy: 0.5382 - val_loss: 1.2828 - val_accuracy: 0.5900
# Epoch 17/70
# 71/71 [==============================] - 6s 88ms/step - loss: 1.3263 - accuracy: 0.5747 - val_loss: 1.3784 - val_accuracy: 0.5367
# Epoch 18/70
# 71/71 [==============================] - 6s 88ms/step - loss: 1.1958 - accuracy: 0.6156 - val_loss: 1.2383 - val_accuracy: 0.6200
# Epoch 19/70
# 71/71 [==============================] - 6s 88ms/step - loss: 1.0591 - accuracy: 0.6458 - val_loss: 1.3328 - val_accuracy: 0.5800
# Epoch 20/70
# 71/71 [==============================] - 6s 87ms/step - loss: 0.9492 - accuracy: 0.6987 - val_loss: 1.2964 - val_accuracy: 0.6100
# Epoch 21/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.8268 - accuracy: 0.7333 - val_loss: 1.2694 - val_accuracy: 0.6100
# Epoch 22/70
# 71/71 [==============================] - 6s 87ms/step - loss: 0.7442 - accuracy: 0.7502 - val_loss: 1.4164 - val_accuracy: 0.6067
# Epoch 23/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.6359 - accuracy: 0.7898 - val_loss: 1.2938 - val_accuracy: 0.6000
# Epoch 24/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.5491 - accuracy: 0.8289 - val_loss: 1.3318 - val_accuracy: 0.6200
# Epoch 25/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.4725 - accuracy: 0.8453 - val_loss: 1.3751 - val_accuracy: 0.6333
# Epoch 26/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.3796 - accuracy: 0.8778 - val_loss: 1.4765 - val_accuracy: 0.6400
# Epoch 27/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.3395 - accuracy: 0.8947 - val_loss: 1.5071 - val_accuracy: 0.6300
# Epoch 28/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.2597 - accuracy: 0.9200 - val_loss: 1.6188 - val_accuracy: 0.6367
# Epoch 29/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.2154 - accuracy: 0.9316 - val_loss: 1.7312 - val_accuracy: 0.6267
# Epoch 30/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.2196 - accuracy: 0.9271 - val_loss: 1.8256 - val_accuracy: 0.6467
# Epoch 31/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.1538 - accuracy: 0.9591 - val_loss: 1.7634 - val_accuracy: 0.6633
# Epoch 32/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.1487 - accuracy: 0.9516 - val_loss: 1.9724 - val_accuracy: 0.6367
# Epoch 33/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.1475 - accuracy: 0.9542 - val_loss: 2.0738 - val_accuracy: 0.6400
# Epoch 34/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.1590 - accuracy: 0.9484 - val_loss: 1.9965 - val_accuracy: 0.6467
# Epoch 35/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.1034 - accuracy: 0.9671 - val_loss: 2.0209 - val_accuracy: 0.6433
# Epoch 36/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0954 - accuracy: 0.9729 - val_loss: 1.9511 - val_accuracy: 0.6400
# Epoch 37/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.1388 - accuracy: 0.9569 - val_loss: 2.0308 - val_accuracy: 0.6433
# Epoch 38/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0796 - accuracy: 0.9782 - val_loss: 2.0007 - val_accuracy: 0.6533
# Epoch 39/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0736 - accuracy: 0.9773 - val_loss: 1.9629 - val_accuracy: 0.6633
# Epoch 40/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0626 - accuracy: 0.9800 - val_loss: 2.0585 - val_accuracy: 0.6567
# Epoch 41/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.1014 - accuracy: 0.9676 - val_loss: 2.0627 - val_accuracy: 0.6433
# Epoch 42/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0396 - accuracy: 0.9916 - val_loss: 2.4489 - val_accuracy: 0.6300
# Epoch 43/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0530 - accuracy: 0.9876 - val_loss: 2.2937 - val_accuracy: 0.6533
# Epoch 44/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0678 - accuracy: 0.9809 - val_loss: 2.0334 - val_accuracy: 0.6500
# Epoch 45/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0430 - accuracy: 0.9867 - val_loss: 2.2294 - val_accuracy: 0.6567
# Epoch 46/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0460 - accuracy: 0.9880 - val_loss: 2.0719 - val_accuracy: 0.6600
# Epoch 47/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0611 - accuracy: 0.9787 - val_loss: 2.2453 - val_accuracy: 0.6567
# Epoch 48/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0578 - accuracy: 0.9822 - val_loss: 2.2751 - val_accuracy: 0.6600
# Epoch 49/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0425 - accuracy: 0.9876 - val_loss: 2.1911 - val_accuracy: 0.6433
# Epoch 50/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0423 - accuracy: 0.9889 - val_loss: 2.5865 - val_accuracy: 0.6367
# Epoch 51/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0522 - accuracy: 0.9858 - val_loss: 2.4357 - val_accuracy: 0.6400
# Epoch 52/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0425 - accuracy: 0.9867 - val_loss: 2.4510 - val_accuracy: 0.6633
# Epoch 53/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0622 - accuracy: 0.9822 - val_loss: 2.3987 - val_accuracy: 0.6400
# Epoch 54/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0546 - accuracy: 0.9836 - val_loss: 2.3037 - val_accuracy: 0.6467
# Epoch 55/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0395 - accuracy: 0.9889 - val_loss: 2.4006 - val_accuracy: 0.6467
# Epoch 56/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0669 - accuracy: 0.9791 - val_loss: 2.4264 - val_accuracy: 0.6400
# Epoch 57/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0450 - accuracy: 0.9889 - val_loss: 2.5212 - val_accuracy: 0.6467
# Epoch 58/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0336 - accuracy: 0.9902 - val_loss: 2.4611 - val_accuracy: 0.6567
# Epoch 59/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0511 - accuracy: 0.9822 - val_loss: 2.5165 - val_accuracy: 0.6367
# Epoch 60/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0486 - accuracy: 0.9871 - val_loss: 2.4637 - val_accuracy: 0.6400
# Epoch 61/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0489 - accuracy: 0.9849 - val_loss: 2.2024 - val_accuracy: 0.6467
# Epoch 62/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0376 - accuracy: 0.9871 - val_loss: 2.4183 - val_accuracy: 0.6400
# Epoch 63/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0343 - accuracy: 0.9893 - val_loss: 2.5111 - val_accuracy: 0.6500
# Epoch 64/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0186 - accuracy: 0.9960 - val_loss: 2.5488 - val_accuracy: 0.6533
# Epoch 65/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0264 - accuracy: 0.9929 - val_loss: 2.5915 - val_accuracy: 0.6500
# Epoch 66/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0422 - accuracy: 0.9853 - val_loss: 2.5219 - val_accuracy: 0.6233
# Epoch 67/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0296 - accuracy: 0.9920 - val_loss: 2.5751 - val_accuracy: 0.6333
# Epoch 68/70
# 71/71 [==============================] - 6s 88ms/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 2.5161 - val_accuracy: 0.6433
# Epoch 69/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.1085 - accuracy: 0.9667 - val_loss: 2.3029 - val_accuracy: 0.6400
# Epoch 70/70
# 71/71 [==============================] - 6s 89ms/step - loss: 0.0396 - accuracy: 0.9876 - val_loss: 2.4962 - val_accuracy: 0.6633

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.80      0.80      0.80        20
#             Garuda       0.77      0.85      0.81        20
#      Goddess_Durga       0.63      0.85      0.72        20
#    Goddess_Lakshmi       0.47      0.35      0.40        20
# Goddess_Saraswathi       0.62      0.40      0.48        20
#        Lord_Ganesh       0.60      0.45      0.51        20
#       Lord_Hanuman       0.53      0.40      0.46        20
#     Lord_Hayagriva       0.45      0.65      0.53        20
#         Lord_Indra       0.71      1.00      0.83        20
#       Lord_Krishna       0.71      0.75      0.73        20
#        Lord_Muruga       0.62      0.25      0.36        20
#              Nandi       0.81      0.85      0.83        20
#            Nataraj       0.83      0.95      0.88        20
#    Shirdi_Sai_Baba       0.55      0.60      0.57        20
#           Shivling       0.76      0.80      0.78        20
#
#           accuracy                           0.66       300
#          macro avg       0.66      0.66      0.65       300
#       weighted avg       0.66      0.66      0.65       300
#
#
# Accuracy = 66.33333333333333%

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-4) and 70 iterations, the accuracy obtained was 66.33%.**
