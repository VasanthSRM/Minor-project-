# %% [markdown]
# ## **CNN Draft 3**
# #### **lr=1*10^(-4), epochs=70, Accuracy = 65.33%**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find the accuracy by increasing the number of dense layers.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                data.append([resized_arr, class_num])
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15006412978779634764
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11321147392
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10871527418899540001
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 70
l_rate = 0.0001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 3000)              1731000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 3000)              9003000
#
#  dropout_1 (Dropout)         (None, 3000)              0
#
#  dense_2 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 10,918,439
# Trainable params: 10,918,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/70
# 71/71 [==============================] - 10s 95ms/step - loss: 2.7097 - accuracy: 0.0689 - val_loss: 2.7054 - val_accuracy: 0.0667
# Epoch 2/70
# 71/71 [==============================] - 6s 83ms/step - loss: 2.7075 - accuracy: 0.0720 - val_loss: 2.6988 - val_accuracy: 0.1133
# Epoch 3/70
# 71/71 [==============================] - 6s 82ms/step - loss: 2.6822 - accuracy: 0.0964 - val_loss: 2.5558 - val_accuracy: 0.1667
# Epoch 4/70
# 71/71 [==============================] - 6s 83ms/step - loss: 2.5225 - accuracy: 0.1800 - val_loss: 2.2152 - val_accuracy: 0.2967
# Epoch 5/70
# 71/71 [==============================] - 6s 82ms/step - loss: 2.3428 - accuracy: 0.2342 - val_loss: 2.0072 - val_accuracy: 0.3333
# Epoch 6/70
# 71/71 [==============================] - 6s 83ms/step - loss: 2.2104 - accuracy: 0.2956 - val_loss: 1.8244 - val_accuracy: 0.4000
# Epoch 7/70
# 71/71 [==============================] - 6s 83ms/step - loss: 2.1424 - accuracy: 0.3138 - val_loss: 1.7589 - val_accuracy: 0.4700
# Epoch 8/70
# 71/71 [==============================] - 6s 82ms/step - loss: 2.0037 - accuracy: 0.3773 - val_loss: 1.6632 - val_accuracy: 0.5033
# Epoch 9/70
# 71/71 [==============================] - 6s 83ms/step - loss: 1.8902 - accuracy: 0.3982 - val_loss: 1.5660 - val_accuracy: 0.5233
# Epoch 10/70
# 71/71 [==============================] - 6s 83ms/step - loss: 1.7728 - accuracy: 0.4467 - val_loss: 1.4875 - val_accuracy: 0.5133
# Epoch 11/70
# 71/71 [==============================] - 6s 84ms/step - loss: 1.6648 - accuracy: 0.4751 - val_loss: 1.5240 - val_accuracy: 0.5233
# Epoch 12/70
# 71/71 [==============================] - 6s 83ms/step - loss: 1.5850 - accuracy: 0.5018 - val_loss: 1.3906 - val_accuracy: 0.5200
# Epoch 13/70
# 71/71 [==============================] - 6s 83ms/step - loss: 1.4341 - accuracy: 0.5569 - val_loss: 1.4275 - val_accuracy: 0.5333
# Epoch 14/70
# 71/71 [==============================] - 6s 83ms/step - loss: 1.3153 - accuracy: 0.5818 - val_loss: 1.3938 - val_accuracy: 0.5633
# Epoch 15/70
# 71/71 [==============================] - 6s 84ms/step - loss: 1.2022 - accuracy: 0.6262 - val_loss: 1.3674 - val_accuracy: 0.5633
# Epoch 16/70
# 71/71 [==============================] - 6s 84ms/step - loss: 1.0752 - accuracy: 0.6640 - val_loss: 1.3541 - val_accuracy: 0.5833
# Epoch 17/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.9740 - accuracy: 0.6916 - val_loss: 1.4011 - val_accuracy: 0.5700
# Epoch 18/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.8347 - accuracy: 0.7342 - val_loss: 1.3994 - val_accuracy: 0.5833
# Epoch 19/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.7154 - accuracy: 0.7840 - val_loss: 1.3770 - val_accuracy: 0.6133
# Epoch 20/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.6233 - accuracy: 0.8129 - val_loss: 1.4126 - val_accuracy: 0.6133
# Epoch 21/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.5312 - accuracy: 0.8311 - val_loss: 1.5458 - val_accuracy: 0.6233
# Epoch 22/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.4563 - accuracy: 0.8596 - val_loss: 1.5589 - val_accuracy: 0.6067
# Epoch 23/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.3781 - accuracy: 0.8840 - val_loss: 1.5388 - val_accuracy: 0.6200
# Epoch 24/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.3290 - accuracy: 0.8964 - val_loss: 1.6892 - val_accuracy: 0.6333
# Epoch 25/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.2655 - accuracy: 0.9204 - val_loss: 1.7303 - val_accuracy: 0.6267
# Epoch 26/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.2230 - accuracy: 0.9280 - val_loss: 1.7241 - val_accuracy: 0.6267
# Epoch 27/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1620 - accuracy: 0.9529 - val_loss: 1.8741 - val_accuracy: 0.6533
# Epoch 28/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.1658 - accuracy: 0.9484 - val_loss: 1.8074 - val_accuracy: 0.6500
# Epoch 29/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1868 - accuracy: 0.9436 - val_loss: 2.0199 - val_accuracy: 0.6467
# Epoch 30/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.1780 - accuracy: 0.9476 - val_loss: 1.8246 - val_accuracy: 0.6400
# Epoch 31/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1332 - accuracy: 0.9618 - val_loss: 1.9641 - val_accuracy: 0.6367
# Epoch 32/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1074 - accuracy: 0.9711 - val_loss: 2.0748 - val_accuracy: 0.6600
# Epoch 33/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1010 - accuracy: 0.9724 - val_loss: 2.1073 - val_accuracy: 0.6267
# Epoch 34/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0845 - accuracy: 0.9782 - val_loss: 2.0554 - val_accuracy: 0.6533
# Epoch 35/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0736 - accuracy: 0.9787 - val_loss: 2.2174 - val_accuracy: 0.6533
# Epoch 36/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0624 - accuracy: 0.9840 - val_loss: 2.0903 - val_accuracy: 0.6700
# Epoch 37/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0775 - accuracy: 0.9809 - val_loss: 2.4963 - val_accuracy: 0.6267
# Epoch 38/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0839 - accuracy: 0.9716 - val_loss: 2.2320 - val_accuracy: 0.6433
# Epoch 39/70
# 71/71 [==============================] - 6s 85ms/step - loss: 0.0805 - accuracy: 0.9738 - val_loss: 2.2950 - val_accuracy: 0.6533
# Epoch 40/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0779 - accuracy: 0.9813 - val_loss: 2.1244 - val_accuracy: 0.6567
# Epoch 41/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0719 - accuracy: 0.9800 - val_loss: 2.0382 - val_accuracy: 0.6600
# Epoch 42/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.1005 - accuracy: 0.9716 - val_loss: 2.1521 - val_accuracy: 0.6500
# Epoch 43/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0569 - accuracy: 0.9858 - val_loss: 2.3479 - val_accuracy: 0.6500
# Epoch 44/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0476 - accuracy: 0.9858 - val_loss: 2.3054 - val_accuracy: 0.6733
# Epoch 45/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0591 - accuracy: 0.9787 - val_loss: 2.4937 - val_accuracy: 0.6433
# Epoch 46/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0605 - accuracy: 0.9800 - val_loss: 2.4770 - val_accuracy: 0.6467
# Epoch 47/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0342 - accuracy: 0.9907 - val_loss: 2.5745 - val_accuracy: 0.6433
# Epoch 48/70
# 71/71 [==============================] - 6s 85ms/step - loss: 0.0602 - accuracy: 0.9800 - val_loss: 2.5305 - val_accuracy: 0.6433
# Epoch 49/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0498 - accuracy: 0.9867 - val_loss: 2.5102 - val_accuracy: 0.6333
# Epoch 50/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0539 - accuracy: 0.9849 - val_loss: 2.4746 - val_accuracy: 0.6300
# Epoch 51/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0480 - accuracy: 0.9827 - val_loss: 2.5622 - val_accuracy: 0.6400
# Epoch 52/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0198 - accuracy: 0.9964 - val_loss: 2.5860 - val_accuracy: 0.6500
# Epoch 53/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0407 - accuracy: 0.9880 - val_loss: 2.5715 - val_accuracy: 0.6533
# Epoch 54/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0660 - accuracy: 0.9796 - val_loss: 2.3522 - val_accuracy: 0.6500
# Epoch 55/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0495 - accuracy: 0.9858 - val_loss: 2.4679 - val_accuracy: 0.6533
# Epoch 56/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0373 - accuracy: 0.9898 - val_loss: 2.4349 - val_accuracy: 0.6433
# Epoch 57/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0236 - accuracy: 0.9947 - val_loss: 2.3869 - val_accuracy: 0.6533
# Epoch 58/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0383 - accuracy: 0.9884 - val_loss: 2.4543 - val_accuracy: 0.6333
# Epoch 59/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0523 - accuracy: 0.9844 - val_loss: 2.3465 - val_accuracy: 0.6533
# Epoch 60/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0261 - accuracy: 0.9933 - val_loss: 2.4830 - val_accuracy: 0.6600
# Epoch 61/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 2.7532 - val_accuracy: 0.6467
# Epoch 62/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0297 - accuracy: 0.9916 - val_loss: 2.7840 - val_accuracy: 0.6533
# Epoch 63/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0709 - accuracy: 0.9804 - val_loss: 2.6266 - val_accuracy: 0.6567
# Epoch 64/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0477 - accuracy: 0.9827 - val_loss: 2.4304 - val_accuracy: 0.6467
# Epoch 65/70
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0315 - accuracy: 0.9916 - val_loss: 2.4429 - val_accuracy: 0.6500
# Epoch 66/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0179 - accuracy: 0.9947 - val_loss: 2.4961 - val_accuracy: 0.6367
# Epoch 67/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0456 - accuracy: 0.9862 - val_loss: 2.6315 - val_accuracy: 0.6600
# Epoch 68/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0397 - accuracy: 0.9898 - val_loss: 2.4521 - val_accuracy: 0.6600
# Epoch 69/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0506 - accuracy: 0.9840 - val_loss: 2.5334 - val_accuracy: 0.6600
# Epoch 70/70
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0922 - accuracy: 0.9751 - val_loss: 2.5897 - val_accuracy: 0.6533

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.85      0.55      0.67        20
#             Garuda       0.73      0.80      0.76        20
#      Goddess_Durga       0.73      0.80      0.76        20
#    Goddess_Lakshmi       0.48      0.50      0.49        20
# Goddess_Saraswathi       0.86      0.30      0.44        20
#        Lord_Ganesh       0.45      0.50      0.48        20
#       Lord_Hanuman       0.47      0.40      0.43        20
#     Lord_Hayagriva       0.50      0.60      0.55        20
#         Lord_Indra       0.61      1.00      0.75        20
#       Lord_Krishna       0.88      0.70      0.78        20
#        Lord_Muruga       0.64      0.45      0.53        20
#              Nandi       0.65      0.85      0.74        20
#            Nataraj       0.86      0.95      0.90        20
#    Shirdi_Sai_Baba       0.68      0.65      0.67        20
#           Shivling       0.68      0.75      0.71        20
#
#           accuracy                           0.65       300
#          macro avg       0.67      0.65      0.64       300
#       weighted avg       0.67      0.65      0.64       300
#
#
# Accuracy = 65.33333333333333%

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-4) and 70 iterations, the accuracy obtained was 65.33%.**
