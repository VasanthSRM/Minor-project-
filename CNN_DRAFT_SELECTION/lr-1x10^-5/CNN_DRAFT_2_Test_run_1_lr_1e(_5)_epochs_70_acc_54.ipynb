# %% [markdown]
# ## **CNN Draft 2**
# #### **lr=1*10^(-5), epochs=70, Accuracy = 54% (approx) at (60, 70) epochs range**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find suitable learning rate and epoch value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                data.append([resized_arr, class_num])
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4417250135319197435
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11321147392
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15092520131730740603
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 70
l_rate = 0.00001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 3000)              1731000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 1,915,439
# Trainable params: 1,915,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/70
# 71/71 [==============================] - 10s 93ms/step - loss: 2.7088 - accuracy: 0.0702 - val_loss: 2.7068 - val_accuracy: 0.1033
# Epoch 2/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.7070 - accuracy: 0.0831 - val_loss: 2.7054 - val_accuracy: 0.0667
# Epoch 3/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.7063 - accuracy: 0.0720 - val_loss: 2.7040 - val_accuracy: 0.0667
# Epoch 4/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.7052 - accuracy: 0.0733 - val_loss: 2.7026 - val_accuracy: 0.0667
# Epoch 5/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.7040 - accuracy: 0.0791 - val_loss: 2.7009 - val_accuracy: 0.0667
# Epoch 6/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.7029 - accuracy: 0.0844 - val_loss: 2.6986 - val_accuracy: 0.0667
# Epoch 7/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.7005 - accuracy: 0.0929 - val_loss: 2.6956 - val_accuracy: 0.0667
# Epoch 8/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6971 - accuracy: 0.0964 - val_loss: 2.6913 - val_accuracy: 0.0767
# Epoch 9/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6938 - accuracy: 0.1004 - val_loss: 2.6853 - val_accuracy: 0.1067
# Epoch 10/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6902 - accuracy: 0.1120 - val_loss: 2.6761 - val_accuracy: 0.1700
# Epoch 11/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6796 - accuracy: 0.1324 - val_loss: 2.6601 - val_accuracy: 0.1700
# Epoch 12/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6675 - accuracy: 0.1298 - val_loss: 2.6345 - val_accuracy: 0.1900
# Epoch 13/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6459 - accuracy: 0.1378 - val_loss: 2.5970 - val_accuracy: 0.2300
# Epoch 14/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6170 - accuracy: 0.1489 - val_loss: 2.5487 - val_accuracy: 0.2600
# Epoch 15/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.5870 - accuracy: 0.1680 - val_loss: 2.5044 - val_accuracy: 0.2367
# Epoch 16/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.5606 - accuracy: 0.1849 - val_loss: 2.4535 - val_accuracy: 0.2467
# Epoch 17/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.5272 - accuracy: 0.1902 - val_loss: 2.4085 - val_accuracy: 0.2900
# Epoch 18/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.5046 - accuracy: 0.1929 - val_loss: 2.3625 - val_accuracy: 0.3033
# Epoch 19/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.4708 - accuracy: 0.2093 - val_loss: 2.3181 - val_accuracy: 0.3000
# Epoch 20/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.4496 - accuracy: 0.2173 - val_loss: 2.2743 - val_accuracy: 0.3233
# Epoch 21/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.4302 - accuracy: 0.2338 - val_loss: 2.2455 - val_accuracy: 0.3200
# Epoch 22/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.4059 - accuracy: 0.2329 - val_loss: 2.2052 - val_accuracy: 0.3233
# Epoch 23/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.3934 - accuracy: 0.2204 - val_loss: 2.1812 - val_accuracy: 0.3500
# Epoch 24/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.3785 - accuracy: 0.2476 - val_loss: 2.1558 - val_accuracy: 0.3300
# Epoch 25/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.3585 - accuracy: 0.2449 - val_loss: 2.1255 - val_accuracy: 0.3533
# Epoch 26/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.3347 - accuracy: 0.2569 - val_loss: 2.1100 - val_accuracy: 0.3600
# Epoch 27/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.3184 - accuracy: 0.2631 - val_loss: 2.0865 - val_accuracy: 0.3600
# Epoch 28/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.3023 - accuracy: 0.2667 - val_loss: 2.0598 - val_accuracy: 0.3600
# Epoch 29/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.2986 - accuracy: 0.2596 - val_loss: 2.0376 - val_accuracy: 0.4000
# Epoch 30/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.2887 - accuracy: 0.2693 - val_loss: 2.0363 - val_accuracy: 0.3667
# Epoch 31/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.2723 - accuracy: 0.2720 - val_loss: 2.0024 - val_accuracy: 0.3900
# Epoch 32/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.2511 - accuracy: 0.2831 - val_loss: 1.9861 - val_accuracy: 0.3900
# Epoch 33/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.2440 - accuracy: 0.2836 - val_loss: 1.9715 - val_accuracy: 0.3733
# Epoch 34/70
# 71/71 [==============================] - 6s 81ms/step - loss: 2.2226 - accuracy: 0.3000 - val_loss: 1.9410 - val_accuracy: 0.4100
# Epoch 35/70
# 71/71 [==============================] - 6s 81ms/step - loss: 2.2151 - accuracy: 0.3089 - val_loss: 1.9360 - val_accuracy: 0.4400
# Epoch 36/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1994 - accuracy: 0.3044 - val_loss: 1.9166 - val_accuracy: 0.4433
# Epoch 37/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.2006 - accuracy: 0.3053 - val_loss: 1.9057 - val_accuracy: 0.4133
# Epoch 38/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1804 - accuracy: 0.3036 - val_loss: 1.8843 - val_accuracy: 0.4600
# Epoch 39/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1688 - accuracy: 0.3151 - val_loss: 1.8700 - val_accuracy: 0.4500
# Epoch 40/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1575 - accuracy: 0.3289 - val_loss: 1.8568 - val_accuracy: 0.4467
# Epoch 41/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1357 - accuracy: 0.3258 - val_loss: 1.8473 - val_accuracy: 0.4633
# Epoch 42/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1177 - accuracy: 0.3316 - val_loss: 1.8362 - val_accuracy: 0.4633
# Epoch 43/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1323 - accuracy: 0.3204 - val_loss: 1.8173 - val_accuracy: 0.4733
# Epoch 44/70
# 71/71 [==============================] - 6s 81ms/step - loss: 2.1168 - accuracy: 0.3387 - val_loss: 1.8099 - val_accuracy: 0.4667
# Epoch 45/70
# 71/71 [==============================] - 6s 81ms/step - loss: 2.0929 - accuracy: 0.3462 - val_loss: 1.7914 - val_accuracy: 0.4500
# Epoch 46/70
# 71/71 [==============================] - 6s 81ms/step - loss: 2.0848 - accuracy: 0.3436 - val_loss: 1.7761 - val_accuracy: 0.4800
# Epoch 47/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0773 - accuracy: 0.3453 - val_loss: 1.7699 - val_accuracy: 0.4833
# Epoch 48/70
# 71/71 [==============================] - 6s 81ms/step - loss: 2.0754 - accuracy: 0.3440 - val_loss: 1.7484 - val_accuracy: 0.4667
# Epoch 49/70
# 71/71 [==============================] - 6s 81ms/step - loss: 2.0583 - accuracy: 0.3382 - val_loss: 1.7511 - val_accuracy: 0.4500
# Epoch 50/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0564 - accuracy: 0.3551 - val_loss: 1.7351 - val_accuracy: 0.5133
# Epoch 51/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0431 - accuracy: 0.3667 - val_loss: 1.7347 - val_accuracy: 0.4800
# Epoch 52/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0333 - accuracy: 0.3649 - val_loss: 1.7089 - val_accuracy: 0.4767
# Epoch 53/70
# 71/71 [==============================] - 6s 81ms/step - loss: 2.0012 - accuracy: 0.3782 - val_loss: 1.6996 - val_accuracy: 0.4833
# Epoch 54/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0122 - accuracy: 0.3724 - val_loss: 1.6959 - val_accuracy: 0.4833
# Epoch 55/70
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0008 - accuracy: 0.3716 - val_loss: 1.6837 - val_accuracy: 0.4933
# Epoch 56/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9921 - accuracy: 0.3791 - val_loss: 1.6772 - val_accuracy: 0.5233
# Epoch 57/70
# 71/71 [==============================] - 6s 81ms/step - loss: 1.9795 - accuracy: 0.3796 - val_loss: 1.6603 - val_accuracy: 0.4933
# Epoch 58/70
# 71/71 [==============================] - 6s 81ms/step - loss: 1.9575 - accuracy: 0.3867 - val_loss: 1.6534 - val_accuracy: 0.5167
# Epoch 59/70
# 71/71 [==============================] - 6s 81ms/step - loss: 1.9612 - accuracy: 0.3822 - val_loss: 1.6546 - val_accuracy: 0.5067
# Epoch 60/70
# 71/71 [==============================] - 6s 81ms/step - loss: 1.9459 - accuracy: 0.3942 - val_loss: 1.6364 - val_accuracy: 0.5033
# Epoch 61/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9368 - accuracy: 0.3978 - val_loss: 1.6323 - val_accuracy: 0.5233
# Epoch 62/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9262 - accuracy: 0.4062 - val_loss: 1.6241 - val_accuracy: 0.4933
# Epoch 63/70
# 71/71 [==============================] - 6s 82ms/step - loss: 1.9218 - accuracy: 0.4191 - val_loss: 1.6150 - val_accuracy: 0.5033
# Epoch 64/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9113 - accuracy: 0.4196 - val_loss: 1.6248 - val_accuracy: 0.5333
# Epoch 65/70
# 71/71 [==============================] - 6s 81ms/step - loss: 1.9007 - accuracy: 0.4107 - val_loss: 1.6027 - val_accuracy: 0.5033
# Epoch 66/70
# 71/71 [==============================] - 6s 81ms/step - loss: 1.8953 - accuracy: 0.4164 - val_loss: 1.5982 - val_accuracy: 0.5233
# Epoch 67/70
# 71/71 [==============================] - 6s 81ms/step - loss: 1.8766 - accuracy: 0.4200 - val_loss: 1.5941 - val_accuracy: 0.5133
# Epoch 68/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.8677 - accuracy: 0.4253 - val_loss: 1.5786 - val_accuracy: 0.5033
# Epoch 69/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.8547 - accuracy: 0.4253 - val_loss: 1.5696 - val_accuracy: 0.5133
# Epoch 70/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.8655 - accuracy: 0.4262 - val_loss: 1.5690 - val_accuracy: 0.5367

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.68      0.65      0.67        20
#             Garuda       0.20      0.10      0.13        20
#      Goddess_Durga       0.58      0.90      0.71        20
#    Goddess_Lakshmi       0.35      0.45      0.39        20
# Goddess_Saraswathi       0.54      0.35      0.42        20
#        Lord_Ganesh       0.50      0.25      0.33        20
#       Lord_Hanuman       0.17      0.15      0.16        20
#     Lord_Hayagriva       0.53      0.45      0.49        20
#         Lord_Indra       0.61      0.70      0.65        20
#       Lord_Krishna       0.68      0.75      0.71        20
#        Lord_Muruga       0.26      0.35      0.30        20
#              Nandi       0.80      0.80      0.80        20
#            Nataraj       0.83      1.00      0.91        20
#    Shirdi_Sai_Baba       0.41      0.45      0.43        20
#           Shivling       0.78      0.70      0.74        20
#
#           accuracy                           0.54       300
#          macro avg       0.53      0.54      0.52       300
#       weighted avg       0.53      0.54      0.52       300
#
#
# Accuracy = 53.666666666666664%

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-5) and 70 iterations, the highest accuracy obtained is 54%(approx) at (60, 70).**
