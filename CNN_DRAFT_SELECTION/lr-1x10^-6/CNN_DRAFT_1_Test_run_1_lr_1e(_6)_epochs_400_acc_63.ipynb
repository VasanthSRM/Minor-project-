# %% [markdown]
# ## **CNN Draft 1**
# #### **lr=1*10^(-6), epochs=400, Accuracy = 63% (approx) at (300, 350) epochs range**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find suitable learning rate and epoch value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                data.append([resized_arr, class_num])
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))
      
    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15913125852199602404
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11321147392
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 12927721502351328627
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 400
l_rate = 0.000001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 3000)              150531000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 150,604,655
# Trainable params: 150,604,655
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/400
# 71/71 [==============================] - 13s 148ms/step - loss: 2.7126 - accuracy: 0.0747 - val_loss: 2.6940 - val_accuracy: 0.0933
# Epoch 2/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.6964 - accuracy: 0.0867 - val_loss: 2.6808 - val_accuracy: 0.1300
# Epoch 3/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.6853 - accuracy: 0.1089 - val_loss: 2.6687 - val_accuracy: 0.1500
# Epoch 4/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.6742 - accuracy: 0.1298 - val_loss: 2.6569 - val_accuracy: 0.2167
# Epoch 5/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.6660 - accuracy: 0.1391 - val_loss: 2.6447 - val_accuracy: 0.2300
# Epoch 6/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.6542 - accuracy: 0.1578 - val_loss: 2.6332 - val_accuracy: 0.2300
# Epoch 7/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.6433 - accuracy: 0.1591 - val_loss: 2.6197 - val_accuracy: 0.2767
# Epoch 8/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.6270 - accuracy: 0.1782 - val_loss: 2.6077 - val_accuracy: 0.2467
# Epoch 9/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.6159 - accuracy: 0.2018 - val_loss: 2.5935 - val_accuracy: 0.2733
# Epoch 10/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.6042 - accuracy: 0.2053 - val_loss: 2.5799 - val_accuracy: 0.3033
# Epoch 11/400
# 71/71 [==============================] - 10s 141ms/step - loss: 2.5904 - accuracy: 0.2147 - val_loss: 2.5641 - val_accuracy: 0.3133
# Epoch 12/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.5767 - accuracy: 0.2253 - val_loss: 2.5494 - val_accuracy: 0.3067
# Epoch 13/400
# 71/71 [==============================] - 10s 142ms/step - loss: 2.5668 - accuracy: 0.2289 - val_loss: 2.5335 - val_accuracy: 0.3433
# Epoch 14/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.5512 - accuracy: 0.2418 - val_loss: 2.5181 - val_accuracy: 0.3133
# Epoch 15/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.5385 - accuracy: 0.2409 - val_loss: 2.5014 - val_accuracy: 0.3400
# Epoch 16/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.5301 - accuracy: 0.2529 - val_loss: 2.4861 - val_accuracy: 0.3233
# Epoch 17/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.5134 - accuracy: 0.2613 - val_loss: 2.4679 - val_accuracy: 0.3267
# Epoch 18/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.4976 - accuracy: 0.2596 - val_loss: 2.4500 - val_accuracy: 0.3667
# Epoch 19/400
# 71/71 [==============================] - 10s 142ms/step - loss: 2.4799 - accuracy: 0.2742 - val_loss: 2.4343 - val_accuracy: 0.3600
# Epoch 20/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.4604 - accuracy: 0.2818 - val_loss: 2.4148 - val_accuracy: 0.3667
# Epoch 21/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.4502 - accuracy: 0.2853 - val_loss: 2.3974 - val_accuracy: 0.3567
# Epoch 22/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.4346 - accuracy: 0.2982 - val_loss: 2.3804 - val_accuracy: 0.3567
# Epoch 23/400
# 71/71 [==============================] - 10s 139ms/step - loss: 2.4138 - accuracy: 0.3018 - val_loss: 2.3630 - val_accuracy: 0.3600
# Epoch 24/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.3961 - accuracy: 0.3027 - val_loss: 2.3442 - val_accuracy: 0.3767
# Epoch 25/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.3852 - accuracy: 0.3138 - val_loss: 2.3280 - val_accuracy: 0.3700
# Epoch 26/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.3625 - accuracy: 0.3293 - val_loss: 2.3117 - val_accuracy: 0.3700
# Epoch 27/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.3539 - accuracy: 0.3249 - val_loss: 2.2925 - val_accuracy: 0.3767
# Epoch 28/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.3318 - accuracy: 0.3364 - val_loss: 2.2753 - val_accuracy: 0.3867
# Epoch 29/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.3195 - accuracy: 0.3342 - val_loss: 2.2586 - val_accuracy: 0.4000
# Epoch 30/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.3066 - accuracy: 0.3480 - val_loss: 2.2420 - val_accuracy: 0.3733
# Epoch 31/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.2911 - accuracy: 0.3440 - val_loss: 2.2282 - val_accuracy: 0.4100
# Epoch 32/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.2768 - accuracy: 0.3493 - val_loss: 2.2104 - val_accuracy: 0.4267
# Epoch 33/400
# 71/71 [==============================] - 10s 143ms/step - loss: 2.2579 - accuracy: 0.3529 - val_loss: 2.1960 - val_accuracy: 0.4033
# Epoch 34/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.2467 - accuracy: 0.3573 - val_loss: 2.1788 - val_accuracy: 0.4067
# Epoch 35/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.2374 - accuracy: 0.3609 - val_loss: 2.1622 - val_accuracy: 0.3933
# Epoch 36/400
# 71/71 [==============================] - 10s 142ms/step - loss: 2.2167 - accuracy: 0.3831 - val_loss: 2.1502 - val_accuracy: 0.4333
# Epoch 37/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.1980 - accuracy: 0.3831 - val_loss: 2.1379 - val_accuracy: 0.4267
# Epoch 38/400
# 71/71 [==============================] - 10s 139ms/step - loss: 2.1814 - accuracy: 0.3902 - val_loss: 2.1212 - val_accuracy: 0.4233
# Epoch 39/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.1755 - accuracy: 0.3920 - val_loss: 2.1077 - val_accuracy: 0.4367
# Epoch 40/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.1605 - accuracy: 0.3893 - val_loss: 2.0960 - val_accuracy: 0.4233
# Epoch 41/400
# 71/71 [==============================] - 10s 142ms/step - loss: 2.1389 - accuracy: 0.4040 - val_loss: 2.0819 - val_accuracy: 0.4267
# Epoch 42/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.1244 - accuracy: 0.4191 - val_loss: 2.0677 - val_accuracy: 0.4333
# Epoch 43/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.1176 - accuracy: 0.4084 - val_loss: 2.0569 - val_accuracy: 0.4433
# Epoch 44/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.0976 - accuracy: 0.4236 - val_loss: 2.0467 - val_accuracy: 0.4267
# Epoch 45/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.0890 - accuracy: 0.4178 - val_loss: 2.0318 - val_accuracy: 0.4367
# Epoch 46/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.0797 - accuracy: 0.4182 - val_loss: 2.0200 - val_accuracy: 0.4400
# Epoch 47/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.0735 - accuracy: 0.4249 - val_loss: 2.0092 - val_accuracy: 0.4367
# Epoch 48/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.0527 - accuracy: 0.4196 - val_loss: 1.9964 - val_accuracy: 0.4533
# Epoch 49/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.0482 - accuracy: 0.4404 - val_loss: 1.9877 - val_accuracy: 0.4500
# Epoch 50/400
# 71/71 [==============================] - 10s 138ms/step - loss: 2.0246 - accuracy: 0.4511 - val_loss: 1.9757 - val_accuracy: 0.4667
# Epoch 51/400
# 71/71 [==============================] - 10s 137ms/step - loss: 2.0082 - accuracy: 0.4382 - val_loss: 1.9638 - val_accuracy: 0.4567
# Epoch 52/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.9983 - accuracy: 0.4422 - val_loss: 1.9568 - val_accuracy: 0.4467
# Epoch 53/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.9839 - accuracy: 0.4600 - val_loss: 1.9448 - val_accuracy: 0.4533
# Epoch 54/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.9795 - accuracy: 0.4551 - val_loss: 1.9372 - val_accuracy: 0.4600
# Epoch 55/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.9732 - accuracy: 0.4618 - val_loss: 1.9268 - val_accuracy: 0.4467
# Epoch 56/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.9670 - accuracy: 0.4609 - val_loss: 1.9238 - val_accuracy: 0.4633
# Epoch 57/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.9614 - accuracy: 0.4498 - val_loss: 1.9094 - val_accuracy: 0.4533
# Epoch 58/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.9408 - accuracy: 0.4756 - val_loss: 1.9009 - val_accuracy: 0.4533
# Epoch 59/400
# 71/71 [==============================] - 10s 143ms/step - loss: 1.9336 - accuracy: 0.4689 - val_loss: 1.8971 - val_accuracy: 0.4600
# Epoch 60/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.9202 - accuracy: 0.4689 - val_loss: 1.8866 - val_accuracy: 0.4733
# Epoch 61/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.9022 - accuracy: 0.4831 - val_loss: 1.8748 - val_accuracy: 0.4633
# Epoch 62/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.8905 - accuracy: 0.4840 - val_loss: 1.8648 - val_accuracy: 0.4767
# Epoch 63/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.8906 - accuracy: 0.4716 - val_loss: 1.8568 - val_accuracy: 0.4767
# Epoch 64/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.8773 - accuracy: 0.4871 - val_loss: 1.8480 - val_accuracy: 0.4800
# Epoch 65/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.8633 - accuracy: 0.4942 - val_loss: 1.8411 - val_accuracy: 0.4767
# Epoch 66/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.8537 - accuracy: 0.4996 - val_loss: 1.8333 - val_accuracy: 0.4867
# Epoch 67/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.8460 - accuracy: 0.4982 - val_loss: 1.8221 - val_accuracy: 0.4767
# Epoch 68/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.8371 - accuracy: 0.4973 - val_loss: 1.8179 - val_accuracy: 0.4833
# Epoch 69/400
# 71/71 [==============================] - 10s 143ms/step - loss: 1.8220 - accuracy: 0.5160 - val_loss: 1.8108 - val_accuracy: 0.4833
# Epoch 70/400
# 71/71 [==============================] - 10s 142ms/step - loss: 1.8121 - accuracy: 0.5098 - val_loss: 1.8020 - val_accuracy: 0.4800
# Epoch 71/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.7977 - accuracy: 0.5218 - val_loss: 1.7962 - val_accuracy: 0.4833
# Epoch 72/400
# 71/71 [==============================] - 10s 143ms/step - loss: 1.7894 - accuracy: 0.5204 - val_loss: 1.7844 - val_accuracy: 0.4933
# Epoch 73/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.7816 - accuracy: 0.5164 - val_loss: 1.7826 - val_accuracy: 0.5000
# Epoch 74/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.7633 - accuracy: 0.5364 - val_loss: 1.7772 - val_accuracy: 0.4833
# Epoch 75/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.7624 - accuracy: 0.5351 - val_loss: 1.7728 - val_accuracy: 0.4900
# Epoch 76/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.7538 - accuracy: 0.5289 - val_loss: 1.7683 - val_accuracy: 0.4867
# Epoch 77/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.7508 - accuracy: 0.5324 - val_loss: 1.7538 - val_accuracy: 0.4967
# Epoch 78/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.7272 - accuracy: 0.5462 - val_loss: 1.7474 - val_accuracy: 0.4833
# Epoch 79/400
# 71/71 [==============================] - 10s 143ms/step - loss: 1.7281 - accuracy: 0.5333 - val_loss: 1.7430 - val_accuracy: 0.4867
# Epoch 80/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.7214 - accuracy: 0.5471 - val_loss: 1.7401 - val_accuracy: 0.5033
# Epoch 81/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.7000 - accuracy: 0.5418 - val_loss: 1.7316 - val_accuracy: 0.5000
# Epoch 82/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6983 - accuracy: 0.5462 - val_loss: 1.7226 - val_accuracy: 0.5000
# Epoch 83/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6898 - accuracy: 0.5458 - val_loss: 1.7143 - val_accuracy: 0.5100
# Epoch 84/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6746 - accuracy: 0.5556 - val_loss: 1.7132 - val_accuracy: 0.5133
# Epoch 85/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6676 - accuracy: 0.5684 - val_loss: 1.7092 - val_accuracy: 0.5100
# Epoch 86/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.6607 - accuracy: 0.5573 - val_loss: 1.6994 - val_accuracy: 0.5167
# Epoch 87/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6603 - accuracy: 0.5578 - val_loss: 1.6961 - val_accuracy: 0.4933
# Epoch 88/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6406 - accuracy: 0.5667 - val_loss: 1.6890 - val_accuracy: 0.5300
# Epoch 89/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6325 - accuracy: 0.5640 - val_loss: 1.6833 - val_accuracy: 0.5400
# Epoch 90/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6356 - accuracy: 0.5569 - val_loss: 1.6788 - val_accuracy: 0.5267
# Epoch 91/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6169 - accuracy: 0.5662 - val_loss: 1.6747 - val_accuracy: 0.5133
# Epoch 92/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.6125 - accuracy: 0.5769 - val_loss: 1.6708 - val_accuracy: 0.5067
# Epoch 93/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5983 - accuracy: 0.5773 - val_loss: 1.6683 - val_accuracy: 0.5133
# Epoch 94/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5923 - accuracy: 0.5813 - val_loss: 1.6643 - val_accuracy: 0.5333
# Epoch 95/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5834 - accuracy: 0.5862 - val_loss: 1.6515 - val_accuracy: 0.5600
# Epoch 96/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5762 - accuracy: 0.5924 - val_loss: 1.6487 - val_accuracy: 0.5333
# Epoch 97/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5778 - accuracy: 0.5827 - val_loss: 1.6458 - val_accuracy: 0.5333
# Epoch 98/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5617 - accuracy: 0.5893 - val_loss: 1.6387 - val_accuracy: 0.5433
# Epoch 99/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5480 - accuracy: 0.5956 - val_loss: 1.6412 - val_accuracy: 0.5433
# Epoch 100/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.5448 - accuracy: 0.6004 - val_loss: 1.6291 - val_accuracy: 0.5400
# Epoch 101/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5389 - accuracy: 0.6022 - val_loss: 1.6317 - val_accuracy: 0.5467
# Epoch 102/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5279 - accuracy: 0.6040 - val_loss: 1.6326 - val_accuracy: 0.5467
# Epoch 103/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5199 - accuracy: 0.6191 - val_loss: 1.6158 - val_accuracy: 0.5400
# Epoch 104/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5183 - accuracy: 0.6036 - val_loss: 1.6162 - val_accuracy: 0.5467
# Epoch 105/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.5092 - accuracy: 0.6102 - val_loss: 1.6089 - val_accuracy: 0.5633
# Epoch 106/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.5040 - accuracy: 0.6116 - val_loss: 1.6050 - val_accuracy: 0.5467
# Epoch 107/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.4926 - accuracy: 0.6093 - val_loss: 1.5996 - val_accuracy: 0.5533
# Epoch 108/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.4863 - accuracy: 0.6164 - val_loss: 1.5933 - val_accuracy: 0.5633
# Epoch 109/400
# 71/71 [==============================] - 10s 143ms/step - loss: 1.4815 - accuracy: 0.6098 - val_loss: 1.5968 - val_accuracy: 0.5533
# Epoch 110/400
# 71/71 [==============================] - 10s 143ms/step - loss: 1.4688 - accuracy: 0.6187 - val_loss: 1.5878 - val_accuracy: 0.5567
# Epoch 111/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.4675 - accuracy: 0.6293 - val_loss: 1.5834 - val_accuracy: 0.5433
# Epoch 112/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.4610 - accuracy: 0.6227 - val_loss: 1.5799 - val_accuracy: 0.5667
# Epoch 113/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.4508 - accuracy: 0.6342 - val_loss: 1.5755 - val_accuracy: 0.5667
# Epoch 114/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.4345 - accuracy: 0.6284 - val_loss: 1.5736 - val_accuracy: 0.5633
# Epoch 115/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.4256 - accuracy: 0.6356 - val_loss: 1.5752 - val_accuracy: 0.5500
# Epoch 116/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.4301 - accuracy: 0.6356 - val_loss: 1.5700 - val_accuracy: 0.5567
# Epoch 117/400
# 71/71 [==============================] - 10s 144ms/step - loss: 1.4222 - accuracy: 0.6324 - val_loss: 1.5660 - val_accuracy: 0.5600
# Epoch 118/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.3997 - accuracy: 0.6418 - val_loss: 1.5573 - val_accuracy: 0.5767
# Epoch 119/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3947 - accuracy: 0.6449 - val_loss: 1.5551 - val_accuracy: 0.5500
# Epoch 120/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3901 - accuracy: 0.6444 - val_loss: 1.5534 - val_accuracy: 0.5633
# Epoch 121/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3852 - accuracy: 0.6662 - val_loss: 1.5474 - val_accuracy: 0.5733
# Epoch 122/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3775 - accuracy: 0.6489 - val_loss: 1.5516 - val_accuracy: 0.5700
# Epoch 123/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3861 - accuracy: 0.6422 - val_loss: 1.5383 - val_accuracy: 0.5767
# Epoch 124/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3673 - accuracy: 0.6547 - val_loss: 1.5396 - val_accuracy: 0.5667
# Epoch 125/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3604 - accuracy: 0.6591 - val_loss: 1.5362 - val_accuracy: 0.5667
# Epoch 126/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3543 - accuracy: 0.6582 - val_loss: 1.5297 - val_accuracy: 0.5833
# Epoch 127/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.3450 - accuracy: 0.6609 - val_loss: 1.5255 - val_accuracy: 0.5867
# Epoch 128/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3353 - accuracy: 0.6720 - val_loss: 1.5230 - val_accuracy: 0.5833
# Epoch 129/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3300 - accuracy: 0.6627 - val_loss: 1.5251 - val_accuracy: 0.5633
# Epoch 130/400
# 71/71 [==============================] - 10s 143ms/step - loss: 1.3278 - accuracy: 0.6733 - val_loss: 1.5176 - val_accuracy: 0.5833
# Epoch 131/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3110 - accuracy: 0.6751 - val_loss: 1.5166 - val_accuracy: 0.5633
# Epoch 132/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.3048 - accuracy: 0.6796 - val_loss: 1.5191 - val_accuracy: 0.5700
# Epoch 133/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.3038 - accuracy: 0.6787 - val_loss: 1.5109 - val_accuracy: 0.5967
# Epoch 134/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.2914 - accuracy: 0.6742 - val_loss: 1.5061 - val_accuracy: 0.5867
# Epoch 135/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.2823 - accuracy: 0.6849 - val_loss: 1.4997 - val_accuracy: 0.5867
# Epoch 136/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.2871 - accuracy: 0.6738 - val_loss: 1.5075 - val_accuracy: 0.5833
# Epoch 137/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2822 - accuracy: 0.6751 - val_loss: 1.4982 - val_accuracy: 0.5900
# Epoch 138/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2712 - accuracy: 0.6804 - val_loss: 1.4924 - val_accuracy: 0.5967
# Epoch 139/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2628 - accuracy: 0.6858 - val_loss: 1.4924 - val_accuracy: 0.5800
# Epoch 140/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.2575 - accuracy: 0.6898 - val_loss: 1.4981 - val_accuracy: 0.5833
# Epoch 141/400
# 71/71 [==============================] - 10s 142ms/step - loss: 1.2456 - accuracy: 0.6947 - val_loss: 1.4869 - val_accuracy: 0.5900
# Epoch 142/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2411 - accuracy: 0.6978 - val_loss: 1.4901 - val_accuracy: 0.5567
# Epoch 143/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2405 - accuracy: 0.6969 - val_loss: 1.4965 - val_accuracy: 0.5900
# Epoch 144/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2247 - accuracy: 0.7036 - val_loss: 1.4939 - val_accuracy: 0.5867
# Epoch 145/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2269 - accuracy: 0.6960 - val_loss: 1.4772 - val_accuracy: 0.5800
# Epoch 146/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2134 - accuracy: 0.7204 - val_loss: 1.4801 - val_accuracy: 0.5800
# Epoch 147/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2076 - accuracy: 0.7169 - val_loss: 1.4749 - val_accuracy: 0.5767
# Epoch 148/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.2073 - accuracy: 0.7178 - val_loss: 1.4697 - val_accuracy: 0.5967
# Epoch 149/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.1973 - accuracy: 0.7071 - val_loss: 1.4705 - val_accuracy: 0.5867
# Epoch 150/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.1982 - accuracy: 0.7129 - val_loss: 1.4731 - val_accuracy: 0.5900
# Epoch 151/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.1849 - accuracy: 0.7240 - val_loss: 1.4679 - val_accuracy: 0.5900
# Epoch 152/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.1865 - accuracy: 0.7147 - val_loss: 1.4745 - val_accuracy: 0.6000
# Epoch 153/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.1672 - accuracy: 0.7209 - val_loss: 1.4682 - val_accuracy: 0.5700
# Epoch 154/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.1693 - accuracy: 0.7267 - val_loss: 1.4600 - val_accuracy: 0.5933
# Epoch 155/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.1665 - accuracy: 0.7209 - val_loss: 1.4538 - val_accuracy: 0.5767
# Epoch 156/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.1616 - accuracy: 0.7236 - val_loss: 1.4528 - val_accuracy: 0.5833
# Epoch 157/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.1557 - accuracy: 0.7236 - val_loss: 1.4589 - val_accuracy: 0.5833
# Epoch 158/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.1474 - accuracy: 0.7293 - val_loss: 1.4479 - val_accuracy: 0.6000
# Epoch 159/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.1393 - accuracy: 0.7262 - val_loss: 1.4531 - val_accuracy: 0.5667
# Epoch 160/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.1358 - accuracy: 0.7258 - val_loss: 1.4464 - val_accuracy: 0.5833
# Epoch 161/400
# 71/71 [==============================] - 10s 138ms/step - loss: 1.1227 - accuracy: 0.7342 - val_loss: 1.4503 - val_accuracy: 0.6000
# Epoch 162/400
# 71/71 [==============================] - 10s 143ms/step - loss: 1.1287 - accuracy: 0.7391 - val_loss: 1.4509 - val_accuracy: 0.5833
# Epoch 163/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.1195 - accuracy: 0.7316 - val_loss: 1.4475 - val_accuracy: 0.5933
# Epoch 164/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.1119 - accuracy: 0.7396 - val_loss: 1.4514 - val_accuracy: 0.5800
# Epoch 165/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.1042 - accuracy: 0.7382 - val_loss: 1.4488 - val_accuracy: 0.5867
# Epoch 166/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0921 - accuracy: 0.7364 - val_loss: 1.4396 - val_accuracy: 0.6033
# Epoch 167/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0997 - accuracy: 0.7427 - val_loss: 1.4358 - val_accuracy: 0.6167
# Epoch 168/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0878 - accuracy: 0.7453 - val_loss: 1.4317 - val_accuracy: 0.5933
# Epoch 169/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0715 - accuracy: 0.7604 - val_loss: 1.4400 - val_accuracy: 0.5967
# Epoch 170/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0790 - accuracy: 0.7427 - val_loss: 1.4319 - val_accuracy: 0.5967
# Epoch 171/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0740 - accuracy: 0.7538 - val_loss: 1.4346 - val_accuracy: 0.5833
# Epoch 172/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0630 - accuracy: 0.7511 - val_loss: 1.4204 - val_accuracy: 0.5967
# Epoch 173/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0576 - accuracy: 0.7609 - val_loss: 1.4243 - val_accuracy: 0.5933
# Epoch 174/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0533 - accuracy: 0.7600 - val_loss: 1.4311 - val_accuracy: 0.6000
# Epoch 175/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0510 - accuracy: 0.7676 - val_loss: 1.4170 - val_accuracy: 0.5933
# Epoch 176/400
# 71/71 [==============================] - 10s 141ms/step - loss: 1.0401 - accuracy: 0.7604 - val_loss: 1.4169 - val_accuracy: 0.6033
# Epoch 177/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.0440 - accuracy: 0.7591 - val_loss: 1.4082 - val_accuracy: 0.6000
# Epoch 178/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.0327 - accuracy: 0.7667 - val_loss: 1.4100 - val_accuracy: 0.6033
# Epoch 179/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.0309 - accuracy: 0.7680 - val_loss: 1.4217 - val_accuracy: 0.6100
# Epoch 180/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.0297 - accuracy: 0.7573 - val_loss: 1.4095 - val_accuracy: 0.6033
# Epoch 181/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0052 - accuracy: 0.7769 - val_loss: 1.4121 - val_accuracy: 0.6000
# Epoch 182/400
# 71/71 [==============================] - 10s 140ms/step - loss: 1.0163 - accuracy: 0.7636 - val_loss: 1.4061 - val_accuracy: 0.5933
# Epoch 183/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0002 - accuracy: 0.7787 - val_loss: 1.3984 - val_accuracy: 0.5800
# Epoch 184/400
# 71/71 [==============================] - 10s 139ms/step - loss: 1.0079 - accuracy: 0.7760 - val_loss: 1.4095 - val_accuracy: 0.5967
# Epoch 185/400
# 71/71 [==============================] - 10s 144ms/step - loss: 0.9874 - accuracy: 0.7796 - val_loss: 1.4102 - val_accuracy: 0.6100
# Epoch 186/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9967 - accuracy: 0.7711 - val_loss: 1.4051 - val_accuracy: 0.5800
# Epoch 187/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.9858 - accuracy: 0.7698 - val_loss: 1.3928 - val_accuracy: 0.5967
# Epoch 188/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9739 - accuracy: 0.7818 - val_loss: 1.3990 - val_accuracy: 0.6067
# Epoch 189/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.9763 - accuracy: 0.7791 - val_loss: 1.4032 - val_accuracy: 0.5833
# Epoch 190/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.9745 - accuracy: 0.7756 - val_loss: 1.4060 - val_accuracy: 0.5833
# Epoch 191/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.9729 - accuracy: 0.7778 - val_loss: 1.3953 - val_accuracy: 0.5833
# Epoch 192/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.9612 - accuracy: 0.7827 - val_loss: 1.3893 - val_accuracy: 0.6000
# Epoch 193/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9554 - accuracy: 0.7818 - val_loss: 1.3967 - val_accuracy: 0.6100
# Epoch 194/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9445 - accuracy: 0.7929 - val_loss: 1.3970 - val_accuracy: 0.6033
# Epoch 195/400
# 71/71 [==============================] - 10s 143ms/step - loss: 0.9477 - accuracy: 0.7929 - val_loss: 1.3862 - val_accuracy: 0.5967
# Epoch 196/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9498 - accuracy: 0.7924 - val_loss: 1.3990 - val_accuracy: 0.6100
# Epoch 197/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9455 - accuracy: 0.7889 - val_loss: 1.3940 - val_accuracy: 0.5967
# Epoch 198/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9276 - accuracy: 0.7902 - val_loss: 1.3820 - val_accuracy: 0.6067
# Epoch 199/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9262 - accuracy: 0.7889 - val_loss: 1.3841 - val_accuracy: 0.5967
# Epoch 200/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9198 - accuracy: 0.7916 - val_loss: 1.3801 - val_accuracy: 0.6000
# Epoch 201/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9108 - accuracy: 0.8044 - val_loss: 1.3765 - val_accuracy: 0.6000
# Epoch 202/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.9052 - accuracy: 0.8000 - val_loss: 1.3818 - val_accuracy: 0.6133
# Epoch 203/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.9070 - accuracy: 0.7938 - val_loss: 1.3739 - val_accuracy: 0.5967
# Epoch 204/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8907 - accuracy: 0.8084 - val_loss: 1.3892 - val_accuracy: 0.5967
# Epoch 205/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8978 - accuracy: 0.7982 - val_loss: 1.3743 - val_accuracy: 0.6000
# Epoch 206/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8887 - accuracy: 0.8071 - val_loss: 1.3845 - val_accuracy: 0.5967
# Epoch 207/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8852 - accuracy: 0.8138 - val_loss: 1.3757 - val_accuracy: 0.6100
# Epoch 208/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8895 - accuracy: 0.8040 - val_loss: 1.3835 - val_accuracy: 0.5933
# Epoch 209/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8763 - accuracy: 0.8049 - val_loss: 1.3708 - val_accuracy: 0.6000
# Epoch 210/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8763 - accuracy: 0.8036 - val_loss: 1.3752 - val_accuracy: 0.6033
# Epoch 211/400
# 71/71 [==============================] - 10s 143ms/step - loss: 0.8617 - accuracy: 0.8124 - val_loss: 1.3715 - val_accuracy: 0.5800
# Epoch 212/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8669 - accuracy: 0.8147 - val_loss: 1.3635 - val_accuracy: 0.5967
# Epoch 213/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8555 - accuracy: 0.8138 - val_loss: 1.3743 - val_accuracy: 0.6133
# Epoch 214/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8484 - accuracy: 0.8067 - val_loss: 1.3766 - val_accuracy: 0.5900
# Epoch 215/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8552 - accuracy: 0.8102 - val_loss: 1.3580 - val_accuracy: 0.6133
# Epoch 216/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8419 - accuracy: 0.8187 - val_loss: 1.3691 - val_accuracy: 0.6000
# Epoch 217/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8312 - accuracy: 0.8240 - val_loss: 1.3709 - val_accuracy: 0.5967
# Epoch 218/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8353 - accuracy: 0.8196 - val_loss: 1.3789 - val_accuracy: 0.5967
# Epoch 219/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8223 - accuracy: 0.8298 - val_loss: 1.3724 - val_accuracy: 0.5967
# Epoch 220/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8264 - accuracy: 0.8169 - val_loss: 1.3548 - val_accuracy: 0.5933
# Epoch 221/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8127 - accuracy: 0.8360 - val_loss: 1.3738 - val_accuracy: 0.6033
# Epoch 222/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8122 - accuracy: 0.8244 - val_loss: 1.3589 - val_accuracy: 0.6133
# Epoch 223/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8091 - accuracy: 0.8227 - val_loss: 1.3592 - val_accuracy: 0.5867
# Epoch 224/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.8033 - accuracy: 0.8293 - val_loss: 1.3602 - val_accuracy: 0.6000
# Epoch 225/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8010 - accuracy: 0.8267 - val_loss: 1.3602 - val_accuracy: 0.5800
# Epoch 226/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7971 - accuracy: 0.8240 - val_loss: 1.3716 - val_accuracy: 0.5933
# Epoch 227/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.8007 - accuracy: 0.8267 - val_loss: 1.3584 - val_accuracy: 0.6000
# Epoch 228/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.7875 - accuracy: 0.8360 - val_loss: 1.3573 - val_accuracy: 0.5833
# Epoch 229/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7854 - accuracy: 0.8307 - val_loss: 1.3540 - val_accuracy: 0.6000
# Epoch 230/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.7854 - accuracy: 0.8356 - val_loss: 1.3543 - val_accuracy: 0.6000
# Epoch 231/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.7732 - accuracy: 0.8387 - val_loss: 1.3632 - val_accuracy: 0.6000
# Epoch 232/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7755 - accuracy: 0.8356 - val_loss: 1.3417 - val_accuracy: 0.5900
# Epoch 233/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7612 - accuracy: 0.8418 - val_loss: 1.3604 - val_accuracy: 0.5900
# Epoch 234/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7559 - accuracy: 0.8444 - val_loss: 1.3488 - val_accuracy: 0.5933
# Epoch 235/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.7512 - accuracy: 0.8431 - val_loss: 1.3423 - val_accuracy: 0.5900
# Epoch 236/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.7437 - accuracy: 0.8529 - val_loss: 1.3510 - val_accuracy: 0.5967
# Epoch 237/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7496 - accuracy: 0.8378 - val_loss: 1.3549 - val_accuracy: 0.6033
# Epoch 238/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.7498 - accuracy: 0.8413 - val_loss: 1.3511 - val_accuracy: 0.5900
# Epoch 239/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7476 - accuracy: 0.8458 - val_loss: 1.3497 - val_accuracy: 0.5900
# Epoch 240/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7258 - accuracy: 0.8511 - val_loss: 1.3423 - val_accuracy: 0.5900
# Epoch 241/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.7397 - accuracy: 0.8458 - val_loss: 1.3422 - val_accuracy: 0.5833
# Epoch 242/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7248 - accuracy: 0.8551 - val_loss: 1.3722 - val_accuracy: 0.5733
# Epoch 243/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7293 - accuracy: 0.8480 - val_loss: 1.3465 - val_accuracy: 0.6100
# Epoch 244/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7185 - accuracy: 0.8591 - val_loss: 1.3366 - val_accuracy: 0.6000
# Epoch 245/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7186 - accuracy: 0.8529 - val_loss: 1.3355 - val_accuracy: 0.6000
# Epoch 246/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.7038 - accuracy: 0.8542 - val_loss: 1.3329 - val_accuracy: 0.5933
# Epoch 247/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7097 - accuracy: 0.8587 - val_loss: 1.3452 - val_accuracy: 0.5933
# Epoch 248/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.7074 - accuracy: 0.8556 - val_loss: 1.3458 - val_accuracy: 0.5833
# Epoch 249/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7021 - accuracy: 0.8591 - val_loss: 1.3510 - val_accuracy: 0.5933
# Epoch 250/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.7033 - accuracy: 0.8578 - val_loss: 1.3294 - val_accuracy: 0.5833
# Epoch 251/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.6875 - accuracy: 0.8631 - val_loss: 1.3418 - val_accuracy: 0.5867
# Epoch 252/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.6923 - accuracy: 0.8556 - val_loss: 1.3385 - val_accuracy: 0.5867
# Epoch 253/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.6850 - accuracy: 0.8636 - val_loss: 1.3352 - val_accuracy: 0.5867
# Epoch 254/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.6809 - accuracy: 0.8649 - val_loss: 1.3311 - val_accuracy: 0.5833
# Epoch 255/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.6822 - accuracy: 0.8587 - val_loss: 1.3482 - val_accuracy: 0.5933
# Epoch 256/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.6822 - accuracy: 0.8609 - val_loss: 1.3374 - val_accuracy: 0.5933
# Epoch 257/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.6672 - accuracy: 0.8671 - val_loss: 1.3328 - val_accuracy: 0.5833
# Epoch 258/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6714 - accuracy: 0.8573 - val_loss: 1.3349 - val_accuracy: 0.5833
# Epoch 259/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6591 - accuracy: 0.8676 - val_loss: 1.3349 - val_accuracy: 0.5900
# Epoch 260/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6629 - accuracy: 0.8662 - val_loss: 1.3389 - val_accuracy: 0.5833
# Epoch 261/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6600 - accuracy: 0.8653 - val_loss: 1.3287 - val_accuracy: 0.5867
# Epoch 262/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6476 - accuracy: 0.8778 - val_loss: 1.3300 - val_accuracy: 0.5833
# Epoch 263/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6453 - accuracy: 0.8693 - val_loss: 1.3262 - val_accuracy: 0.5833
# Epoch 264/400
# 71/71 [==============================] - 10s 144ms/step - loss: 0.6450 - accuracy: 0.8707 - val_loss: 1.3348 - val_accuracy: 0.5833
# Epoch 265/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.6379 - accuracy: 0.8747 - val_loss: 1.3252 - val_accuracy: 0.5933
# Epoch 266/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.6403 - accuracy: 0.8693 - val_loss: 1.3453 - val_accuracy: 0.5767
# Epoch 267/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6321 - accuracy: 0.8724 - val_loss: 1.3272 - val_accuracy: 0.5700
# Epoch 268/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6334 - accuracy: 0.8764 - val_loss: 1.3243 - val_accuracy: 0.5867
# Epoch 269/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6280 - accuracy: 0.8764 - val_loss: 1.3371 - val_accuracy: 0.5900
# Epoch 270/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6255 - accuracy: 0.8729 - val_loss: 1.3297 - val_accuracy: 0.5633
# Epoch 271/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.6157 - accuracy: 0.8773 - val_loss: 1.3383 - val_accuracy: 0.5900
# Epoch 272/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6171 - accuracy: 0.8769 - val_loss: 1.3415 - val_accuracy: 0.5933
# Epoch 273/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6060 - accuracy: 0.8809 - val_loss: 1.3215 - val_accuracy: 0.5933
# Epoch 274/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6088 - accuracy: 0.8853 - val_loss: 1.3292 - val_accuracy: 0.5800
# Epoch 275/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5996 - accuracy: 0.8853 - val_loss: 1.3235 - val_accuracy: 0.5800
# Epoch 276/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.6009 - accuracy: 0.8827 - val_loss: 1.3203 - val_accuracy: 0.6000
# Epoch 277/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.5927 - accuracy: 0.8862 - val_loss: 1.3341 - val_accuracy: 0.5900
# Epoch 278/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.5993 - accuracy: 0.8836 - val_loss: 1.3310 - val_accuracy: 0.6067
# Epoch 279/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5917 - accuracy: 0.8884 - val_loss: 1.3241 - val_accuracy: 0.5933
# Epoch 280/400
# 71/71 [==============================] - 10s 145ms/step - loss: 0.5874 - accuracy: 0.8884 - val_loss: 1.3375 - val_accuracy: 0.5933
# Epoch 281/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.5891 - accuracy: 0.8831 - val_loss: 1.3242 - val_accuracy: 0.5933
# Epoch 282/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5737 - accuracy: 0.8916 - val_loss: 1.3340 - val_accuracy: 0.5867
# Epoch 283/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5759 - accuracy: 0.8951 - val_loss: 1.3337 - val_accuracy: 0.5867
# Epoch 284/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5679 - accuracy: 0.8902 - val_loss: 1.3252 - val_accuracy: 0.5933
# Epoch 285/400
# 71/71 [==============================] - 10s 145ms/step - loss: 0.5676 - accuracy: 0.8916 - val_loss: 1.3235 - val_accuracy: 0.5767
# Epoch 286/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5689 - accuracy: 0.8924 - val_loss: 1.3217 - val_accuracy: 0.5667
# Epoch 287/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5538 - accuracy: 0.8929 - val_loss: 1.3331 - val_accuracy: 0.5933
# Epoch 288/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.5575 - accuracy: 0.8880 - val_loss: 1.3173 - val_accuracy: 0.5800
# Epoch 289/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5529 - accuracy: 0.8947 - val_loss: 1.3318 - val_accuracy: 0.5900
# Epoch 290/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5545 - accuracy: 0.8982 - val_loss: 1.3267 - val_accuracy: 0.5867
# Epoch 291/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5424 - accuracy: 0.9009 - val_loss: 1.3303 - val_accuracy: 0.6067
# Epoch 292/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.5438 - accuracy: 0.9036 - val_loss: 1.3313 - val_accuracy: 0.5800
# Epoch 293/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.5456 - accuracy: 0.8942 - val_loss: 1.3404 - val_accuracy: 0.5900
# Epoch 294/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5381 - accuracy: 0.9036 - val_loss: 1.3185 - val_accuracy: 0.5967
# Epoch 295/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5328 - accuracy: 0.9018 - val_loss: 1.3234 - val_accuracy: 0.5900
# Epoch 296/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5294 - accuracy: 0.9022 - val_loss: 1.3189 - val_accuracy: 0.5733
# Epoch 297/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.5285 - accuracy: 0.9049 - val_loss: 1.3143 - val_accuracy: 0.5867
# Epoch 298/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5276 - accuracy: 0.9004 - val_loss: 1.3138 - val_accuracy: 0.5967
# Epoch 299/400
# 71/71 [==============================] - 10s 144ms/step - loss: 0.5211 - accuracy: 0.9022 - val_loss: 1.3349 - val_accuracy: 0.5967
# Epoch 300/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.5160 - accuracy: 0.9084 - val_loss: 1.3206 - val_accuracy: 0.6033
# Epoch 301/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5197 - accuracy: 0.9031 - val_loss: 1.3293 - val_accuracy: 0.6000
# Epoch 302/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.5109 - accuracy: 0.9093 - val_loss: 1.3243 - val_accuracy: 0.6000
# Epoch 303/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.5092 - accuracy: 0.9071 - val_loss: 1.3212 - val_accuracy: 0.5800
# Epoch 304/400
# 71/71 [==============================] - 10s 146ms/step - loss: 0.5120 - accuracy: 0.9058 - val_loss: 1.3325 - val_accuracy: 0.6033
# Epoch 305/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.5038 - accuracy: 0.9076 - val_loss: 1.3181 - val_accuracy: 0.5900
# Epoch 306/400
# 71/71 [==============================] - 10s 144ms/step - loss: 0.4981 - accuracy: 0.9120 - val_loss: 1.3211 - val_accuracy: 0.5900
# Epoch 307/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4884 - accuracy: 0.9129 - val_loss: 1.3212 - val_accuracy: 0.6000
# Epoch 308/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4912 - accuracy: 0.9196 - val_loss: 1.3160 - val_accuracy: 0.5900
# Epoch 309/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4872 - accuracy: 0.9164 - val_loss: 1.3104 - val_accuracy: 0.5933
# Epoch 310/400
# 71/71 [==============================] - 10s 144ms/step - loss: 0.4886 - accuracy: 0.9169 - val_loss: 1.3139 - val_accuracy: 0.6000
# Epoch 311/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4762 - accuracy: 0.9200 - val_loss: 1.3223 - val_accuracy: 0.5933
# Epoch 312/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4730 - accuracy: 0.9160 - val_loss: 1.3242 - val_accuracy: 0.5967
# Epoch 313/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4738 - accuracy: 0.9200 - val_loss: 1.3254 - val_accuracy: 0.6000
# Epoch 314/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4697 - accuracy: 0.9169 - val_loss: 1.3226 - val_accuracy: 0.5900
# Epoch 315/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.4688 - accuracy: 0.9200 - val_loss: 1.3138 - val_accuracy: 0.5967
# Epoch 316/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4570 - accuracy: 0.9240 - val_loss: 1.3252 - val_accuracy: 0.5933
# Epoch 317/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4683 - accuracy: 0.9187 - val_loss: 1.3295 - val_accuracy: 0.5800
# Epoch 318/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4580 - accuracy: 0.9236 - val_loss: 1.3161 - val_accuracy: 0.6000
# Epoch 319/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4551 - accuracy: 0.9249 - val_loss: 1.3215 - val_accuracy: 0.6100
# Epoch 320/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4512 - accuracy: 0.9227 - val_loss: 1.3281 - val_accuracy: 0.5967
# Epoch 321/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4534 - accuracy: 0.9253 - val_loss: 1.3140 - val_accuracy: 0.6200
# Epoch 322/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4474 - accuracy: 0.9204 - val_loss: 1.3290 - val_accuracy: 0.5900
# Epoch 323/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4524 - accuracy: 0.9222 - val_loss: 1.3262 - val_accuracy: 0.6067
# Epoch 324/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4444 - accuracy: 0.9231 - val_loss: 1.3119 - val_accuracy: 0.6033
# Epoch 325/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4401 - accuracy: 0.9289 - val_loss: 1.3088 - val_accuracy: 0.6000
# Epoch 326/400
# 71/71 [==============================] - 10s 143ms/step - loss: 0.4383 - accuracy: 0.9244 - val_loss: 1.3312 - val_accuracy: 0.5933
# Epoch 327/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.4353 - accuracy: 0.9280 - val_loss: 1.3245 - val_accuracy: 0.5833
# Epoch 328/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4402 - accuracy: 0.9244 - val_loss: 1.3269 - val_accuracy: 0.6000
# Epoch 329/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4313 - accuracy: 0.9293 - val_loss: 1.3128 - val_accuracy: 0.5967
# Epoch 330/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4287 - accuracy: 0.9258 - val_loss: 1.3314 - val_accuracy: 0.6000
# Epoch 331/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4303 - accuracy: 0.9240 - val_loss: 1.3244 - val_accuracy: 0.6000
# Epoch 332/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.4251 - accuracy: 0.9293 - val_loss: 1.3068 - val_accuracy: 0.5900
# Epoch 333/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.4243 - accuracy: 0.9311 - val_loss: 1.3060 - val_accuracy: 0.6033
# Epoch 334/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4186 - accuracy: 0.9307 - val_loss: 1.3260 - val_accuracy: 0.6067
# Epoch 335/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.4082 - accuracy: 0.9378 - val_loss: 1.3180 - val_accuracy: 0.5933
# Epoch 336/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.4084 - accuracy: 0.9329 - val_loss: 1.3333 - val_accuracy: 0.6033
# Epoch 337/400
# 71/71 [==============================] - 10s 145ms/step - loss: 0.4083 - accuracy: 0.9351 - val_loss: 1.3282 - val_accuracy: 0.6000
# Epoch 338/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.4065 - accuracy: 0.9333 - val_loss: 1.3124 - val_accuracy: 0.6033
# Epoch 339/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4018 - accuracy: 0.9338 - val_loss: 1.3261 - val_accuracy: 0.6100
# Epoch 340/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.4008 - accuracy: 0.9369 - val_loss: 1.3529 - val_accuracy: 0.5900
# Epoch 341/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3955 - accuracy: 0.9409 - val_loss: 1.3132 - val_accuracy: 0.6067
# Epoch 342/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3937 - accuracy: 0.9391 - val_loss: 1.3160 - val_accuracy: 0.5933
# Epoch 343/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3915 - accuracy: 0.9338 - val_loss: 1.3368 - val_accuracy: 0.6033
# Epoch 344/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3941 - accuracy: 0.9316 - val_loss: 1.3306 - val_accuracy: 0.5967
# Epoch 345/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3915 - accuracy: 0.9356 - val_loss: 1.3140 - val_accuracy: 0.6033
# Epoch 346/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3834 - accuracy: 0.9422 - val_loss: 1.3350 - val_accuracy: 0.6167
# Epoch 347/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3802 - accuracy: 0.9431 - val_loss: 1.3263 - val_accuracy: 0.6133
# Epoch 348/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3789 - accuracy: 0.9440 - val_loss: 1.3381 - val_accuracy: 0.5967
# Epoch 349/400
# 71/71 [==============================] - 10s 139ms/step - loss: 0.3807 - accuracy: 0.9391 - val_loss: 1.3333 - val_accuracy: 0.6200
# Epoch 350/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3745 - accuracy: 0.9462 - val_loss: 1.3248 - val_accuracy: 0.6067
# Epoch 351/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3642 - accuracy: 0.9476 - val_loss: 1.3274 - val_accuracy: 0.6100
# Epoch 352/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3672 - accuracy: 0.9409 - val_loss: 1.3228 - val_accuracy: 0.6167
# Epoch 353/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.3665 - accuracy: 0.9396 - val_loss: 1.3237 - val_accuracy: 0.6033
# Epoch 354/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3663 - accuracy: 0.9471 - val_loss: 1.3214 - val_accuracy: 0.6233
# Epoch 355/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3680 - accuracy: 0.9471 - val_loss: 1.3193 - val_accuracy: 0.6100
# Epoch 356/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3498 - accuracy: 0.9533 - val_loss: 1.3407 - val_accuracy: 0.6000
# Epoch 357/400
# 71/71 [==============================] - 10s 146ms/step - loss: 0.3558 - accuracy: 0.9462 - val_loss: 1.3209 - val_accuracy: 0.6100
# Epoch 358/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3556 - accuracy: 0.9489 - val_loss: 1.3279 - val_accuracy: 0.6100
# Epoch 359/400
# 71/71 [==============================] - 10s 145ms/step - loss: 0.3494 - accuracy: 0.9520 - val_loss: 1.3451 - val_accuracy: 0.6067
# Epoch 360/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3495 - accuracy: 0.9484 - val_loss: 1.3563 - val_accuracy: 0.5933
# Epoch 361/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3499 - accuracy: 0.9471 - val_loss: 1.3441 - val_accuracy: 0.6133
# Epoch 362/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3476 - accuracy: 0.9502 - val_loss: 1.3402 - val_accuracy: 0.6067
# Epoch 363/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3413 - accuracy: 0.9507 - val_loss: 1.3377 - val_accuracy: 0.6133
# Epoch 364/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3409 - accuracy: 0.9476 - val_loss: 1.3213 - val_accuracy: 0.6167
# Epoch 365/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3392 - accuracy: 0.9493 - val_loss: 1.3373 - val_accuracy: 0.6133
# Epoch 366/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3357 - accuracy: 0.9520 - val_loss: 1.3209 - val_accuracy: 0.6067
# Epoch 367/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3341 - accuracy: 0.9542 - val_loss: 1.3228 - val_accuracy: 0.6000
# Epoch 368/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3342 - accuracy: 0.9493 - val_loss: 1.3284 - val_accuracy: 0.6033
# Epoch 369/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3278 - accuracy: 0.9516 - val_loss: 1.3541 - val_accuracy: 0.5833
# Epoch 370/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3258 - accuracy: 0.9529 - val_loss: 1.3198 - val_accuracy: 0.6067
# Epoch 371/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3290 - accuracy: 0.9498 - val_loss: 1.3359 - val_accuracy: 0.6200
# Epoch 372/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3247 - accuracy: 0.9498 - val_loss: 1.3248 - val_accuracy: 0.6033
# Epoch 373/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3154 - accuracy: 0.9560 - val_loss: 1.3330 - val_accuracy: 0.6200
# Epoch 374/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.3186 - accuracy: 0.9538 - val_loss: 1.3329 - val_accuracy: 0.5867
# Epoch 375/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3122 - accuracy: 0.9547 - val_loss: 1.3393 - val_accuracy: 0.6133
# Epoch 376/400
# 71/71 [==============================] - 10s 145ms/step - loss: 0.3127 - accuracy: 0.9578 - val_loss: 1.3586 - val_accuracy: 0.6067
# Epoch 377/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3122 - accuracy: 0.9578 - val_loss: 1.3429 - val_accuracy: 0.6133
# Epoch 378/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3059 - accuracy: 0.9591 - val_loss: 1.3475 - val_accuracy: 0.6100
# Epoch 379/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3097 - accuracy: 0.9582 - val_loss: 1.3222 - val_accuracy: 0.5900
# Epoch 380/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3026 - accuracy: 0.9582 - val_loss: 1.3280 - val_accuracy: 0.6200
# Epoch 381/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.3018 - accuracy: 0.9609 - val_loss: 1.3312 - val_accuracy: 0.6167
# Epoch 382/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3006 - accuracy: 0.9560 - val_loss: 1.3371 - val_accuracy: 0.6033
# Epoch 383/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.3044 - accuracy: 0.9600 - val_loss: 1.3304 - val_accuracy: 0.6133
# Epoch 384/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.2971 - accuracy: 0.9600 - val_loss: 1.3389 - val_accuracy: 0.5933
# Epoch 385/400
# 71/71 [==============================] - 10s 145ms/step - loss: 0.2909 - accuracy: 0.9627 - val_loss: 1.3336 - val_accuracy: 0.5900
# Epoch 386/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.2908 - accuracy: 0.9582 - val_loss: 1.3335 - val_accuracy: 0.6133
# Epoch 387/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.2882 - accuracy: 0.9569 - val_loss: 1.3250 - val_accuracy: 0.5967
# Epoch 388/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.2858 - accuracy: 0.9609 - val_loss: 1.3413 - val_accuracy: 0.6133
# Epoch 389/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.2894 - accuracy: 0.9604 - val_loss: 1.3464 - val_accuracy: 0.5933
# Epoch 390/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.2837 - accuracy: 0.9627 - val_loss: 1.3539 - val_accuracy: 0.5967
# Epoch 391/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.2819 - accuracy: 0.9591 - val_loss: 1.3461 - val_accuracy: 0.6133
# Epoch 392/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.2822 - accuracy: 0.9622 - val_loss: 1.3608 - val_accuracy: 0.6133
# Epoch 393/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.2763 - accuracy: 0.9640 - val_loss: 1.3495 - val_accuracy: 0.6033
# Epoch 394/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.2806 - accuracy: 0.9596 - val_loss: 1.3617 - val_accuracy: 0.6167
# Epoch 395/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.2741 - accuracy: 0.9640 - val_loss: 1.3383 - val_accuracy: 0.6067
# Epoch 396/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.2780 - accuracy: 0.9609 - val_loss: 1.3379 - val_accuracy: 0.6033
# Epoch 397/400
# 71/71 [==============================] - 10s 140ms/step - loss: 0.2687 - accuracy: 0.9636 - val_loss: 1.3342 - val_accuracy: 0.6000
# Epoch 398/400
# 71/71 [==============================] - 10s 141ms/step - loss: 0.2734 - accuracy: 0.9636 - val_loss: 1.3284 - val_accuracy: 0.6133
# Epoch 399/400
# 71/71 [==============================] - 10s 142ms/step - loss: 0.2688 - accuracy: 0.9649 - val_loss: 1.3493 - val_accuracy: 0.6133
# Epoch 400/400
# 71/71 [==============================] - 10s 145ms/step - loss: 0.2636 - accuracy: 0.9671 - val_loss: 1.3576 - val_accuracy: 0.6067

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.65      0.75      0.70        20
#             Garuda       0.72      0.65      0.68        20
#      Goddess_Durga       0.72      0.90      0.80        20
#    Goddess_Lakshmi       0.33      0.40      0.36        20
# Goddess_Saraswathi       0.50      0.25      0.33        20
#        Lord_Ganesh       0.44      0.35      0.39        20
#       Lord_Hanuman       0.39      0.35      0.37        20
#     Lord_Hayagriva       0.73      0.55      0.63        20
#         Lord_Indra       0.71      1.00      0.83        20
#       Lord_Krishna       0.76      0.65      0.70        20
#        Lord_Muruga       0.33      0.30      0.32        20
#              Nandi       0.78      0.70      0.74        20
#            Nataraj       0.86      0.90      0.88        20
#    Shirdi_Sai_Baba       0.45      0.65      0.53        20
#           Shivling       0.70      0.70      0.70        20
#
#           accuracy                           0.61       300
#          macro avg       0.61      0.61      0.60       300
#       weighted avg       0.61      0.61      0.60       300
#
#
# Accuracy = 60.66666666666667%

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-6) and 400 iterations, the highest accuracy obtained is 63%(approx) at (300, 350).**
