# %% [markdown]
# ## **CNN Draft 2**
# #### **lr=1*10^(-6), epochs=400, Accuracy = 68% (approx) at (290, 360) epochs range**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find suitable learning rate and epoch value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                data.append([resized_arr, class_num])
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15990709069611165743
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11320098816
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5580651850562509895
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 400
l_rate = 0.000001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 3000)              1731000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 1,915,439
# Trainable params: 1,915,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/400
# 71/71 [==============================] - 16s 92ms/step - loss: 2.7092 - accuracy: 0.0556 - val_loss: 2.7072 - val_accuracy: 0.0667
# Epoch 2/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.7079 - accuracy: 0.0698 - val_loss: 2.7060 - val_accuracy: 0.0933
# Epoch 3/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.7065 - accuracy: 0.0742 - val_loss: 2.7049 - val_accuracy: 0.0767
# Epoch 4/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.7054 - accuracy: 0.0760 - val_loss: 2.7038 - val_accuracy: 0.0800
# Epoch 5/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.7045 - accuracy: 0.0813 - val_loss: 2.7025 - val_accuracy: 0.0733
# Epoch 6/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.7037 - accuracy: 0.0902 - val_loss: 2.7013 - val_accuracy: 0.1200
# Epoch 7/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.7035 - accuracy: 0.0867 - val_loss: 2.6996 - val_accuracy: 0.1200
# Epoch 8/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.7017 - accuracy: 0.0858 - val_loss: 2.6973 - val_accuracy: 0.1267
# Epoch 9/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6988 - accuracy: 0.1027 - val_loss: 2.6943 - val_accuracy: 0.1333
# Epoch 10/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6973 - accuracy: 0.1062 - val_loss: 2.6902 - val_accuracy: 0.1467
# Epoch 11/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.6936 - accuracy: 0.1160 - val_loss: 2.6838 - val_accuracy: 0.1667
# Epoch 12/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6880 - accuracy: 0.1253 - val_loss: 2.6750 - val_accuracy: 0.1567
# Epoch 13/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6814 - accuracy: 0.1182 - val_loss: 2.6615 - val_accuracy: 0.1833
# Epoch 14/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6684 - accuracy: 0.1307 - val_loss: 2.6417 - val_accuracy: 0.2100
# Epoch 15/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6555 - accuracy: 0.1369 - val_loss: 2.6152 - val_accuracy: 0.2100
# Epoch 16/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6311 - accuracy: 0.1578 - val_loss: 2.5760 - val_accuracy: 0.2333
# Epoch 17/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6056 - accuracy: 0.1627 - val_loss: 2.5296 - val_accuracy: 0.2133
# Epoch 18/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.5808 - accuracy: 0.1778 - val_loss: 2.4855 - val_accuracy: 0.2433
# Epoch 19/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.5479 - accuracy: 0.1844 - val_loss: 2.4378 - val_accuracy: 0.2500
# Epoch 20/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.5144 - accuracy: 0.1876 - val_loss: 2.3911 - val_accuracy: 0.2933
# Epoch 21/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.4892 - accuracy: 0.2058 - val_loss: 2.3494 - val_accuracy: 0.2767
# Epoch 22/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.4718 - accuracy: 0.2044 - val_loss: 2.3232 - val_accuracy: 0.2867
# Epoch 23/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.4323 - accuracy: 0.2240 - val_loss: 2.2698 - val_accuracy: 0.3133
# Epoch 24/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.4196 - accuracy: 0.2187 - val_loss: 2.2390 - val_accuracy: 0.3300
# Epoch 25/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.3893 - accuracy: 0.2329 - val_loss: 2.2080 - val_accuracy: 0.3367
# Epoch 26/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.3731 - accuracy: 0.2436 - val_loss: 2.1758 - val_accuracy: 0.3333
# Epoch 27/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.3587 - accuracy: 0.2467 - val_loss: 2.1477 - val_accuracy: 0.3433
# Epoch 28/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.3309 - accuracy: 0.2480 - val_loss: 2.1215 - val_accuracy: 0.3500
# Epoch 29/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.3170 - accuracy: 0.2622 - val_loss: 2.0949 - val_accuracy: 0.3433
# Epoch 30/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.3060 - accuracy: 0.2560 - val_loss: 2.0761 - val_accuracy: 0.3467
# Epoch 31/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.2816 - accuracy: 0.2782 - val_loss: 2.0539 - val_accuracy: 0.3533
# Epoch 32/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.2685 - accuracy: 0.2804 - val_loss: 2.0311 - val_accuracy: 0.3867
# Epoch 33/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.2481 - accuracy: 0.2831 - val_loss: 2.0069 - val_accuracy: 0.3833
# Epoch 34/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.2350 - accuracy: 0.2876 - val_loss: 1.9938 - val_accuracy: 0.3767
# Epoch 35/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.2123 - accuracy: 0.3022 - val_loss: 1.9631 - val_accuracy: 0.3767
# Epoch 36/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.2013 - accuracy: 0.2991 - val_loss: 1.9518 - val_accuracy: 0.3800
# Epoch 37/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.1846 - accuracy: 0.3009 - val_loss: 1.9261 - val_accuracy: 0.3933
# Epoch 38/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.1823 - accuracy: 0.3071 - val_loss: 1.9093 - val_accuracy: 0.4333
# Epoch 39/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1663 - accuracy: 0.3111 - val_loss: 1.8921 - val_accuracy: 0.4100
# Epoch 40/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1378 - accuracy: 0.3271 - val_loss: 1.8712 - val_accuracy: 0.4333
# Epoch 41/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1247 - accuracy: 0.3351 - val_loss: 1.8576 - val_accuracy: 0.4300
# Epoch 42/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.1089 - accuracy: 0.3196 - val_loss: 1.8356 - val_accuracy: 0.4267
# Epoch 43/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.1051 - accuracy: 0.3231 - val_loss: 1.8257 - val_accuracy: 0.4433
# Epoch 44/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0941 - accuracy: 0.3369 - val_loss: 1.8279 - val_accuracy: 0.4267
# Epoch 45/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0831 - accuracy: 0.3347 - val_loss: 1.8046 - val_accuracy: 0.4433
# Epoch 46/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.0714 - accuracy: 0.3427 - val_loss: 1.7865 - val_accuracy: 0.4367
# Epoch 47/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0606 - accuracy: 0.3418 - val_loss: 1.7679 - val_accuracy: 0.4767
# Epoch 48/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.0489 - accuracy: 0.3476 - val_loss: 1.7748 - val_accuracy: 0.4333
# Epoch 49/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0258 - accuracy: 0.3564 - val_loss: 1.7720 - val_accuracy: 0.4400
# Epoch 50/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0244 - accuracy: 0.3542 - val_loss: 1.7456 - val_accuracy: 0.4567
# Epoch 51/400
# 71/71 [==============================] - 6s 80ms/step - loss: 2.0125 - accuracy: 0.3724 - val_loss: 1.7213 - val_accuracy: 0.4633
# Epoch 52/400
# 71/71 [==============================] - 6s 79ms/step - loss: 2.0185 - accuracy: 0.3769 - val_loss: 1.7391 - val_accuracy: 0.4567
# Epoch 53/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9941 - accuracy: 0.3640 - val_loss: 1.7007 - val_accuracy: 0.4900
# Epoch 54/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9823 - accuracy: 0.3747 - val_loss: 1.6876 - val_accuracy: 0.4667
# Epoch 55/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9942 - accuracy: 0.3698 - val_loss: 1.6903 - val_accuracy: 0.4633
# Epoch 56/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9659 - accuracy: 0.3853 - val_loss: 1.6798 - val_accuracy: 0.4800
# Epoch 57/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9561 - accuracy: 0.3818 - val_loss: 1.6701 - val_accuracy: 0.4867
# Epoch 58/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9580 - accuracy: 0.3871 - val_loss: 1.6689 - val_accuracy: 0.4633
# Epoch 59/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9365 - accuracy: 0.3751 - val_loss: 1.6527 - val_accuracy: 0.4800
# Epoch 60/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.9181 - accuracy: 0.4027 - val_loss: 1.6358 - val_accuracy: 0.4900
# Epoch 61/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.9147 - accuracy: 0.4049 - val_loss: 1.6276 - val_accuracy: 0.4800
# Epoch 62/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.9112 - accuracy: 0.4000 - val_loss: 1.6219 - val_accuracy: 0.5033
# Epoch 63/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.8842 - accuracy: 0.4084 - val_loss: 1.6115 - val_accuracy: 0.4900
# Epoch 64/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.8886 - accuracy: 0.4036 - val_loss: 1.6229 - val_accuracy: 0.4867
# Epoch 65/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.8594 - accuracy: 0.4147 - val_loss: 1.5971 - val_accuracy: 0.4900
# Epoch 66/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.8645 - accuracy: 0.4053 - val_loss: 1.5766 - val_accuracy: 0.5133
# Epoch 67/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.8558 - accuracy: 0.4169 - val_loss: 1.5701 - val_accuracy: 0.5233
# Epoch 68/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.8445 - accuracy: 0.4187 - val_loss: 1.5644 - val_accuracy: 0.5233
# Epoch 69/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.8420 - accuracy: 0.4240 - val_loss: 1.5559 - val_accuracy: 0.5300
# Epoch 70/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.8276 - accuracy: 0.4320 - val_loss: 1.5652 - val_accuracy: 0.5000
# Epoch 71/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.8072 - accuracy: 0.4391 - val_loss: 1.5444 - val_accuracy: 0.5433
# Epoch 72/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.8141 - accuracy: 0.4307 - val_loss: 1.5360 - val_accuracy: 0.5267
# Epoch 73/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.8033 - accuracy: 0.4356 - val_loss: 1.5233 - val_accuracy: 0.5133
# Epoch 74/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.7829 - accuracy: 0.4351 - val_loss: 1.5311 - val_accuracy: 0.5133
# Epoch 75/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.7763 - accuracy: 0.4436 - val_loss: 1.5133 - val_accuracy: 0.5067
# Epoch 76/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.7577 - accuracy: 0.4547 - val_loss: 1.5083 - val_accuracy: 0.5533
# Epoch 77/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.7548 - accuracy: 0.4658 - val_loss: 1.5083 - val_accuracy: 0.5233
# Epoch 78/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.7291 - accuracy: 0.4640 - val_loss: 1.4898 - val_accuracy: 0.5367
# Epoch 79/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.7416 - accuracy: 0.4520 - val_loss: 1.4922 - val_accuracy: 0.5267
# Epoch 80/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.7262 - accuracy: 0.4600 - val_loss: 1.4805 - val_accuracy: 0.5033
# Epoch 81/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.7251 - accuracy: 0.4587 - val_loss: 1.4725 - val_accuracy: 0.5467
# Epoch 82/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.6936 - accuracy: 0.4729 - val_loss: 1.4603 - val_accuracy: 0.5433
# Epoch 83/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.7097 - accuracy: 0.4711 - val_loss: 1.4640 - val_accuracy: 0.5500
# Epoch 84/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.6916 - accuracy: 0.4627 - val_loss: 1.4470 - val_accuracy: 0.5467
# Epoch 85/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.6707 - accuracy: 0.4853 - val_loss: 1.4597 - val_accuracy: 0.5300
# Epoch 86/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.6570 - accuracy: 0.4804 - val_loss: 1.4480 - val_accuracy: 0.5567
# Epoch 87/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.6500 - accuracy: 0.4911 - val_loss: 1.4421 - val_accuracy: 0.5400
# Epoch 88/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.6500 - accuracy: 0.4831 - val_loss: 1.4372 - val_accuracy: 0.5633
# Epoch 89/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.6370 - accuracy: 0.4831 - val_loss: 1.4392 - val_accuracy: 0.5433
# Epoch 90/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.6169 - accuracy: 0.5018 - val_loss: 1.4306 - val_accuracy: 0.5467
# Epoch 91/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.5977 - accuracy: 0.5102 - val_loss: 1.4065 - val_accuracy: 0.5567
# Epoch 92/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.6121 - accuracy: 0.4929 - val_loss: 1.4058 - val_accuracy: 0.5567
# Epoch 93/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.6046 - accuracy: 0.5058 - val_loss: 1.3978 - val_accuracy: 0.5367
# Epoch 94/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.5942 - accuracy: 0.4951 - val_loss: 1.3979 - val_accuracy: 0.5367
# Epoch 95/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.5694 - accuracy: 0.5138 - val_loss: 1.3960 - val_accuracy: 0.5600
# Epoch 96/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.5533 - accuracy: 0.5151 - val_loss: 1.3813 - val_accuracy: 0.5767
# Epoch 97/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.5735 - accuracy: 0.5040 - val_loss: 1.3789 - val_accuracy: 0.5667
# Epoch 98/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.5280 - accuracy: 0.5320 - val_loss: 1.4013 - val_accuracy: 0.5533
# Epoch 99/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.5305 - accuracy: 0.5347 - val_loss: 1.3650 - val_accuracy: 0.5533
# Epoch 100/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.5290 - accuracy: 0.5338 - val_loss: 1.3721 - val_accuracy: 0.5833
# Epoch 101/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.5270 - accuracy: 0.5262 - val_loss: 1.3588 - val_accuracy: 0.5667
# Epoch 102/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.5120 - accuracy: 0.5360 - val_loss: 1.3486 - val_accuracy: 0.5600
# Epoch 103/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.4855 - accuracy: 0.5311 - val_loss: 1.3591 - val_accuracy: 0.5667
# Epoch 104/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.4873 - accuracy: 0.5338 - val_loss: 1.3377 - val_accuracy: 0.5633
# Epoch 105/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.4833 - accuracy: 0.5511 - val_loss: 1.3537 - val_accuracy: 0.5600
# Epoch 106/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.4730 - accuracy: 0.5444 - val_loss: 1.3535 - val_accuracy: 0.5633
# Epoch 107/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.4483 - accuracy: 0.5462 - val_loss: 1.3395 - val_accuracy: 0.5833
# Epoch 108/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.4402 - accuracy: 0.5618 - val_loss: 1.3273 - val_accuracy: 0.5733
# Epoch 109/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.4272 - accuracy: 0.5587 - val_loss: 1.3342 - val_accuracy: 0.5833
# Epoch 110/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.4404 - accuracy: 0.5627 - val_loss: 1.3304 - val_accuracy: 0.5700
# Epoch 111/400
# 71/71 [==============================] - 6s 79ms/step - loss: 1.4349 - accuracy: 0.5498 - val_loss: 1.3458 - val_accuracy: 0.5700
# Epoch 112/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3961 - accuracy: 0.5693 - val_loss: 1.3078 - val_accuracy: 0.5800
# Epoch 113/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3925 - accuracy: 0.5773 - val_loss: 1.3189 - val_accuracy: 0.5833
# Epoch 114/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3861 - accuracy: 0.5698 - val_loss: 1.3108 - val_accuracy: 0.5867
# Epoch 115/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3828 - accuracy: 0.5791 - val_loss: 1.3115 - val_accuracy: 0.5867
# Epoch 116/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3587 - accuracy: 0.5747 - val_loss: 1.3151 - val_accuracy: 0.5800
# Epoch 117/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3644 - accuracy: 0.5764 - val_loss: 1.3013 - val_accuracy: 0.5967
# Epoch 118/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3573 - accuracy: 0.5818 - val_loss: 1.3021 - val_accuracy: 0.5800
# Epoch 119/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3402 - accuracy: 0.5849 - val_loss: 1.2832 - val_accuracy: 0.6100
# Epoch 120/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3390 - accuracy: 0.5844 - val_loss: 1.3081 - val_accuracy: 0.5700
# Epoch 121/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3183 - accuracy: 0.5884 - val_loss: 1.2764 - val_accuracy: 0.6000
# Epoch 122/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.2969 - accuracy: 0.6093 - val_loss: 1.2797 - val_accuracy: 0.5833
# Epoch 123/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.2776 - accuracy: 0.6027 - val_loss: 1.2772 - val_accuracy: 0.5767
# Epoch 124/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.2889 - accuracy: 0.5960 - val_loss: 1.2653 - val_accuracy: 0.6000
# Epoch 125/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.2698 - accuracy: 0.6160 - val_loss: 1.2877 - val_accuracy: 0.5567
# Epoch 126/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.2708 - accuracy: 0.6089 - val_loss: 1.2689 - val_accuracy: 0.5767
# Epoch 127/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.2519 - accuracy: 0.6124 - val_loss: 1.2731 - val_accuracy: 0.5833
# Epoch 128/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.2433 - accuracy: 0.6240 - val_loss: 1.2620 - val_accuracy: 0.6000
# Epoch 129/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.2356 - accuracy: 0.6200 - val_loss: 1.2477 - val_accuracy: 0.5933
# Epoch 130/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.2289 - accuracy: 0.6218 - val_loss: 1.2453 - val_accuracy: 0.6067
# Epoch 131/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.2446 - accuracy: 0.6138 - val_loss: 1.2452 - val_accuracy: 0.6100
# Epoch 132/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.1964 - accuracy: 0.6373 - val_loss: 1.2484 - val_accuracy: 0.5933
# Epoch 133/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.1985 - accuracy: 0.6418 - val_loss: 1.2494 - val_accuracy: 0.5967
# Epoch 134/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.1960 - accuracy: 0.6333 - val_loss: 1.2354 - val_accuracy: 0.6067
# Epoch 135/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.1758 - accuracy: 0.6364 - val_loss: 1.2509 - val_accuracy: 0.5900
# Epoch 136/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.1739 - accuracy: 0.6369 - val_loss: 1.2455 - val_accuracy: 0.5767
# Epoch 137/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.1660 - accuracy: 0.6640 - val_loss: 1.2162 - val_accuracy: 0.6167
# Epoch 138/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.1482 - accuracy: 0.6529 - val_loss: 1.2135 - val_accuracy: 0.6033
# Epoch 139/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.1164 - accuracy: 0.6631 - val_loss: 1.2383 - val_accuracy: 0.5933
# Epoch 140/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.1119 - accuracy: 0.6604 - val_loss: 1.2529 - val_accuracy: 0.5633
# Epoch 141/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.1124 - accuracy: 0.6649 - val_loss: 1.2110 - val_accuracy: 0.6100
# Epoch 142/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.1113 - accuracy: 0.6556 - val_loss: 1.2172 - val_accuracy: 0.5933
# Epoch 143/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.0958 - accuracy: 0.6556 - val_loss: 1.2112 - val_accuracy: 0.5867
# Epoch 144/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.0706 - accuracy: 0.6693 - val_loss: 1.1956 - val_accuracy: 0.6167
# Epoch 145/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.0557 - accuracy: 0.6747 - val_loss: 1.2057 - val_accuracy: 0.6200
# Epoch 146/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.0813 - accuracy: 0.6640 - val_loss: 1.2009 - val_accuracy: 0.6367
# Epoch 147/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.0699 - accuracy: 0.6680 - val_loss: 1.2050 - val_accuracy: 0.5933
# Epoch 148/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.0339 - accuracy: 0.6782 - val_loss: 1.2075 - val_accuracy: 0.6067
# Epoch 149/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.0225 - accuracy: 0.6907 - val_loss: 1.1857 - val_accuracy: 0.6133
# Epoch 150/400
# 71/71 [==============================] - 6s 80ms/step - loss: 1.0201 - accuracy: 0.6907 - val_loss: 1.1947 - val_accuracy: 0.6133
# Epoch 151/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.0239 - accuracy: 0.6893 - val_loss: 1.1756 - val_accuracy: 0.6267
# Epoch 152/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.9839 - accuracy: 0.7076 - val_loss: 1.1921 - val_accuracy: 0.5967
# Epoch 153/400
# 71/71 [==============================] - 6s 81ms/step - loss: 1.0163 - accuracy: 0.6880 - val_loss: 1.1763 - val_accuracy: 0.6200
# Epoch 154/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.9642 - accuracy: 0.6996 - val_loss: 1.1955 - val_accuracy: 0.6167
# Epoch 155/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.9667 - accuracy: 0.7062 - val_loss: 1.2266 - val_accuracy: 0.5867
# Epoch 156/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.9641 - accuracy: 0.7133 - val_loss: 1.1706 - val_accuracy: 0.6100
# Epoch 157/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.9437 - accuracy: 0.7102 - val_loss: 1.1737 - val_accuracy: 0.6233
# Epoch 158/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.9354 - accuracy: 0.7258 - val_loss: 1.2291 - val_accuracy: 0.5967
# Epoch 159/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.9383 - accuracy: 0.7102 - val_loss: 1.1762 - val_accuracy: 0.6333
# Epoch 160/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.9347 - accuracy: 0.7142 - val_loss: 1.1745 - val_accuracy: 0.6133
# Epoch 161/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.9173 - accuracy: 0.7240 - val_loss: 1.1783 - val_accuracy: 0.6300
# Epoch 162/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.9245 - accuracy: 0.7093 - val_loss: 1.1644 - val_accuracy: 0.6200
# Epoch 163/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.8844 - accuracy: 0.7422 - val_loss: 1.1844 - val_accuracy: 0.5900
# Epoch 164/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.8791 - accuracy: 0.7342 - val_loss: 1.1761 - val_accuracy: 0.6033
# Epoch 165/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.8756 - accuracy: 0.7436 - val_loss: 1.1549 - val_accuracy: 0.6233
# Epoch 166/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.8521 - accuracy: 0.7467 - val_loss: 1.1515 - val_accuracy: 0.6367
# Epoch 167/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.8637 - accuracy: 0.7302 - val_loss: 1.1570 - val_accuracy: 0.6300
# Epoch 168/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.8503 - accuracy: 0.7356 - val_loss: 1.1554 - val_accuracy: 0.6133
# Epoch 169/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.8470 - accuracy: 0.7476 - val_loss: 1.1494 - val_accuracy: 0.6267
# Epoch 170/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.8405 - accuracy: 0.7387 - val_loss: 1.1367 - val_accuracy: 0.6267
# Epoch 171/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.8343 - accuracy: 0.7444 - val_loss: 1.1360 - val_accuracy: 0.6433
# Epoch 172/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.8161 - accuracy: 0.7529 - val_loss: 1.1540 - val_accuracy: 0.6333
# Epoch 173/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.7946 - accuracy: 0.7600 - val_loss: 1.1396 - val_accuracy: 0.6400
# Epoch 174/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.7988 - accuracy: 0.7511 - val_loss: 1.1560 - val_accuracy: 0.6233
# Epoch 175/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.7885 - accuracy: 0.7596 - val_loss: 1.1517 - val_accuracy: 0.6067
# Epoch 176/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.7681 - accuracy: 0.7742 - val_loss: 1.1517 - val_accuracy: 0.6167
# Epoch 177/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.8057 - accuracy: 0.7560 - val_loss: 1.1599 - val_accuracy: 0.6433
# Epoch 178/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.7679 - accuracy: 0.7702 - val_loss: 1.1263 - val_accuracy: 0.6300
# Epoch 179/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.7520 - accuracy: 0.7689 - val_loss: 1.1650 - val_accuracy: 0.6200
# Epoch 180/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.7451 - accuracy: 0.7764 - val_loss: 1.1405 - val_accuracy: 0.6367
# Epoch 181/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.7337 - accuracy: 0.7720 - val_loss: 1.1433 - val_accuracy: 0.6433
# Epoch 182/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.7280 - accuracy: 0.7898 - val_loss: 1.1406 - val_accuracy: 0.6400
# Epoch 183/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.7177 - accuracy: 0.7836 - val_loss: 1.1463 - val_accuracy: 0.6467
# Epoch 184/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.7033 - accuracy: 0.7867 - val_loss: 1.1742 - val_accuracy: 0.6300
# Epoch 185/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.7088 - accuracy: 0.7827 - val_loss: 1.1375 - val_accuracy: 0.6467
# Epoch 186/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.7073 - accuracy: 0.7876 - val_loss: 1.1245 - val_accuracy: 0.6433
# Epoch 187/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.6842 - accuracy: 0.7987 - val_loss: 1.1320 - val_accuracy: 0.6233
# Epoch 188/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.6901 - accuracy: 0.7924 - val_loss: 1.1216 - val_accuracy: 0.6433
# Epoch 189/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.6964 - accuracy: 0.7876 - val_loss: 1.1215 - val_accuracy: 0.6433
# Epoch 190/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.6622 - accuracy: 0.8031 - val_loss: 1.1754 - val_accuracy: 0.6233
# Epoch 191/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.6354 - accuracy: 0.8129 - val_loss: 1.1427 - val_accuracy: 0.6367
# Epoch 192/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.6525 - accuracy: 0.7978 - val_loss: 1.1142 - val_accuracy: 0.6467
# Epoch 193/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.6433 - accuracy: 0.8044 - val_loss: 1.1637 - val_accuracy: 0.6333
# Epoch 194/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.6278 - accuracy: 0.8102 - val_loss: 1.1287 - val_accuracy: 0.6400
# Epoch 195/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.6201 - accuracy: 0.8147 - val_loss: 1.1517 - val_accuracy: 0.6400
# Epoch 196/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.6338 - accuracy: 0.8089 - val_loss: 1.1377 - val_accuracy: 0.6300
# Epoch 197/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.6032 - accuracy: 0.8164 - val_loss: 1.1430 - val_accuracy: 0.6367
# Epoch 198/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.6081 - accuracy: 0.8124 - val_loss: 1.1447 - val_accuracy: 0.6500
# Epoch 199/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.6164 - accuracy: 0.8058 - val_loss: 1.1460 - val_accuracy: 0.6500
# Epoch 200/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.5830 - accuracy: 0.8227 - val_loss: 1.1169 - val_accuracy: 0.6367
# Epoch 201/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.5809 - accuracy: 0.8200 - val_loss: 1.1311 - val_accuracy: 0.6467
# Epoch 202/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.5587 - accuracy: 0.8338 - val_loss: 1.1382 - val_accuracy: 0.6400
# Epoch 203/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.5589 - accuracy: 0.8302 - val_loss: 1.1396 - val_accuracy: 0.6500
# Epoch 204/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.5513 - accuracy: 0.8373 - val_loss: 1.1571 - val_accuracy: 0.6300
# Epoch 205/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.5469 - accuracy: 0.8320 - val_loss: 1.1400 - val_accuracy: 0.6400
# Epoch 206/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.5457 - accuracy: 0.8413 - val_loss: 1.1664 - val_accuracy: 0.6400
# Epoch 207/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.5281 - accuracy: 0.8453 - val_loss: 1.1438 - val_accuracy: 0.6667
# Epoch 208/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.5395 - accuracy: 0.8351 - val_loss: 1.1606 - val_accuracy: 0.6533
# Epoch 209/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.5116 - accuracy: 0.8462 - val_loss: 1.1621 - val_accuracy: 0.6400
# Epoch 210/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.4909 - accuracy: 0.8569 - val_loss: 1.1800 - val_accuracy: 0.6567
# Epoch 211/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.5039 - accuracy: 0.8476 - val_loss: 1.1713 - val_accuracy: 0.6500
# Epoch 212/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.5090 - accuracy: 0.8396 - val_loss: 1.1340 - val_accuracy: 0.6600
# Epoch 213/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.4928 - accuracy: 0.8467 - val_loss: 1.1161 - val_accuracy: 0.6300
# Epoch 214/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.4717 - accuracy: 0.8591 - val_loss: 1.1512 - val_accuracy: 0.6367
# Epoch 215/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.4822 - accuracy: 0.8476 - val_loss: 1.1812 - val_accuracy: 0.6333
# Epoch 216/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.4603 - accuracy: 0.8667 - val_loss: 1.1545 - val_accuracy: 0.6433
# Epoch 217/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.4781 - accuracy: 0.8578 - val_loss: 1.1751 - val_accuracy: 0.6367
# Epoch 218/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.4495 - accuracy: 0.8644 - val_loss: 1.1475 - val_accuracy: 0.6333
# Epoch 219/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.4545 - accuracy: 0.8622 - val_loss: 1.1542 - val_accuracy: 0.6533
# Epoch 220/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.4434 - accuracy: 0.8667 - val_loss: 1.1910 - val_accuracy: 0.6667
# Epoch 221/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.4468 - accuracy: 0.8649 - val_loss: 1.1680 - val_accuracy: 0.6400
# Epoch 222/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.4309 - accuracy: 0.8729 - val_loss: 1.1814 - val_accuracy: 0.6300
# Epoch 223/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.4324 - accuracy: 0.8733 - val_loss: 1.1766 - val_accuracy: 0.6400
# Epoch 224/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.4120 - accuracy: 0.8720 - val_loss: 1.1713 - val_accuracy: 0.6433
# Epoch 225/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.4073 - accuracy: 0.8818 - val_loss: 1.1642 - val_accuracy: 0.6367
# Epoch 226/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.4273 - accuracy: 0.8760 - val_loss: 1.1673 - val_accuracy: 0.6600
# Epoch 227/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.4104 - accuracy: 0.8756 - val_loss: 1.1764 - val_accuracy: 0.6567
# Epoch 228/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.3781 - accuracy: 0.8907 - val_loss: 1.1632 - val_accuracy: 0.6400
# Epoch 229/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3856 - accuracy: 0.8871 - val_loss: 1.1839 - val_accuracy: 0.6400
# Epoch 230/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.4006 - accuracy: 0.8831 - val_loss: 1.1744 - val_accuracy: 0.6700
# Epoch 231/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.3820 - accuracy: 0.8813 - val_loss: 1.2208 - val_accuracy: 0.6600
# Epoch 232/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3688 - accuracy: 0.8836 - val_loss: 1.1696 - val_accuracy: 0.6300
# Epoch 233/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3646 - accuracy: 0.8951 - val_loss: 1.1797 - val_accuracy: 0.6367
# Epoch 234/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3691 - accuracy: 0.8924 - val_loss: 1.1757 - val_accuracy: 0.6467
# Epoch 235/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3692 - accuracy: 0.8840 - val_loss: 1.1845 - val_accuracy: 0.6567
# Epoch 236/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3790 - accuracy: 0.8822 - val_loss: 1.2015 - val_accuracy: 0.6500
# Epoch 237/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3543 - accuracy: 0.8978 - val_loss: 1.1789 - val_accuracy: 0.6500
# Epoch 238/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3491 - accuracy: 0.8929 - val_loss: 1.1947 - val_accuracy: 0.6533
# Epoch 239/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3420 - accuracy: 0.8929 - val_loss: 1.1744 - val_accuracy: 0.6500
# Epoch 240/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3372 - accuracy: 0.9004 - val_loss: 1.1835 - val_accuracy: 0.6567
# Epoch 241/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3332 - accuracy: 0.9000 - val_loss: 1.1832 - val_accuracy: 0.6700
# Epoch 242/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3212 - accuracy: 0.9022 - val_loss: 1.1809 - val_accuracy: 0.6533
# Epoch 243/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.3228 - accuracy: 0.9044 - val_loss: 1.1930 - val_accuracy: 0.6433
# Epoch 244/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.3098 - accuracy: 0.9076 - val_loss: 1.2175 - val_accuracy: 0.6367
# Epoch 245/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3181 - accuracy: 0.9076 - val_loss: 1.1971 - val_accuracy: 0.6567
# Epoch 246/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.3033 - accuracy: 0.9004 - val_loss: 1.2207 - val_accuracy: 0.6567
# Epoch 247/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3116 - accuracy: 0.9080 - val_loss: 1.2355 - val_accuracy: 0.6767
# Epoch 248/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.3098 - accuracy: 0.9120 - val_loss: 1.1892 - val_accuracy: 0.6500
# Epoch 249/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.3010 - accuracy: 0.9080 - val_loss: 1.2272 - val_accuracy: 0.6567
# Epoch 250/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2953 - accuracy: 0.9196 - val_loss: 1.2295 - val_accuracy: 0.6667
# Epoch 251/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2851 - accuracy: 0.9164 - val_loss: 1.2390 - val_accuracy: 0.6533
# Epoch 252/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2725 - accuracy: 0.9262 - val_loss: 1.2319 - val_accuracy: 0.6533
# Epoch 253/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2955 - accuracy: 0.9080 - val_loss: 1.2288 - val_accuracy: 0.6733
# Epoch 254/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2766 - accuracy: 0.9129 - val_loss: 1.2231 - val_accuracy: 0.6567
# Epoch 255/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2476 - accuracy: 0.9324 - val_loss: 1.2601 - val_accuracy: 0.6633
# Epoch 256/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2562 - accuracy: 0.9267 - val_loss: 1.2552 - val_accuracy: 0.6700
# Epoch 257/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2750 - accuracy: 0.9200 - val_loss: 1.2327 - val_accuracy: 0.6700
# Epoch 258/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2554 - accuracy: 0.9236 - val_loss: 1.2931 - val_accuracy: 0.6533
# Epoch 259/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2614 - accuracy: 0.9191 - val_loss: 1.2760 - val_accuracy: 0.6500
# Epoch 260/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2572 - accuracy: 0.9204 - val_loss: 1.2448 - val_accuracy: 0.6567
# Epoch 261/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2528 - accuracy: 0.9218 - val_loss: 1.2583 - val_accuracy: 0.6667
# Epoch 262/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2522 - accuracy: 0.9271 - val_loss: 1.2639 - val_accuracy: 0.6600
# Epoch 263/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2316 - accuracy: 0.9333 - val_loss: 1.2773 - val_accuracy: 0.6533
# Epoch 264/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2608 - accuracy: 0.9236 - val_loss: 1.2671 - val_accuracy: 0.6533
# Epoch 265/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.2327 - accuracy: 0.9324 - val_loss: 1.2851 - val_accuracy: 0.6600
# Epoch 266/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2250 - accuracy: 0.9404 - val_loss: 1.2702 - val_accuracy: 0.6667
# Epoch 267/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2175 - accuracy: 0.9364 - val_loss: 1.2789 - val_accuracy: 0.6600
# Epoch 268/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.2209 - accuracy: 0.9356 - val_loss: 1.2735 - val_accuracy: 0.6567
# Epoch 269/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2105 - accuracy: 0.9449 - val_loss: 1.2385 - val_accuracy: 0.6567
# Epoch 270/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2230 - accuracy: 0.9351 - val_loss: 1.2694 - val_accuracy: 0.6667
# Epoch 271/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2287 - accuracy: 0.9320 - val_loss: 1.2876 - val_accuracy: 0.6400
# Epoch 272/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2177 - accuracy: 0.9347 - val_loss: 1.2814 - val_accuracy: 0.6600
# Epoch 273/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2051 - accuracy: 0.9409 - val_loss: 1.3311 - val_accuracy: 0.6467
# Epoch 274/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2094 - accuracy: 0.9369 - val_loss: 1.3043 - val_accuracy: 0.6633
# Epoch 275/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2154 - accuracy: 0.9360 - val_loss: 1.2579 - val_accuracy: 0.6567
# Epoch 276/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2146 - accuracy: 0.9360 - val_loss: 1.3067 - val_accuracy: 0.6600
# Epoch 277/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1994 - accuracy: 0.9440 - val_loss: 1.3309 - val_accuracy: 0.6567
# Epoch 278/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.1985 - accuracy: 0.9431 - val_loss: 1.3095 - val_accuracy: 0.6467
# Epoch 279/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.2082 - accuracy: 0.9387 - val_loss: 1.2950 - val_accuracy: 0.6600
# Epoch 280/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.2225 - accuracy: 0.9360 - val_loss: 1.3052 - val_accuracy: 0.6667
# Epoch 281/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.1873 - accuracy: 0.9484 - val_loss: 1.3570 - val_accuracy: 0.6567
# Epoch 282/400
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1806 - accuracy: 0.9462 - val_loss: 1.3187 - val_accuracy: 0.6567
# Epoch 283/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1884 - accuracy: 0.9453 - val_loss: 1.3149 - val_accuracy: 0.6567
# Epoch 284/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1756 - accuracy: 0.9453 - val_loss: 1.3101 - val_accuracy: 0.6633
# Epoch 285/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.1785 - accuracy: 0.9493 - val_loss: 1.3070 - val_accuracy: 0.6600
# Epoch 286/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1797 - accuracy: 0.9484 - val_loss: 1.3026 - val_accuracy: 0.6633
# Epoch 287/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.1632 - accuracy: 0.9547 - val_loss: 1.2728 - val_accuracy: 0.6667
# Epoch 288/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1670 - accuracy: 0.9578 - val_loss: 1.3393 - val_accuracy: 0.6567
# Epoch 289/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1707 - accuracy: 0.9498 - val_loss: 1.3229 - val_accuracy: 0.6767
# Epoch 290/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1725 - accuracy: 0.9538 - val_loss: 1.3229 - val_accuracy: 0.6533
# Epoch 291/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.1735 - accuracy: 0.9511 - val_loss: 1.3457 - val_accuracy: 0.6800
# Epoch 292/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1779 - accuracy: 0.9471 - val_loss: 1.3281 - val_accuracy: 0.6633
# Epoch 293/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1477 - accuracy: 0.9618 - val_loss: 1.3556 - val_accuracy: 0.6500
# Epoch 294/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1525 - accuracy: 0.9551 - val_loss: 1.3203 - val_accuracy: 0.6600
# Epoch 295/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1552 - accuracy: 0.9516 - val_loss: 1.3466 - val_accuracy: 0.6567
# Epoch 296/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1679 - accuracy: 0.9533 - val_loss: 1.3421 - val_accuracy: 0.6633
# Epoch 297/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1652 - accuracy: 0.9516 - val_loss: 1.3193 - val_accuracy: 0.6733
# Epoch 298/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1555 - accuracy: 0.9587 - val_loss: 1.3323 - val_accuracy: 0.6600
# Epoch 299/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1542 - accuracy: 0.9551 - val_loss: 1.3532 - val_accuracy: 0.6533
# Epoch 300/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1490 - accuracy: 0.9596 - val_loss: 1.3299 - val_accuracy: 0.6767
# Epoch 301/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1401 - accuracy: 0.9636 - val_loss: 1.3670 - val_accuracy: 0.6633
# Epoch 302/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.1360 - accuracy: 0.9644 - val_loss: 1.3556 - val_accuracy: 0.6533
# Epoch 303/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1416 - accuracy: 0.9600 - val_loss: 1.3465 - val_accuracy: 0.6867
# Epoch 304/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1384 - accuracy: 0.9582 - val_loss: 1.3683 - val_accuracy: 0.6733
# Epoch 305/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.1188 - accuracy: 0.9702 - val_loss: 1.3737 - val_accuracy: 0.6700
# Epoch 306/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1285 - accuracy: 0.9644 - val_loss: 1.3729 - val_accuracy: 0.6800
# Epoch 307/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1358 - accuracy: 0.9658 - val_loss: 1.3941 - val_accuracy: 0.6567
# Epoch 308/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1309 - accuracy: 0.9644 - val_loss: 1.4396 - val_accuracy: 0.6733
# Epoch 309/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1404 - accuracy: 0.9613 - val_loss: 1.3984 - val_accuracy: 0.6767
# Epoch 310/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1499 - accuracy: 0.9560 - val_loss: 1.4231 - val_accuracy: 0.6667
# Epoch 311/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1333 - accuracy: 0.9604 - val_loss: 1.3865 - val_accuracy: 0.6800
# Epoch 312/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1089 - accuracy: 0.9716 - val_loss: 1.3496 - val_accuracy: 0.6633
# Epoch 313/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1221 - accuracy: 0.9622 - val_loss: 1.3927 - val_accuracy: 0.6800
# Epoch 314/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1192 - accuracy: 0.9684 - val_loss: 1.3314 - val_accuracy: 0.6700
# Epoch 315/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1296 - accuracy: 0.9631 - val_loss: 1.3497 - val_accuracy: 0.6600
# Epoch 316/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1350 - accuracy: 0.9649 - val_loss: 1.4531 - val_accuracy: 0.6600
# Epoch 317/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1117 - accuracy: 0.9702 - val_loss: 1.4459 - val_accuracy: 0.6633
# Epoch 318/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1237 - accuracy: 0.9649 - val_loss: 1.3713 - val_accuracy: 0.6600
# Epoch 319/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1086 - accuracy: 0.9684 - val_loss: 1.3678 - val_accuracy: 0.6567
# Epoch 320/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1192 - accuracy: 0.9707 - val_loss: 1.3863 - val_accuracy: 0.6633
# Epoch 321/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1129 - accuracy: 0.9707 - val_loss: 1.4341 - val_accuracy: 0.6633
# Epoch 322/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1092 - accuracy: 0.9698 - val_loss: 1.3905 - val_accuracy: 0.6567
# Epoch 323/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1000 - accuracy: 0.9742 - val_loss: 1.4503 - val_accuracy: 0.6733
# Epoch 324/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1036 - accuracy: 0.9711 - val_loss: 1.4847 - val_accuracy: 0.6533
# Epoch 325/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1019 - accuracy: 0.9764 - val_loss: 1.4402 - val_accuracy: 0.6767
# Epoch 326/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.1035 - accuracy: 0.9707 - val_loss: 1.3998 - val_accuracy: 0.6633
# Epoch 327/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0978 - accuracy: 0.9751 - val_loss: 1.4733 - val_accuracy: 0.6733
# Epoch 328/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0917 - accuracy: 0.9764 - val_loss: 1.4824 - val_accuracy: 0.6633
# Epoch 329/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0903 - accuracy: 0.9778 - val_loss: 1.4661 - val_accuracy: 0.6633
# Epoch 330/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1069 - accuracy: 0.9720 - val_loss: 1.5197 - val_accuracy: 0.6500
# Epoch 331/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1177 - accuracy: 0.9644 - val_loss: 1.4161 - val_accuracy: 0.6767
# Epoch 332/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.1013 - accuracy: 0.9720 - val_loss: 1.4558 - val_accuracy: 0.6600
# Epoch 333/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0873 - accuracy: 0.9804 - val_loss: 1.4659 - val_accuracy: 0.6633
# Epoch 334/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0860 - accuracy: 0.9751 - val_loss: 1.4309 - val_accuracy: 0.6600
# Epoch 335/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0915 - accuracy: 0.9738 - val_loss: 1.4440 - val_accuracy: 0.6567
# Epoch 336/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0832 - accuracy: 0.9800 - val_loss: 1.5320 - val_accuracy: 0.6633
# Epoch 337/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0970 - accuracy: 0.9751 - val_loss: 1.4766 - val_accuracy: 0.6600
# Epoch 338/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0937 - accuracy: 0.9733 - val_loss: 1.4992 - val_accuracy: 0.6800
# Epoch 339/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0950 - accuracy: 0.9742 - val_loss: 1.4267 - val_accuracy: 0.6700
# Epoch 340/400
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0963 - accuracy: 0.9751 - val_loss: 1.5109 - val_accuracy: 0.6767
# Epoch 341/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0852 - accuracy: 0.9764 - val_loss: 1.4323 - val_accuracy: 0.6633
# Epoch 342/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0790 - accuracy: 0.9782 - val_loss: 1.4792 - val_accuracy: 0.6700
# Epoch 343/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0857 - accuracy: 0.9764 - val_loss: 1.4364 - val_accuracy: 0.6667
# Epoch 344/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0899 - accuracy: 0.9751 - val_loss: 1.4616 - val_accuracy: 0.6700
# Epoch 345/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.1011 - accuracy: 0.9733 - val_loss: 1.4507 - val_accuracy: 0.6600
# Epoch 346/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0764 - accuracy: 0.9800 - val_loss: 1.4909 - val_accuracy: 0.6533
# Epoch 347/400
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0956 - accuracy: 0.9764 - val_loss: 1.4641 - val_accuracy: 0.6700
# Epoch 348/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0893 - accuracy: 0.9747 - val_loss: 1.4645 - val_accuracy: 0.6667
# Epoch 349/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0846 - accuracy: 0.9751 - val_loss: 1.4714 - val_accuracy: 0.6833
# Epoch 350/400
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0826 - accuracy: 0.9773 - val_loss: 1.5556 - val_accuracy: 0.6633
# Epoch 351/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0727 - accuracy: 0.9804 - val_loss: 1.5691 - val_accuracy: 0.6600
# Epoch 352/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0738 - accuracy: 0.9809 - val_loss: 1.5355 - val_accuracy: 0.6700
# Epoch 353/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0817 - accuracy: 0.9760 - val_loss: 1.5686 - val_accuracy: 0.6633
# Epoch 354/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0820 - accuracy: 0.9773 - val_loss: 1.5573 - val_accuracy: 0.6867
# Epoch 355/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0806 - accuracy: 0.9800 - val_loss: 1.5472 - val_accuracy: 0.6767
# Epoch 356/400
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0787 - accuracy: 0.9796 - val_loss: 1.5775 - val_accuracy: 0.6500
# Epoch 357/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0742 - accuracy: 0.9804 - val_loss: 1.5585 - val_accuracy: 0.6733
# Epoch 358/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0890 - accuracy: 0.9778 - val_loss: 1.5560 - val_accuracy: 0.6633
# Epoch 359/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0720 - accuracy: 0.9782 - val_loss: 1.4969 - val_accuracy: 0.6667
# Epoch 360/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0768 - accuracy: 0.9782 - val_loss: 1.4690 - val_accuracy: 0.6767
# Epoch 361/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0712 - accuracy: 0.9853 - val_loss: 1.5223 - val_accuracy: 0.6800
# Epoch 362/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0724 - accuracy: 0.9827 - val_loss: 1.5109 - val_accuracy: 0.6600
# Epoch 363/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0656 - accuracy: 0.9827 - val_loss: 1.5486 - val_accuracy: 0.6567
# Epoch 364/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0667 - accuracy: 0.9818 - val_loss: 1.5940 - val_accuracy: 0.6667
# Epoch 365/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0734 - accuracy: 0.9773 - val_loss: 1.5001 - val_accuracy: 0.6667
# Epoch 366/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0658 - accuracy: 0.9809 - val_loss: 1.5499 - val_accuracy: 0.6633
# Epoch 367/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0654 - accuracy: 0.9804 - val_loss: 1.5947 - val_accuracy: 0.6667
# Epoch 368/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0637 - accuracy: 0.9827 - val_loss: 1.6043 - val_accuracy: 0.6667
# Epoch 369/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0659 - accuracy: 0.9822 - val_loss: 1.5934 - val_accuracy: 0.6567
# Epoch 370/400
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0615 - accuracy: 0.9827 - val_loss: 1.5166 - val_accuracy: 0.6600
# Epoch 371/400
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0570 - accuracy: 0.9853 - val_loss: 1.5476 - val_accuracy: 0.6600
# Epoch 372/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0553 - accuracy: 0.9876 - val_loss: 1.5713 - val_accuracy: 0.6667
# Epoch 373/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0780 - accuracy: 0.9742 - val_loss: 1.5275 - val_accuracy: 0.6600
# Epoch 374/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0631 - accuracy: 0.9818 - val_loss: 1.6652 - val_accuracy: 0.6700
# Epoch 375/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0619 - accuracy: 0.9836 - val_loss: 1.6467 - val_accuracy: 0.6567
# Epoch 376/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0721 - accuracy: 0.9836 - val_loss: 1.5962 - val_accuracy: 0.6733
# Epoch 377/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0660 - accuracy: 0.9809 - val_loss: 1.5804 - val_accuracy: 0.6700
# Epoch 378/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0664 - accuracy: 0.9813 - val_loss: 1.5398 - val_accuracy: 0.6667
# Epoch 379/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0684 - accuracy: 0.9822 - val_loss: 1.5367 - val_accuracy: 0.6567
# Epoch 380/400
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0695 - accuracy: 0.9813 - val_loss: 1.6297 - val_accuracy: 0.6767
# Epoch 381/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0701 - accuracy: 0.9809 - val_loss: 1.4935 - val_accuracy: 0.6667
# Epoch 382/400
# 71/71 [==============================] - 6s 84ms/step - loss: 0.0588 - accuracy: 0.9849 - val_loss: 1.5643 - val_accuracy: 0.6667
# Epoch 383/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0436 - accuracy: 0.9916 - val_loss: 1.5837 - val_accuracy: 0.6633
# Epoch 384/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0529 - accuracy: 0.9871 - val_loss: 1.5126 - val_accuracy: 0.6767
# Epoch 385/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0539 - accuracy: 0.9831 - val_loss: 1.5890 - val_accuracy: 0.6533
# Epoch 386/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0549 - accuracy: 0.9867 - val_loss: 1.6850 - val_accuracy: 0.6567
# Epoch 387/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0536 - accuracy: 0.9858 - val_loss: 1.6295 - val_accuracy: 0.6700
# Epoch 388/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0554 - accuracy: 0.9844 - val_loss: 1.5798 - val_accuracy: 0.6833
# Epoch 389/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0548 - accuracy: 0.9831 - val_loss: 1.5652 - val_accuracy: 0.6667
# Epoch 390/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0521 - accuracy: 0.9849 - val_loss: 1.6942 - val_accuracy: 0.6467
# Epoch 391/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0561 - accuracy: 0.9862 - val_loss: 1.6240 - val_accuracy: 0.6467
# Epoch 392/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0488 - accuracy: 0.9849 - val_loss: 1.5964 - val_accuracy: 0.6533
# Epoch 393/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0576 - accuracy: 0.9840 - val_loss: 1.5752 - val_accuracy: 0.6667
# Epoch 394/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0481 - accuracy: 0.9907 - val_loss: 1.6901 - val_accuracy: 0.6533
# Epoch 395/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0519 - accuracy: 0.9836 - val_loss: 1.5984 - val_accuracy: 0.6600
# Epoch 396/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0562 - accuracy: 0.9827 - val_loss: 1.5898 - val_accuracy: 0.6733
# Epoch 397/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0566 - accuracy: 0.9831 - val_loss: 1.6076 - val_accuracy: 0.6667
# Epoch 398/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0455 - accuracy: 0.9867 - val_loss: 1.5812 - val_accuracy: 0.6700
# Epoch 399/400
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0450 - accuracy: 0.9876 - val_loss: 1.6946 - val_accuracy: 0.6633
# Epoch 400/400
# 71/71 [==============================] - 6s 83ms/step - loss: 0.0613 - accuracy: 0.9844 - val_loss: 1.6548 - val_accuracy: 0.6500

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.70      0.70      0.70        20
#             Garuda       0.70      0.80      0.74        20
#      Goddess_Durga       0.71      0.85      0.77        20
#    Goddess_Lakshmi       0.50      0.60      0.55        20
# Goddess_Saraswathi       0.73      0.40      0.52        20
#        Lord_Ganesh       0.60      0.30      0.40        20
#       Lord_Hanuman       0.40      0.30      0.34        20
#     Lord_Hayagriva       0.61      0.55      0.58        20
#         Lord_Indra       0.69      1.00      0.82        20
#       Lord_Krishna       0.76      0.65      0.70        20
#        Lord_Muruga       0.46      0.55      0.50        20
#              Nandi       0.84      0.80      0.82        20
#            Nataraj       0.83      1.00      0.91        20
#    Shirdi_Sai_Baba       0.52      0.55      0.54        20
#           Shivling       0.67      0.70      0.68        20
#
#           accuracy                           0.65       300
#          macro avg       0.65      0.65      0.64       300
#       weighted avg       0.65      0.65      0.64       300
#
#
# Accuracy = 65.0%

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-6) and 400 iterations, the highest accuracy obtained is 68%(approx) at (290, 360).**
