# %% [markdown]
# ## **CNN Draft 2**
# #### **lr=1*10^(-4), epochs=40, Accuracy = 67% (approx) at (30, 35) epochs range**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find suitable learning rate and epoch value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                data.append([resized_arr, class_num])
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4178473880395141792
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11321147392
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17904365527429292896
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 40
l_rate = 0.0001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 3000)              1731000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 1,915,439
# Trainable params: 1,915,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/40
# 71/71 [==============================] - 10s 90ms/step - loss: 2.7102 - accuracy: 0.0596 - val_loss: 2.7055 - val_accuracy: 0.0800
# Epoch 2/40
# 71/71 [==============================] - 5s 77ms/step - loss: 2.7015 - accuracy: 0.0907 - val_loss: 2.6702 - val_accuracy: 0.1333
# Epoch 3/40
# 71/71 [==============================] - 5s 77ms/step - loss: 2.6203 - accuracy: 0.1471 - val_loss: 2.3976 - val_accuracy: 0.3000
# Epoch 4/40
# 71/71 [==============================] - 5s 78ms/step - loss: 2.4324 - accuracy: 0.2164 - val_loss: 2.1302 - val_accuracy: 0.3400
# Epoch 5/40
# 71/71 [==============================] - 6s 78ms/step - loss: 2.3188 - accuracy: 0.2524 - val_loss: 2.0011 - val_accuracy: 0.3433
# Epoch 6/40
# 71/71 [==============================] - 6s 78ms/step - loss: 2.2038 - accuracy: 0.3009 - val_loss: 1.8198 - val_accuracy: 0.4133
# Epoch 7/40
# 71/71 [==============================] - 6s 79ms/step - loss: 2.1014 - accuracy: 0.3444 - val_loss: 1.7257 - val_accuracy: 0.4433
# Epoch 8/40
# 71/71 [==============================] - 6s 78ms/step - loss: 2.0017 - accuracy: 0.3693 - val_loss: 1.5952 - val_accuracy: 0.5000
# Epoch 9/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.9311 - accuracy: 0.3902 - val_loss: 1.6410 - val_accuracy: 0.5033
# Epoch 10/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.8169 - accuracy: 0.4364 - val_loss: 1.4851 - val_accuracy: 0.5300
# Epoch 11/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.7460 - accuracy: 0.4529 - val_loss: 1.4679 - val_accuracy: 0.5500
# Epoch 12/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.6545 - accuracy: 0.4924 - val_loss: 1.3702 - val_accuracy: 0.5567
# Epoch 13/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.5402 - accuracy: 0.5151 - val_loss: 1.3470 - val_accuracy: 0.5700
# Epoch 14/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.4536 - accuracy: 0.5480 - val_loss: 1.3487 - val_accuracy: 0.6000
# Epoch 15/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.3346 - accuracy: 0.5858 - val_loss: 1.2812 - val_accuracy: 0.5833
# Epoch 16/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.2341 - accuracy: 0.6200 - val_loss: 1.2991 - val_accuracy: 0.5833
# Epoch 17/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.1252 - accuracy: 0.6431 - val_loss: 1.2503 - val_accuracy: 0.5867
# Epoch 18/40
# 71/71 [==============================] - 6s 78ms/step - loss: 1.0510 - accuracy: 0.6729 - val_loss: 1.2542 - val_accuracy: 0.5967
# Epoch 19/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.8999 - accuracy: 0.7164 - val_loss: 1.2319 - val_accuracy: 0.5967
# Epoch 20/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.8061 - accuracy: 0.7449 - val_loss: 1.1979 - val_accuracy: 0.6367
# Epoch 21/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.7054 - accuracy: 0.7738 - val_loss: 1.2417 - val_accuracy: 0.6333
# Epoch 22/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.6337 - accuracy: 0.8013 - val_loss: 1.2560 - val_accuracy: 0.6367
# Epoch 23/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.5540 - accuracy: 0.8227 - val_loss: 1.2754 - val_accuracy: 0.6400
# Epoch 24/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.4685 - accuracy: 0.8600 - val_loss: 1.3610 - val_accuracy: 0.6600
# Epoch 25/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.3674 - accuracy: 0.8898 - val_loss: 1.3904 - val_accuracy: 0.6500
# Epoch 26/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.3307 - accuracy: 0.8938 - val_loss: 1.3673 - val_accuracy: 0.6667
# Epoch 27/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.3049 - accuracy: 0.9133 - val_loss: 1.4091 - val_accuracy: 0.6667
# Epoch 28/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.2459 - accuracy: 0.9271 - val_loss: 1.4798 - val_accuracy: 0.6567
# Epoch 29/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.2132 - accuracy: 0.9373 - val_loss: 1.4793 - val_accuracy: 0.6667
# Epoch 30/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2221 - accuracy: 0.9333 - val_loss: 1.5539 - val_accuracy: 0.6600
# Epoch 31/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.1618 - accuracy: 0.9560 - val_loss: 1.6033 - val_accuracy: 0.6633
# Epoch 32/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1498 - accuracy: 0.9591 - val_loss: 1.6279 - val_accuracy: 0.6600
# Epoch 33/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1271 - accuracy: 0.9631 - val_loss: 1.6944 - val_accuracy: 0.6600
# Epoch 34/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1218 - accuracy: 0.9658 - val_loss: 1.6981 - val_accuracy: 0.6767
# Epoch 35/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0922 - accuracy: 0.9707 - val_loss: 1.7669 - val_accuracy: 0.6833
# Epoch 36/40
# 71/71 [==============================] - 6s 78ms/step - loss: 0.1029 - accuracy: 0.9733 - val_loss: 1.7868 - val_accuracy: 0.6533
# Epoch 37/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1388 - accuracy: 0.9596 - val_loss: 1.7762 - val_accuracy: 0.6600
# Epoch 38/40
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1397 - accuracy: 0.9573 - val_loss: 1.7616 - val_accuracy: 0.6567
# Epoch 39/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0862 - accuracy: 0.9702 - val_loss: 1.9593 - val_accuracy: 0.6733
# Epoch 40/40
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0688 - accuracy: 0.9818 - val_loss: 1.8629 - val_accuracy: 0.6633

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.48      0.70      0.57        20
#             Garuda       0.73      0.80      0.76        20
#      Goddess_Durga       0.78      0.90      0.84        20
#    Goddess_Lakshmi       0.55      0.55      0.55        20
# Goddess_Saraswathi       0.46      0.30      0.36        20
#        Lord_Ganesh       0.50      0.60      0.55        20
#       Lord_Hanuman       0.31      0.25      0.28        20
#     Lord_Hayagriva       0.68      0.65      0.67        20
#         Lord_Indra       0.77      1.00      0.87        20
#       Lord_Krishna       0.78      0.70      0.74        20
#        Lord_Muruga       0.77      0.50      0.61        20
#              Nandi       0.86      0.90      0.88        20
#            Nataraj       0.90      0.95      0.93        20
#    Shirdi_Sai_Baba       0.52      0.55      0.54        20
#           Shivling       0.86      0.60      0.71        20
#
#           accuracy                           0.66       300
#          macro avg       0.66      0.66      0.66       300
#       weighted avg       0.66      0.66      0.66       300
#
#
# Accuracy = 66.33333333333333%

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-4) and 40 iterations, the highest accuracy obtained is 67%(approx) at (30, 35).**
