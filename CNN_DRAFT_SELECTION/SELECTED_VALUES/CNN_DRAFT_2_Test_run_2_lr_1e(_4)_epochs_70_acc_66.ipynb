# %% [markdown]
# ## **CNN Draft 2**
# #### **lr=1*10^(-4), epochs=70, Accuracy = 66%**
# #### **Test run - 2**

# %% [markdown]
# #### **Aim: To find suitable learning rate and epoch value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                data.append([resized_arr, class_num])
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 635768628710536179
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11321147392
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 12901901557967725532
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 70
l_rate = 0.0001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 3000)              1731000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 1,915,439
# Trainable params: 1,915,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/70
# 71/71 [==============================] - 16s 91ms/step - loss: 2.7083 - accuracy: 0.0564 - val_loss: 2.6999 - val_accuracy: 0.0900
# Epoch 2/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6718 - accuracy: 0.1031 - val_loss: 2.5652 - val_accuracy: 0.1833
# Epoch 3/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.5294 - accuracy: 0.1849 - val_loss: 2.2673 - val_accuracy: 0.2667
# Epoch 4/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.3643 - accuracy: 0.2378 - val_loss: 2.0417 - val_accuracy: 0.3533
# Epoch 5/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.2377 - accuracy: 0.2880 - val_loss: 1.9050 - val_accuracy: 0.4200
# Epoch 6/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.1478 - accuracy: 0.3213 - val_loss: 1.7740 - val_accuracy: 0.4200
# Epoch 7/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.0373 - accuracy: 0.3609 - val_loss: 1.6915 - val_accuracy: 0.5033
# Epoch 8/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.9551 - accuracy: 0.3916 - val_loss: 1.6040 - val_accuracy: 0.5100
# Epoch 9/70
# 71/71 [==============================] - 6s 78ms/step - loss: 1.8561 - accuracy: 0.4204 - val_loss: 1.7266 - val_accuracy: 0.5000
# Epoch 10/70
# 71/71 [==============================] - 6s 78ms/step - loss: 1.7950 - accuracy: 0.4547 - val_loss: 1.5062 - val_accuracy: 0.5267
# Epoch 11/70
# 71/71 [==============================] - 6s 78ms/step - loss: 1.6680 - accuracy: 0.4769 - val_loss: 1.5788 - val_accuracy: 0.5300
# Epoch 12/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.5818 - accuracy: 0.5107 - val_loss: 1.4467 - val_accuracy: 0.5667
# Epoch 13/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.4911 - accuracy: 0.5356 - val_loss: 1.3862 - val_accuracy: 0.5667
# Epoch 14/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.3640 - accuracy: 0.5756 - val_loss: 1.4168 - val_accuracy: 0.5667
# Epoch 15/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.2614 - accuracy: 0.6200 - val_loss: 1.3853 - val_accuracy: 0.5867
# Epoch 16/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.1524 - accuracy: 0.6431 - val_loss: 1.3701 - val_accuracy: 0.5833
# Epoch 17/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.0761 - accuracy: 0.6733 - val_loss: 1.3561 - val_accuracy: 0.6033
# Epoch 18/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.9586 - accuracy: 0.7084 - val_loss: 1.3678 - val_accuracy: 0.6033
# Epoch 19/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.8428 - accuracy: 0.7427 - val_loss: 1.3483 - val_accuracy: 0.6400
# Epoch 20/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.7284 - accuracy: 0.7787 - val_loss: 1.3750 - val_accuracy: 0.6067
# Epoch 21/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.6550 - accuracy: 0.7938 - val_loss: 1.3818 - val_accuracy: 0.6400
# Epoch 22/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.5928 - accuracy: 0.8227 - val_loss: 1.3437 - val_accuracy: 0.6333
# Epoch 23/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.5049 - accuracy: 0.8409 - val_loss: 1.4691 - val_accuracy: 0.6200
# Epoch 24/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.4075 - accuracy: 0.8813 - val_loss: 1.4812 - val_accuracy: 0.6300
# Epoch 25/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.3402 - accuracy: 0.8942 - val_loss: 1.3383 - val_accuracy: 0.6533
# Epoch 26/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.3019 - accuracy: 0.9044 - val_loss: 1.5393 - val_accuracy: 0.6467
# Epoch 27/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2709 - accuracy: 0.9187 - val_loss: 1.5100 - val_accuracy: 0.6600
# Epoch 28/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.2206 - accuracy: 0.9329 - val_loss: 1.6691 - val_accuracy: 0.6700
# Epoch 29/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1800 - accuracy: 0.9507 - val_loss: 1.6161 - val_accuracy: 0.6433
# Epoch 30/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1608 - accuracy: 0.9489 - val_loss: 1.7530 - val_accuracy: 0.6400
# Epoch 31/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1531 - accuracy: 0.9578 - val_loss: 1.7400 - val_accuracy: 0.6767
# Epoch 32/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1283 - accuracy: 0.9631 - val_loss: 1.6818 - val_accuracy: 0.6700
# Epoch 33/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1404 - accuracy: 0.9591 - val_loss: 1.8231 - val_accuracy: 0.6133
# Epoch 34/70
# 71/71 [==============================] - 6s 78ms/step - loss: 0.1134 - accuracy: 0.9644 - val_loss: 1.7293 - val_accuracy: 0.6600
# Epoch 35/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0870 - accuracy: 0.9751 - val_loss: 1.7932 - val_accuracy: 0.6633
# Epoch 36/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0773 - accuracy: 0.9818 - val_loss: 1.9442 - val_accuracy: 0.6633
# Epoch 37/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0613 - accuracy: 0.9809 - val_loss: 1.9737 - val_accuracy: 0.6700
# Epoch 38/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0672 - accuracy: 0.9813 - val_loss: 2.0414 - val_accuracy: 0.6533
# Epoch 39/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0632 - accuracy: 0.9849 - val_loss: 1.9404 - val_accuracy: 0.6767
# Epoch 40/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0750 - accuracy: 0.9769 - val_loss: 1.9068 - val_accuracy: 0.6533
# Epoch 41/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0777 - accuracy: 0.9778 - val_loss: 2.0025 - val_accuracy: 0.6633
# Epoch 42/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0575 - accuracy: 0.9889 - val_loss: 2.0299 - val_accuracy: 0.6600
# Epoch 43/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0652 - accuracy: 0.9813 - val_loss: 2.1515 - val_accuracy: 0.6500
# Epoch 44/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0696 - accuracy: 0.9782 - val_loss: 2.0783 - val_accuracy: 0.6533
# Epoch 45/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0714 - accuracy: 0.9769 - val_loss: 2.2263 - val_accuracy: 0.6333
# Epoch 46/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0388 - accuracy: 0.9929 - val_loss: 2.0636 - val_accuracy: 0.6567
# Epoch 47/70
# 71/71 [==============================] - 6s 78ms/step - loss: 0.0425 - accuracy: 0.9876 - val_loss: 2.2109 - val_accuracy: 0.6633
# Epoch 48/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0950 - accuracy: 0.9698 - val_loss: 2.3640 - val_accuracy: 0.6200
# Epoch 49/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0540 - accuracy: 0.9840 - val_loss: 2.0932 - val_accuracy: 0.6567
# Epoch 50/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0485 - accuracy: 0.9871 - val_loss: 2.3041 - val_accuracy: 0.6467
# Epoch 51/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0496 - accuracy: 0.9880 - val_loss: 2.2284 - val_accuracy: 0.6633
# Epoch 52/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0371 - accuracy: 0.9893 - val_loss: 2.2101 - val_accuracy: 0.6600
# Epoch 53/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0394 - accuracy: 0.9911 - val_loss: 2.2095 - val_accuracy: 0.6533
# Epoch 54/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0369 - accuracy: 0.9902 - val_loss: 2.0851 - val_accuracy: 0.6667
# Epoch 55/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0198 - accuracy: 0.9960 - val_loss: 2.1211 - val_accuracy: 0.6867
# Epoch 56/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0412 - accuracy: 0.9884 - val_loss: 2.1605 - val_accuracy: 0.6767
# Epoch 57/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0284 - accuracy: 0.9956 - val_loss: 2.2236 - val_accuracy: 0.6567
# Epoch 58/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0326 - accuracy: 0.9898 - val_loss: 2.3771 - val_accuracy: 0.6633
# Epoch 59/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0341 - accuracy: 0.9902 - val_loss: 2.3785 - val_accuracy: 0.6333
# Epoch 60/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0394 - accuracy: 0.9871 - val_loss: 2.3045 - val_accuracy: 0.6633
# Epoch 61/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0532 - accuracy: 0.9844 - val_loss: 2.2385 - val_accuracy: 0.6733
# Epoch 62/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0741 - accuracy: 0.9751 - val_loss: 2.1478 - val_accuracy: 0.6667
# Epoch 63/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0680 - accuracy: 0.9778 - val_loss: 2.0350 - val_accuracy: 0.6767
# Epoch 64/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0458 - accuracy: 0.9867 - val_loss: 2.0964 - val_accuracy: 0.6700
# Epoch 65/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0441 - accuracy: 0.9907 - val_loss: 2.1764 - val_accuracy: 0.6600
# Epoch 66/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0270 - accuracy: 0.9933 - val_loss: 2.2349 - val_accuracy: 0.6633
# Epoch 67/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0301 - accuracy: 0.9942 - val_loss: 2.2473 - val_accuracy: 0.6600
# Epoch 68/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0222 - accuracy: 0.9947 - val_loss: 2.3196 - val_accuracy: 0.6567
# Epoch 69/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0345 - accuracy: 0.9898 - val_loss: 2.2655 - val_accuracy: 0.6467
# Epoch 70/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0396 - accuracy: 0.9876 - val_loss: 2.4174 - val_accuracy: 0.6600

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.68      0.65      0.67        20
#             Garuda       0.67      0.80      0.73        20
#      Goddess_Durga       0.60      0.90      0.72        20
#    Goddess_Lakshmi       0.67      0.60      0.63        20
# Goddess_Saraswathi       0.50      0.35      0.41        20
#        Lord_Ganesh       0.56      0.50      0.53        20
#       Lord_Hanuman       0.62      0.25      0.36        20
#     Lord_Hayagriva       0.52      0.60      0.56        20
#         Lord_Indra       0.91      1.00      0.95        20
#       Lord_Krishna       0.61      0.70      0.65        20
#        Lord_Muruga       0.73      0.55      0.63        20
#              Nandi       0.68      0.75      0.71        20
#            Nataraj       0.90      0.95      0.93        20
#    Shirdi_Sai_Baba       0.52      0.60      0.56        20
#           Shivling       0.70      0.70      0.70        20
#
#           accuracy                           0.66       300
#          macro avg       0.66      0.66      0.65       300
#       weighted avg       0.66      0.66      0.65       300
#
#
# Accuracy = 66.0%

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-4) and 70 iterations, the accuracy obtained was 66%(approx).**
