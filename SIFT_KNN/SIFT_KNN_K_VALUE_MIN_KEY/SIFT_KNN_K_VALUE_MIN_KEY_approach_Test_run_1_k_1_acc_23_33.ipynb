# %% [markdown]
# ## **SIFT + KNN (K Value test) MIN_KEY approach**
# #### **k=1, Accuracy = 23.33% (approx)**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find suitable k value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Req. opencv 4.5+
# !pip uninstall opencv-python
# !pip install opencv-python
# Out:
# Found existing installation: opencv-python 4.5.4.60
# Uninstalling opencv-python-4.5.4.60:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python-4.5.4.60.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5Core-39545cc7.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5Gui-ba0a2070.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5Test-c38a5234.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5Widgets-e69d94fb.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libQt5XcbQpa-ca221f44.so.5.15.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libX11-xcb-69166bdf.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libXau-00ec42fe.so.6.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libavcodec-64ac49e1.so.58.91.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libavformat-4b79e479.so.58.45.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libavutil-805734e8.so.56.51.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libbz2-a273e504.so.1.0.6
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libcrypto-018b8c17.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libfreetype-c0e61f0c.so.6.14.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libgfortran-91cc3cb1.so.3.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libopenblas-r0-f650aae0.3.3.so
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libpng15-ce838cd1.so.15.13.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libssl-6082116c.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libswresample-83ce3247.so.3.7.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libswscale-7e960168.so.5.7.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libvpx-392cd848.so.6.4.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-icccm-413c9f41.so.4.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-image-e82a276d.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-keysyms-21015570.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-randr-a96a5a87.so.0.1.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-render-637b984a.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-render-util-43ce00f5.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-shape-25c2b258.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-shm-7a199f70.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-sync-89374f40.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-util-4d666913.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-xfixes-9be3ba6f.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-xinerama-ae147f87.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxcb-xkb-9ba31ab3.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxkbcommon-71ae2972.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python.libs/libxkbcommon-x11-c65ed502.so.0.0.0
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-4.5.4.60
# Collecting opencv-python
#   Using cached opencv_python-4.5.4.60-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.3 MB)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
# Installing collected packages: opencv-python
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed opencv-python-4.5.4.60

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def SIFT_test(dirs, labels, img_size):
    """Scale Invariant Feature Transform Test run for finding the minimum keypoints detected among all the images in the dataset"""
    
    min_key = np.inf
    
    for data_dir in dirs:
        for label in labels:
            path = os.path.join(data_dir, label)
            for img in os.listdir(path):
                #Reading the image in grayscale mode
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                   
                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) 

                #detecting keypoints
                sift = cv2.SIFT_create()
                keypoints = sift.detect(resized_arr, None)

                if (len(keypoints) < min_key):
                    min_key = len(keypoints)
                
    return min_key

# %%
def SIFT(image, min_key):
    """Scale Invariant Feature Transform for finding keypoints and computing descriptors"""
    
    sift = cv2.SIFT_create(min_key)
    keypoints, descriptors = sift.detectAndCompute(image, None)

    return np.array(descriptors, dtype="i")[:min_key]

# %%
def dataset_creation(data_dir, labels, img_size, min_key):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image in grayscale mode
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                
                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) 

                #SIFT function call
                SIFT_img_desc = SIFT(resized_arr, min_key)
                
                data.append([SIFT_img_desc, class_num])
            except Exception as err:
                print("Error:\n",err)
    
    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))    
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature.flatten())
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature.flatten())
        y_test.append(label)

    return (np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test))

# %%
def build_model_knn(x_train, y_train, k):
    """Builds KNN model"""
    model = KNeighborsClassifier(n_neighbors = k)
    model.fit(x_train, y_train)
    
    return model

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = model.predict(x_test)
    print(classification_report(y_test, predictions, target_names = labels))
    accuracy = accuracy_score(y_test, predictions)*100 
    print("\nAccuracy = "+str(accuracy)+"%")
    return accuracy

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12088868620883151223
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11320098816
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4980675817752712388
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
dirs = ["Dataset_test_1/Train", "Dataset_test_1/Test"]
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
k_val = list(range(1, 55))
acc_list = []

# %%
#Min keypoints detection
min_key = SIFT_test(dirs, labels, img_size)

#Train and Test data loading
train = dataset_creation("Dataset_test_1/Train", labels, img_size, min_key)
test = dataset_creation("Dataset_test_1/Test", labels, img_size, min_key)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)
#print (x_train, y_train)

# %%
#Building KNN Model
for k in k_val:
    model = build_model_knn(x_train, y_train, k)
    #Results
    print("k value:",k)
    accuracy = acc_results(model, labels, x_test, y_test)
    acc_list.append(accuracy)
    print("\n\n\n")
# Out:
# k value: 1
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.35      0.16        20
#             Garuda       0.44      0.55      0.49        20
#      Goddess_Durga       0.09      0.05      0.06        20
#    Goddess_Lakshmi       0.15      0.15      0.15        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.27      0.15      0.19        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.38      0.25      0.30        20
#         Lord_Indra       0.87      1.00      0.93        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.17      0.15      0.16        20
#              Nandi       0.05      0.05      0.05        20
#            Nataraj       0.32      0.60      0.41        20
#    Shirdi_Sai_Baba       0.21      0.20      0.21        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.23       300
#          macro avg       0.20      0.23      0.21       300
#       weighted avg       0.20      0.23      0.21       300
#
#
# Accuracy = 23.333333333333332%
#
#
#
#
# k value: 2
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.55      0.17        20
#             Garuda       0.32      0.45      0.38        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.19      0.25      0.22        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.21      0.20      0.21        20
#       Lord_Hanuman       0.20      0.05      0.08        20
#     Lord_Hayagriva       0.17      0.10      0.12        20
#         Lord_Indra       0.77      0.50      0.61        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.15      0.10      0.12        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.57      0.60      0.59        20
#    Shirdi_Sai_Baba       0.40      0.20      0.27        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.20       300
#          macro avg       0.21      0.20      0.18       300
#       weighted avg       0.21      0.20      0.18       300
#
#
# Accuracy = 20.0%
#
#
#
#
# k value: 3
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.60      0.17        20
#             Garuda       0.23      0.35      0.28        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.22      0.30      0.26        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.23      0.15      0.18        20
#       Lord_Hanuman       0.25      0.05      0.08        20
#     Lord_Hayagriva       0.22      0.10      0.14        20
#         Lord_Indra       0.88      0.35      0.50        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.14      0.05      0.07        20
#              Nandi       0.11      0.05      0.07        20
#            Nataraj       0.30      0.50      0.38        20
#    Shirdi_Sai_Baba       0.18      0.10      0.13        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.17       300
#          macro avg       0.19      0.17      0.15       300
#       weighted avg       0.19      0.17      0.15       300
#
#
# Accuracy = 17.333333333333336%
#
#
#
#
# k value: 4
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.70      0.19        20
#             Garuda       0.12      0.15      0.13        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.19      0.25      0.22        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.25      0.05      0.08        20
#     Lord_Hayagriva       0.25      0.05      0.08        20
#         Lord_Indra       1.00      0.40      0.57        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.25      0.10      0.14        20
#            Nataraj       0.28      0.60      0.38        20
#    Shirdi_Sai_Baba       0.10      0.10      0.10        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.16       300
#          macro avg       0.17      0.16      0.13       300
#       weighted avg       0.17      0.16      0.13       300
#
#
# Accuracy = 16.0%
#
#
#
#
# k value: 5
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.65      0.17        20
#             Garuda       0.16      0.15      0.15        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.20      0.25      0.22        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.50      0.05      0.09        20
#     Lord_Hayagriva       0.43      0.15      0.22        20
#         Lord_Indra       1.00      0.35      0.52        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.30      0.15      0.20        20
#            Nataraj       0.26      0.60      0.36        20
#    Shirdi_Sai_Baba       0.10      0.10      0.10        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.16       300
#          macro avg       0.20      0.16      0.14       300
#       weighted avg       0.20      0.16      0.14       300
#
#
# Accuracy = 16.333333333333332%
#
#
#
#
# k value: 6
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.60      0.17        20
#             Garuda       0.12      0.10      0.11        20
#      Goddess_Durga       0.08      0.05      0.06        20
#    Goddess_Lakshmi       0.23      0.25      0.24        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.25      0.05      0.08        20
#     Lord_Hayagriva       0.23      0.15      0.18        20
#         Lord_Indra       0.80      0.20      0.32        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.27      0.15      0.19        20
#            Nataraj       0.26      0.65      0.37        20
#    Shirdi_Sai_Baba       0.13      0.10      0.11        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.15       300
#          macro avg       0.17      0.15      0.12       300
#       weighted avg       0.17      0.15      0.12       300
#
#
# Accuracy = 15.333333333333332%
#
#
#
#
# k value: 7
#                     precision    recall  f1-score   support
#
#             Buddha       0.12      0.70      0.20        20
#             Garuda       0.08      0.05      0.06        20
#      Goddess_Durga       0.07      0.05      0.06        20
#    Goddess_Lakshmi       0.19      0.25      0.21        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.25      0.05      0.08        20
#     Lord_Hayagriva       0.25      0.15      0.19        20
#         Lord_Indra       0.71      0.25      0.37        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.27      0.15      0.19        20
#            Nataraj       0.27      0.70      0.39        20
#    Shirdi_Sai_Baba       0.13      0.10      0.11        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.16       300
#          macro avg       0.16      0.16      0.13       300
#       weighted avg       0.16      0.16      0.13       300
#
#
# Accuracy = 16.333333333333332%
#
#
#
#
# k value: 8
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.55      0.17        20
#             Garuda       0.08      0.05      0.06        20
#      Goddess_Durga       0.08      0.05      0.06        20
#    Goddess_Lakshmi       0.17      0.25      0.20        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.22      0.20      0.21        20
#         Lord_Indra       0.83      0.25      0.38        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.15      0.10      0.12        20
#            Nataraj       0.29      0.75      0.42        20
#    Shirdi_Sai_Baba       0.12      0.10      0.11        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.15       300
#          macro avg       0.14      0.15      0.12       300
#       weighted avg       0.14      0.15      0.12       300
#
#
# Accuracy = 15.333333333333332%
#
#
#
#
# k value: 9
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.55      0.18        20
#             Garuda       0.14      0.10      0.12        20
#      Goddess_Durga       0.07      0.05      0.06        20
#    Goddess_Lakshmi       0.18      0.25      0.21        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.17      0.15      0.16        20
#         Lord_Indra       0.71      0.25      0.37        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.11      0.05      0.07        20
#              Nandi       0.18      0.10      0.13        20
#            Nataraj       0.25      0.70      0.36        20
#    Shirdi_Sai_Baba       0.14      0.15      0.15        20
#           Shivling       0.33      0.10      0.15        20
#
#           accuracy                           0.16       300
#          macro avg       0.16      0.16      0.13       300
#       weighted avg       0.16      0.16      0.13       300
#
#
# Accuracy = 16.333333333333332%
#
#
#
#
# k value: 10
#                     precision    recall  f1-score   support
#
#             Buddha       0.09      0.45      0.15        20
#             Garuda       0.12      0.10      0.11        20
#      Goddess_Durga       0.11      0.10      0.11        20
#    Goddess_Lakshmi       0.19      0.25      0.21        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.13      0.10      0.11        20
#         Lord_Indra       0.50      0.25      0.33        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.14      0.05      0.07        20
#              Nandi       0.22      0.10      0.14        20
#            Nataraj       0.27      0.80      0.41        20
#    Shirdi_Sai_Baba       0.12      0.10      0.11        20
#           Shivling       0.20      0.05      0.08        20
#
#           accuracy                           0.16       300
#          macro avg       0.14      0.16      0.12       300
#       weighted avg       0.14      0.16      0.12       300
#
#
# Accuracy = 15.666666666666668%
#
#
#
#
# k value: 11
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.50      0.17        20
#             Garuda       0.11      0.10      0.10        20
#      Goddess_Durga       0.13      0.10      0.11        20
#    Goddess_Lakshmi       0.15      0.20      0.17        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.17      0.10      0.12        20
#         Lord_Indra       0.56      0.25      0.34        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.11      0.05      0.07        20
#              Nandi       0.20      0.10      0.13        20
#            Nataraj       0.25      0.75      0.37        20
#    Shirdi_Sai_Baba       0.11      0.10      0.11        20
#           Shivling       0.33      0.10      0.15        20
#
#           accuracy                           0.16       300
#          macro avg       0.15      0.16      0.12       300
#       weighted avg       0.15      0.16      0.12       300
#
#
# Accuracy = 15.666666666666668%
#
#
#
#
# k value: 12
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.55      0.19        20
#             Garuda       0.06      0.05      0.05        20
#      Goddess_Durga       0.12      0.10      0.11        20
#    Goddess_Lakshmi       0.15      0.20      0.17        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.17      0.05      0.08        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.17      0.10      0.12        20
#         Lord_Indra       0.44      0.20      0.28        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.12      0.05      0.07        20
#              Nandi       0.20      0.10      0.13        20
#            Nataraj       0.22      0.65      0.33        20
#    Shirdi_Sai_Baba       0.10      0.10      0.10        20
#           Shivling       0.50      0.10      0.17        20
#
#           accuracy                           0.15       300
#          macro avg       0.16      0.15      0.12       300
#       weighted avg       0.16      0.15      0.12       300
#
#
# Accuracy = 15.0%
#
#
#
#
# k value: 13
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.55      0.18        20
#             Garuda       0.06      0.05      0.06        20
#      Goddess_Durga       0.12      0.10      0.11        20
#    Goddess_Lakshmi       0.12      0.15      0.13        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.08      0.05      0.06        20
#         Lord_Indra       0.25      0.10      0.14        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.09      0.05      0.06        20
#              Nandi       0.18      0.10      0.13        20
#            Nataraj       0.20      0.55      0.29        20
#    Shirdi_Sai_Baba       0.14      0.15      0.14        20
#           Shivling       0.67      0.10      0.17        20
#
#           accuracy                           0.13       300
#          macro avg       0.13      0.13      0.10       300
#       weighted avg       0.13      0.13      0.10       300
#
#
# Accuracy = 13.0%
#
#
#
#
# k value: 14
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.50      0.18        20
#             Garuda       0.07      0.05      0.06        20
#      Goddess_Durga       0.11      0.05      0.07        20
#    Goddess_Lakshmi       0.13      0.15      0.14        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.17      0.05      0.08        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.31      0.25      0.28        20
#         Lord_Indra       0.27      0.15      0.19        20
#       Lord_Krishna       0.14      0.05      0.07        20
#        Lord_Muruga       0.07      0.05      0.06        20
#              Nandi       0.22      0.10      0.14        20
#            Nataraj       0.19      0.55      0.28        20
#    Shirdi_Sai_Baba       0.13      0.15      0.14        20
#           Shivling       0.40      0.10      0.16        20
#
#           accuracy                           0.15       300
#          macro avg       0.15      0.15      0.12       300
#       weighted avg       0.15      0.15      0.12       300
#
#
# Accuracy = 14.666666666666666%
#
#
#
#
# k value: 15
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.45      0.16        20
#             Garuda       0.07      0.05      0.06        20
#      Goddess_Durga       0.14      0.05      0.07        20
#    Goddess_Lakshmi       0.16      0.20      0.18        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.33      0.10      0.15        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.22      0.20      0.21        20
#         Lord_Indra       0.33      0.15      0.21        20
#       Lord_Krishna       0.10      0.05      0.07        20
#        Lord_Muruga       0.12      0.10      0.11        20
#              Nandi       0.25      0.10      0.14        20
#            Nataraj       0.17      0.50      0.25        20
#    Shirdi_Sai_Baba       0.21      0.25      0.23        20
#           Shivling       0.33      0.10      0.15        20
#
#           accuracy                           0.15       300
#          macro avg       0.17      0.15      0.13       300
#       weighted avg       0.17      0.15      0.13       300
#
#
# Accuracy = 15.333333333333332%
#
#
#
#
# k value: 16
#                     precision    recall  f1-score   support
#
#             Buddha       0.09      0.40      0.14        20
#             Garuda       0.14      0.10      0.12        20
#      Goddess_Durga       0.20      0.05      0.08        20
#    Goddess_Lakshmi       0.15      0.20      0.17        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.18      0.20      0.19        20
#         Lord_Indra       0.30      0.15      0.20        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.07      0.05      0.06        20
#              Nandi       0.20      0.10      0.13        20
#            Nataraj       0.14      0.40      0.21        20
#    Shirdi_Sai_Baba       0.23      0.30      0.26        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.14       300
#          macro avg       0.15      0.14      0.12       300
#       weighted avg       0.15      0.14      0.12       300
#
#
# Accuracy = 13.666666666666666%
#
#
#
#
# k value: 17
#                     precision    recall  f1-score   support
#
#             Buddha       0.09      0.40      0.14        20
#             Garuda       0.15      0.10      0.12        20
#      Goddess_Durga       0.17      0.05      0.08        20
#    Goddess_Lakshmi       0.12      0.15      0.13        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.17      0.15      0.16        20
#         Lord_Indra       0.44      0.20      0.28        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.07      0.05      0.06        20
#              Nandi       0.22      0.10      0.14        20
#            Nataraj       0.15      0.45      0.23        20
#    Shirdi_Sai_Baba       0.23      0.30      0.26        20
#           Shivling       0.33      0.05      0.09        20
#
#           accuracy                           0.14       300
#          macro avg       0.18      0.14      0.12       300
#       weighted avg       0.18      0.14      0.12       300
#
#
# Accuracy = 14.000000000000002%
#
#
#
#
# k value: 18
#                     precision    recall  f1-score   support
#
#             Buddha       0.12      0.55      0.19        20
#             Garuda       0.18      0.10      0.13        20
#      Goddess_Durga       0.17      0.05      0.08        20
#    Goddess_Lakshmi       0.11      0.15      0.12        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.17      0.15      0.16        20
#         Lord_Indra       0.50      0.15      0.23        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.06      0.05      0.05        20
#              Nandi       0.22      0.10      0.14        20
#            Nataraj       0.16      0.45      0.23        20
#    Shirdi_Sai_Baba       0.21      0.25      0.23        20
#           Shivling       0.40      0.10      0.16        20
#
#           accuracy                           0.15       300
#          macro avg       0.19      0.15      0.13       300
#       weighted avg       0.19      0.15      0.13       300
#
#
# Accuracy = 14.666666666666666%
#
#
#
#
# k value: 19
#                     precision    recall  f1-score   support
#
#             Buddha       0.12      0.55      0.19        20
#             Garuda       0.20      0.10      0.13        20
#      Goddess_Durga       0.17      0.05      0.08        20
#    Goddess_Lakshmi       0.11      0.15      0.13        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.40      0.10      0.16        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.22      0.20      0.21        20
#         Lord_Indra       0.50      0.20      0.29        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.06      0.05      0.05        20
#              Nandi       0.22      0.10      0.14        20
#            Nataraj       0.15      0.45      0.23        20
#    Shirdi_Sai_Baba       0.20      0.25      0.22        20
#           Shivling       0.50      0.10      0.17        20
#
#           accuracy                           0.15       300
#          macro avg       0.19      0.15      0.13       300
#       weighted avg       0.19      0.15      0.13       300
#
#
# Accuracy = 15.333333333333332%
#
#
#
#
# k value: 20
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.55      0.19        20
#             Garuda       0.20      0.10      0.13        20
#      Goddess_Durga       0.17      0.05      0.08        20
#    Goddess_Lakshmi       0.19      0.25      0.21        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.40      0.10      0.16        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.22      0.20      0.21        20
#         Lord_Indra       0.40      0.10      0.16        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.07      0.05      0.06        20
#              Nandi       0.20      0.10      0.13        20
#            Nataraj       0.16      0.50      0.25        20
#    Shirdi_Sai_Baba       0.21      0.25      0.23        20
#           Shivling       0.40      0.10      0.16        20
#
#           accuracy                           0.16       300
#          macro avg       0.18      0.16      0.13       300
#       weighted avg       0.18      0.16      0.13       300
#
#
# Accuracy = 15.666666666666668%
#
#
#
#
# k value: 21
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.55      0.19        20
#             Garuda       0.27      0.15      0.19        20
#      Goddess_Durga       0.12      0.05      0.07        20
#    Goddess_Lakshmi       0.16      0.20      0.18        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.25      0.05      0.08        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.26      0.30      0.28        20
#         Lord_Indra       0.29      0.10      0.15        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.07      0.05      0.06        20
#              Nandi       0.20      0.10      0.13        20
#            Nataraj       0.18      0.55      0.27        20
#    Shirdi_Sai_Baba       0.17      0.20      0.19        20
#           Shivling       0.67      0.10      0.17        20
#
#           accuracy                           0.16       300
#          macro avg       0.18      0.16      0.13       300
#       weighted avg       0.18      0.16      0.13       300
#
#
# Accuracy = 16.0%
#
#
#
#
# k value: 22
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.50      0.17        20
#             Garuda       0.33      0.15      0.21        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.11      0.15      0.13        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.25      0.30      0.27        20
#         Lord_Indra       0.33      0.15      0.21        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.11      0.05      0.07        20
#            Nataraj       0.18      0.55      0.27        20
#    Shirdi_Sai_Baba       0.22      0.30      0.26        20
#           Shivling       0.50      0.05      0.09        20
#
#           accuracy                           0.15       300
#          macro avg       0.14      0.15      0.11       300
#       weighted avg       0.14      0.15      0.11       300
#
#
# Accuracy = 14.666666666666666%
#
#
#
#
# k value: 23
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.45      0.16        20
#             Garuda       0.30      0.15      0.20        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.11      0.15      0.13        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.20      0.25      0.22        20
#         Lord_Indra       0.36      0.20      0.26        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.12      0.05      0.07        20
#            Nataraj       0.18      0.50      0.27        20
#    Shirdi_Sai_Baba       0.21      0.30      0.25        20
#           Shivling       0.25      0.05      0.08        20
#
#           accuracy                           0.14       300
#          macro avg       0.12      0.14      0.11       300
#       weighted avg       0.12      0.14      0.11       300
#
#
# Accuracy = 14.000000000000002%
#
#
#
#
# k value: 24
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.45      0.16        20
#             Garuda       0.38      0.15      0.21        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.13        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.19      0.25      0.22        20
#         Lord_Indra       0.36      0.20      0.26        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.11      0.05      0.07        20
#            Nataraj       0.18      0.50      0.26        20
#    Shirdi_Sai_Baba       0.22      0.35      0.27        20
#           Shivling       0.33      0.05      0.09        20
#
#           accuracy                           0.14       300
#          macro avg       0.13      0.14      0.11       300
#       weighted avg       0.13      0.14      0.11       300
#
#
# Accuracy = 14.333333333333334%
#
#
#
#
# k value: 25
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.50      0.17        20
#             Garuda       0.33      0.15      0.21        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.14        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.19      0.25      0.22        20
#         Lord_Indra       0.30      0.15      0.20        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.14      0.05      0.07        20
#            Nataraj       0.19      0.55      0.29        20
#    Shirdi_Sai_Baba       0.24      0.40      0.30        20
#           Shivling       0.25      0.05      0.08        20
#
#           accuracy                           0.15       300
#          macro avg       0.13      0.15      0.11       300
#       weighted avg       0.13      0.15      0.11       300
#
#
# Accuracy = 15.0%
#
#
#
#
# k value: 26
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.45      0.16        20
#             Garuda       0.38      0.15      0.21        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.16      0.20      0.18        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.23      0.25      0.24        20
#         Lord_Indra       0.27      0.15      0.19        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.10      0.05      0.07        20
#            Nataraj       0.19      0.55      0.28        20
#    Shirdi_Sai_Baba       0.24      0.40      0.30        20
#           Shivling       0.17      0.05      0.08        20
#
#           accuracy                           0.16       300
#          macro avg       0.15      0.16      0.12       300
#       weighted avg       0.15      0.16      0.12       300
#
#
# Accuracy = 15.666666666666668%
#
#
#
#
# k value: 27
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.45      0.16        20
#             Garuda       0.43      0.15      0.22        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.16      0.20      0.18        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.25      0.30      0.27        20
#         Lord_Indra       0.27      0.15      0.19        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.19      0.55      0.28        20
#    Shirdi_Sai_Baba       0.24      0.40      0.30        20
#           Shivling       0.33      0.10      0.15        20
#
#           accuracy                           0.16       300
#          macro avg       0.16      0.16      0.13       300
#       weighted avg       0.16      0.16      0.13       300
#
#
# Accuracy = 16.0%
#
#
#
#
# k value: 28
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.45      0.17        20
#             Garuda       0.38      0.15      0.21        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.14      0.20      0.17        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.20      0.25      0.22        20
#         Lord_Indra       0.27      0.15      0.19        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.18      0.50      0.26        20
#    Shirdi_Sai_Baba       0.18      0.30      0.22        20
#           Shivling       0.33      0.10      0.15        20
#
#           accuracy                           0.15       300
#          macro avg       0.15      0.15      0.12       300
#       weighted avg       0.15      0.15      0.12       300
#
#
# Accuracy = 14.666666666666666%
#
#
#
#
# k value: 29
#                     precision    recall  f1-score   support
#
#             Buddha       0.07      0.30      0.11        20
#             Garuda       0.43      0.15      0.22        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.13        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.40      0.10      0.16        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.23      0.30      0.26        20
#         Lord_Indra       0.25      0.15      0.19        20
#       Lord_Krishna       0.14      0.05      0.07        20
#        Lord_Muruga       0.08      0.05      0.06        20
#              Nandi       0.07      0.05      0.06        20
#            Nataraj       0.18      0.50      0.27        20
#    Shirdi_Sai_Baba       0.21      0.40      0.27        20
#           Shivling       0.50      0.10      0.17        20
#
#           accuracy                           0.15       300
#          macro avg       0.18      0.15      0.13       300
#       weighted avg       0.18      0.15      0.13       300
#
#
# Accuracy = 15.333333333333332%
#
#
#
#
# k value: 30
#                     precision    recall  f1-score   support
#
#             Buddha       0.09      0.40      0.15        20
#             Garuda       0.33      0.10      0.15        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.09      0.10      0.09        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.40      0.10      0.16        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.26      0.30      0.28        20
#         Lord_Indra       0.21      0.15      0.18        20
#       Lord_Krishna       0.14      0.05      0.07        20
#        Lord_Muruga       0.07      0.05      0.06        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.16      0.45      0.24        20
#    Shirdi_Sai_Baba       0.21      0.40      0.27        20
#           Shivling       0.40      0.10      0.16        20
#
#           accuracy                           0.15       300
#          macro avg       0.16      0.15      0.12       300
#       weighted avg       0.16      0.15      0.12       300
#
#
# Accuracy = 14.666666666666666%
#
#
#
#
# k value: 31
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.40      0.16        20
#             Garuda       0.29      0.10      0.15        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.13        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.26      0.30      0.28        20
#         Lord_Indra       0.23      0.15      0.18        20
#       Lord_Krishna       0.12      0.05      0.07        20
#        Lord_Muruga       0.07      0.05      0.06        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.16      0.45      0.24        20
#    Shirdi_Sai_Baba       0.21      0.40      0.27        20
#           Shivling       0.33      0.10      0.15        20
#
#           accuracy                           0.15       300
#          macro avg       0.16      0.15      0.12       300
#       weighted avg       0.16      0.15      0.12       300
#
#
# Accuracy = 15.0%
#
#
#
#
# k value: 32
#                     precision    recall  f1-score   support
#
#             Buddha       0.09      0.35      0.14        20
#             Garuda       0.29      0.10      0.15        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.14        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.40      0.10      0.16        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.27      0.30      0.29        20
#         Lord_Indra       0.25      0.15      0.19        20
#       Lord_Krishna       0.17      0.05      0.08        20
#        Lord_Muruga       0.12      0.10      0.11        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.18      0.50      0.26        20
#    Shirdi_Sai_Baba       0.23      0.45      0.31        20
#           Shivling       0.29      0.10      0.15        20
#
#           accuracy                           0.16       300
#          macro avg       0.16      0.16      0.13       300
#       weighted avg       0.16      0.16      0.13       300
#
#
# Accuracy = 15.666666666666668%
#
#
#
#
# k value: 33
#                     precision    recall  f1-score   support
#
#             Buddha       0.09      0.35      0.14        20
#             Garuda       0.29      0.10      0.15        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.14        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.33      0.10      0.15        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.25      0.30      0.27        20
#         Lord_Indra       0.25      0.15      0.19        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.07      0.05      0.06        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.18      0.50      0.27        20
#    Shirdi_Sai_Baba       0.20      0.40      0.27        20
#           Shivling       0.25      0.10      0.14        20
#
#           accuracy                           0.15       300
#          macro avg       0.14      0.15      0.12       300
#       weighted avg       0.14      0.15      0.12       300
#
#
# Accuracy = 14.666666666666666%
#
#
#
#
# k value: 34
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.40      0.16        20
#             Garuda       0.33      0.10      0.15        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.14        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.33      0.10      0.15        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.24      0.30      0.27        20
#         Lord_Indra       0.25      0.15      0.19        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.07      0.05      0.06        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.18      0.50      0.26        20
#    Shirdi_Sai_Baba       0.19      0.40      0.25        20
#           Shivling       0.38      0.15      0.21        20
#
#           accuracy                           0.15       300
#          macro avg       0.15      0.15      0.12       300
#       weighted avg       0.15      0.15      0.12       300
#
#
# Accuracy = 15.333333333333332%
#
#
#
#
# k value: 35
#                     precision    recall  f1-score   support
#
#             Buddha       0.10      0.40      0.16        20
#             Garuda       0.33      0.10      0.15        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.14        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.40      0.10      0.16        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.23      0.30      0.26        20
#         Lord_Indra       0.23      0.15      0.18        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.14      0.10      0.12        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.16      0.45      0.24        20
#    Shirdi_Sai_Baba       0.20      0.40      0.26        20
#           Shivling       0.43      0.15      0.22        20
#
#           accuracy                           0.15       300
#          macro avg       0.16      0.15      0.13       300
#       weighted avg       0.16      0.15      0.13       300
#
#
# Accuracy = 15.333333333333332%
#
#
#
#
# k value: 36
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.45      0.18        20
#             Garuda       0.20      0.05      0.08        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.14        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.26      0.35      0.30        20
#         Lord_Indra       0.18      0.10      0.13        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.14      0.10      0.12        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.15      0.45      0.22        20
#    Shirdi_Sai_Baba       0.22      0.45      0.30        20
#           Shivling       0.40      0.10      0.16        20
#
#           accuracy                           0.15       300
#          macro avg       0.15      0.15      0.12       300
#       weighted avg       0.15      0.15      0.12       300
#
#
# Accuracy = 15.333333333333332%
#
#
#
#
# k value: 37
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.40      0.17        20
#             Garuda       0.14      0.05      0.07        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.12      0.15      0.13        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.67      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.25      0.35      0.29        20
#         Lord_Indra       0.18      0.10      0.13        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.14      0.10      0.12        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.17      0.50      0.25        20
#    Shirdi_Sai_Baba       0.24      0.50      0.32        20
#           Shivling       0.40      0.10      0.16        20
#
#           accuracy                           0.16       300
#          macro avg       0.16      0.16      0.12       300
#       weighted avg       0.16      0.16      0.12       300
#
#
# Accuracy = 15.666666666666668%
#
#
#
#
# k value: 38
#                     precision    recall  f1-score   support
#
#             Buddha       0.07      0.25      0.11        20
#             Garuda       0.12      0.05      0.07        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.08      0.10      0.09        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.67      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.27      0.35      0.30        20
#         Lord_Indra       0.22      0.10      0.14        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.19      0.15      0.17        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.16      0.50      0.25        20
#    Shirdi_Sai_Baba       0.22      0.50      0.31        20
#           Shivling       0.33      0.05      0.09        20
#
#           accuracy                           0.14       300
#          macro avg       0.16      0.14      0.11       300
#       weighted avg       0.16      0.14      0.11       300
#
#
# Accuracy = 14.333333333333334%
#
#
#
#
# k value: 39
#                     precision    recall  f1-score   support
#
#             Buddha       0.08      0.30      0.13        20
#             Garuda       0.12      0.05      0.07        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.08      0.10      0.09        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.26      0.35      0.30        20
#         Lord_Indra       0.25      0.10      0.14        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.19      0.15      0.17        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.17      0.50      0.25        20
#    Shirdi_Sai_Baba       0.26      0.60      0.36        20
#           Shivling       0.33      0.05      0.09        20
#
#           accuracy                           0.15       300
#          macro avg       0.15      0.15      0.12       300
#       weighted avg       0.15      0.15      0.12       300
#
#
# Accuracy = 15.333333333333332%
#
#
#
#
# k value: 40
#                     precision    recall  f1-score   support
#
#             Buddha       0.09      0.35      0.14        20
#             Garuda       0.12      0.05      0.07        20
#      Goddess_Durga       0.17      0.05      0.08        20
#    Goddess_Lakshmi       0.08      0.10      0.09        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.50      0.10      0.17        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.25      0.35      0.29        20
#         Lord_Indra       0.14      0.05      0.07        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.18      0.15      0.16        20
# ...
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.33      0.05      0.09        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.19      0.30      0.24        20
#         Lord_Indra       0.00      0.00      0.00        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.17      0.15      0.16        20
#              Nandi       0.09      0.05      0.06        20
#            Nataraj       0.17      0.45      0.25        20
#    Shirdi_Sai_Baba       0.18      0.45      0.26        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.13       300
#          macro avg       0.11      0.13      0.10       300
#       weighted avg       0.11      0.13      0.10       300
#
#
# Accuracy = 13.333333333333334%
#
#
#
#
# k value: 47
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                     precision    recall  f1-score   support
#
#             Buddha       0.08      0.30      0.13        20
#             Garuda       0.20      0.05      0.08        20
#      Goddess_Durga       0.14      0.05      0.07        20
#    Goddess_Lakshmi       0.16      0.25      0.19        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.33      0.05      0.09        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.21      0.30      0.25        20
#         Lord_Indra       0.00      0.00      0.00        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.16      0.15      0.15        20
#              Nandi       0.08      0.05      0.06        20
#            Nataraj       0.16      0.45      0.24        20
#    Shirdi_Sai_Baba       0.18      0.45      0.26        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.14       300
#          macro avg       0.11      0.14      0.10       300
#       weighted avg       0.11      0.14      0.10       300
#
#
# Accuracy = 14.000000000000002%
#
#
#
#
# k value: 48
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                     precision    recall  f1-score   support
#
#             Buddha       0.08      0.30      0.13        20
#             Garuda       0.20      0.05      0.08        20
#      Goddess_Durga       0.14      0.05      0.07        20
#    Goddess_Lakshmi       0.17      0.25      0.20        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.25      0.05      0.08        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.23      0.30      0.26        20
#         Lord_Indra       0.00      0.00      0.00        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.17      0.15      0.16        20
#              Nandi       0.06      0.05      0.06        20
#            Nataraj       0.16      0.45      0.23        20
#    Shirdi_Sai_Baba       0.18      0.45      0.26        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.14       300
#          macro avg       0.11      0.14      0.10       300
#       weighted avg       0.11      0.14      0.10       300
#
#
# Accuracy = 14.000000000000002%
#
#
#
#
# k value: 49
#                     precision    recall  f1-score   support
#
#             Buddha       0.08      0.30      0.13        20
#             Garuda       0.25      0.05      0.08        20
#      Goddess_Durga       0.25      0.10      0.14        20
#    Goddess_Lakshmi       0.17      0.25      0.20        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.25      0.05      0.08        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.22      0.30      0.26        20
#         Lord_Indra       0.14      0.05      0.07        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.19      0.15      0.17        20
#              Nandi       0.07      0.05      0.06        20
#            Nataraj       0.16      0.45      0.24        20
#    Shirdi_Sai_Baba       0.19      0.50      0.28        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.15       300
#          macro avg       0.13      0.15      0.11       300
#       weighted avg       0.13      0.15      0.11       300
#
#
# Accuracy = 15.0%
#
#
#
#
# k value: 50
#                     precision    recall  f1-score   support
#
#             Buddha       0.07      0.25      0.11        20
#             Garuda       0.20      0.05      0.08        20
#      Goddess_Durga       0.25      0.10      0.14        20
#    Goddess_Lakshmi       0.19      0.30      0.23        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.25      0.05      0.08        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.21      0.30      0.24        20
#         Lord_Indra       0.12      0.05      0.07        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.16      0.15      0.15        20
#              Nandi       0.07      0.05      0.06        20
#            Nataraj       0.16      0.45      0.24        20
#    Shirdi_Sai_Baba       0.16      0.40      0.23        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.14       300
#          macro avg       0.12      0.14      0.11       300
#       weighted avg       0.12      0.14      0.11       300
#
#
# Accuracy = 14.333333333333334%
#
#
#
#
# k value: 51
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                     precision    recall  f1-score   support
#
#             Buddha       0.08      0.30      0.13        20
#             Garuda       0.20      0.05      0.08        20
#      Goddess_Durga       0.29      0.10      0.15        20
#    Goddess_Lakshmi       0.19      0.30      0.23        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.33      0.05      0.09        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.21      0.30      0.25        20
#         Lord_Indra       0.12      0.05      0.07        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.17      0.15      0.16        20
#              Nandi       0.08      0.05      0.06        20
#            Nataraj       0.16      0.45      0.23        20
#    Shirdi_Sai_Baba       0.18      0.45      0.25        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.15       300
#          macro avg       0.13      0.15      0.11       300
#       weighted avg       0.13      0.15      0.11       300
#
#
# Accuracy = 15.0%
#
#
#
#
# k value: 52
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                     precision    recall  f1-score   support
#
#             Buddha       0.08      0.30      0.13        20
#             Garuda       0.25      0.05      0.08        20
#      Goddess_Durga       0.29      0.10      0.15        20
#    Goddess_Lakshmi       0.16      0.25      0.19        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.33      0.05      0.09        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.20      0.30      0.24        20
#         Lord_Indra       0.12      0.05      0.07        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.17      0.15      0.16        20
#              Nandi       0.08      0.05      0.06        20
#            Nataraj       0.16      0.45      0.24        20
#    Shirdi_Sai_Baba       0.18      0.45      0.25        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.15       300
#          macro avg       0.13      0.15      0.11       300
#       weighted avg       0.13      0.15      0.11       300
#
#
# Accuracy = 14.666666666666666%
#
#
#
#
# k value: 53
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.40      0.17        20
#             Garuda       0.20      0.05      0.08        20
#      Goddess_Durga       0.33      0.10      0.15        20
#    Goddess_Lakshmi       0.15      0.25      0.19        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.33      0.05      0.09        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.20      0.30      0.24        20
#         Lord_Indra       0.14      0.05      0.07        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.17      0.15      0.16        20
#              Nandi       0.09      0.05      0.06        20
#            Nataraj       0.16      0.45      0.24        20
#    Shirdi_Sai_Baba       0.15      0.35      0.21        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.15       300
#          macro avg       0.14      0.15      0.11       300
#       weighted avg       0.14      0.15      0.11       300
#
#
# Accuracy = 14.666666666666666%
#
#
#
#
# k value: 54
#                     precision    recall  f1-score   support
#
#             Buddha       0.11      0.40      0.18        20
#             Garuda       0.20      0.05      0.08        20
#      Goddess_Durga       0.33      0.10      0.15        20
#    Goddess_Lakshmi       0.18      0.30      0.22        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.25      0.05      0.08        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.23      0.35      0.27        20
#         Lord_Indra       0.14      0.05      0.07        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.18      0.15      0.16        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.17      0.50      0.25        20
#    Shirdi_Sai_Baba       0.17      0.40      0.24        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.16       300
#          macro avg       0.13      0.16      0.11       300
#       weighted avg       0.13      0.16      0.11       300
#
#
# Accuracy = 15.666666666666668%
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Plotting graph
plt.figure(figsize=(25,25))
plt.plot(k_val , acc_list, color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
print ("Highest accuracy = " + str(max(acc_list)) + "%  for k value = " + str(k_val[acc_list.index(max(acc_list))]))
# Out:
# Highest accuracy = 23.333333333333332%  for k value = 1

# %% [markdown]
# #### **Result: For k value = 1 , highest accuracy was obtained (23.33%(approx)).**
