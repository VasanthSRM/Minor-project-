# %% [markdown]
# ## **SIFT + ANN (Max_keypoints and padding approach)**
# #### **lr=1*10^(-4), epochs=70, Accuracy = 12% (approx) at (1, 10) epochs range**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find suitable learning rate and epoch value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Req. opencv 4.5+
# !pip uninstall opencv-python
# !pip install opencv-python

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def SIFT_test(dirs, labels, img_size):
    """Scale Invariant Feature Transform Test run for finding the maximum keypoints detected among all the images in the dataset"""
    
    max_key = 0
    
    for data_dir in dirs:
        for label in labels:
            path = os.path.join(data_dir, label)
            for img in os.listdir(path):
                #Reading the image in grayscale mode
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                   
                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) 

                #detecting keypoints
                sift = cv2.SIFT_create()
                keypoints = sift.detect(resized_arr, None)

                if (len(keypoints) > max_key):
                    max_key = len(keypoints)
                
    return max_key

# %%
def SIFT(image, max_key):
    """Scale Invariant Feature Transform for finding keypoints and computing descriptors"""
    
    sift = cv2.SIFT_create()
    keypoints, descriptors = sift.detectAndCompute(image, None)

    return np.pad(np.array(descriptors, dtype="i"), ((0, max_key-len(keypoints)), (0, 0)))[:max_key]

# %%
def dataset_creation(data_dir, labels, img_size, max_key):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image in grayscale mode
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                
                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) 

                #SIFT function call
                SIFT_img_desc = SIFT(resized_arr, max_key)
                
                data.append([SIFT_img_desc, class_num])
            except Exception as err:
                print("Error:\n",err)
    
    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))    
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test))

# %%
def build_model_ann(tot_classes, x_train):
    """Builds ANN model and prints model summary"""
    model = Sequential()
    
    model.add(Flatten(input_shape=x_train.shape[1:]))
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(1000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 204485200836614695
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11321147392
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3946303829500251310
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
dirs = ["Dataset_test_1/Train", "Dataset_test_1/Test"]
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 70
l_rate = 0.0001

# %%
#Max keypoints detection
max_key = SIFT_test(dirs, labels, img_size)

#Train and Test data loading
train = dataset_creation("Dataset_test_1/Train", labels, img_size, max_key)
test = dataset_creation("Dataset_test_1/Test", labels, img_size, max_key)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

# %%
#Building ANN Model
model = build_model_ann(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 147712)            0
#
#  dense (Dense)               (None, 3000)              443139000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 1000)              3001000
#
#  dropout_1 (Dropout)         (None, 1000)              0
#
#  dense_2 (Dense)             (None, 15)                15015
#
# =================================================================
# Total params: 446,155,015
# Trainable params: 446,155,015
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/70
# 71/71 [==============================] - 14s 183ms/step - loss: 289.0683 - accuracy: 0.0742 - val_loss: 33.9332 - val_accuracy: 0.1267
# Epoch 2/70
# 71/71 [==============================] - 13s 179ms/step - loss: 65.3134 - accuracy: 0.1040 - val_loss: 6.1532 - val_accuracy: 0.0867
# Epoch 3/70
# 71/71 [==============================] - 13s 177ms/step - loss: 14.2414 - accuracy: 0.0942 - val_loss: 6.1884 - val_accuracy: 0.0800
# Epoch 4/70
# 71/71 [==============================] - 13s 178ms/step - loss: 9.8778 - accuracy: 0.0889 - val_loss: 3.3310 - val_accuracy: 0.1033
# Epoch 5/70
# 71/71 [==============================] - 13s 178ms/step - loss: 7.6212 - accuracy: 0.0982 - val_loss: 3.0094 - val_accuracy: 0.1033
# Epoch 6/70
# 71/71 [==============================] - 13s 177ms/step - loss: 5.2778 - accuracy: 0.1036 - val_loss: 4.0338 - val_accuracy: 0.0933
# Epoch 7/70
# 71/71 [==============================] - 13s 178ms/step - loss: 6.0116 - accuracy: 0.0933 - val_loss: 3.0652 - val_accuracy: 0.1000
# Epoch 8/70
# 71/71 [==============================] - 13s 181ms/step - loss: 5.1735 - accuracy: 0.0947 - val_loss: 2.7796 - val_accuracy: 0.1100
# Epoch 9/70
# 71/71 [==============================] - 13s 185ms/step - loss: 4.5596 - accuracy: 0.0969 - val_loss: 2.6898 - val_accuracy: 0.0967
# Epoch 10/70
# 71/71 [==============================] - 13s 182ms/step - loss: 4.4476 - accuracy: 0.0898 - val_loss: 2.7654 - val_accuracy: 0.0833
# Epoch 11/70
# 71/71 [==============================] - 13s 182ms/step - loss: 4.2086 - accuracy: 0.0880 - val_loss: 2.7289 - val_accuracy: 0.0867
# Epoch 12/70
# 71/71 [==============================] - 13s 182ms/step - loss: 4.8615 - accuracy: 0.0951 - val_loss: 2.7082 - val_accuracy: 0.0933
# Epoch 13/70
# 71/71 [==============================] - 13s 181ms/step - loss: 3.5477 - accuracy: 0.0982 - val_loss: 2.7306 - val_accuracy: 0.0900
# Epoch 14/70
# 71/71 [==============================] - 13s 180ms/step - loss: 4.0723 - accuracy: 0.0964 - val_loss: 2.7104 - val_accuracy: 0.0767
# Epoch 15/70
# 71/71 [==============================] - 13s 180ms/step - loss: 4.4601 - accuracy: 0.0996 - val_loss: 2.7005 - val_accuracy: 0.1100
# Epoch 16/70
# 71/71 [==============================] - 13s 180ms/step - loss: 3.9629 - accuracy: 0.0880 - val_loss: 2.7311 - val_accuracy: 0.0733
# Epoch 17/70
# 71/71 [==============================] - 13s 179ms/step - loss: 3.2035 - accuracy: 0.0938 - val_loss: 2.6869 - val_accuracy: 0.0800
# Epoch 18/70
# 71/71 [==============================] - 13s 179ms/step - loss: 3.4123 - accuracy: 0.0893 - val_loss: 2.7533 - val_accuracy: 0.0733
# Epoch 19/70
# 71/71 [==============================] - 13s 179ms/step - loss: 3.2193 - accuracy: 0.0991 - val_loss: 2.6955 - val_accuracy: 0.0700
# Epoch 20/70
# 71/71 [==============================] - 13s 179ms/step - loss: 2.8813 - accuracy: 0.0951 - val_loss: 2.6906 - val_accuracy: 0.0800
# Epoch 21/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.9217 - accuracy: 0.1000 - val_loss: 2.6973 - val_accuracy: 0.0700
# Epoch 22/70
# 71/71 [==============================] - 13s 178ms/step - loss: 3.1583 - accuracy: 0.0951 - val_loss: 2.6862 - val_accuracy: 0.0800
# Epoch 23/70
# 71/71 [==============================] - 13s 178ms/step - loss: 3.2067 - accuracy: 0.0924 - val_loss: 2.6911 - val_accuracy: 0.0733
# Epoch 24/70
# 71/71 [==============================] - 13s 178ms/step - loss: 3.3610 - accuracy: 0.0938 - val_loss: 2.6879 - val_accuracy: 0.0767
# Epoch 25/70
# 71/71 [==============================] - 13s 178ms/step - loss: 3.3179 - accuracy: 0.0880 - val_loss: 2.6930 - val_accuracy: 0.0733
# Epoch 26/70
# 71/71 [==============================] - 13s 178ms/step - loss: 3.0579 - accuracy: 0.0907 - val_loss: 2.6955 - val_accuracy: 0.0733
# Epoch 27/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7487 - accuracy: 0.0956 - val_loss: 2.6668 - val_accuracy: 0.0833
# Epoch 28/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.9063 - accuracy: 0.0893 - val_loss: 2.7268 - val_accuracy: 0.0733
# Epoch 29/70
# 71/71 [==============================] - 13s 179ms/step - loss: 3.0758 - accuracy: 0.0938 - val_loss: 2.7488 - val_accuracy: 0.0733
# Epoch 30/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.9717 - accuracy: 0.0893 - val_loss: 2.6914 - val_accuracy: 0.0767
# Epoch 31/70
# 71/71 [==============================] - 13s 178ms/step - loss: 3.0142 - accuracy: 0.0902 - val_loss: 2.6860 - val_accuracy: 0.0800
# Epoch 32/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.7998 - accuracy: 0.0898 - val_loss: 2.6953 - val_accuracy: 0.0700
# Epoch 33/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.8411 - accuracy: 0.0849 - val_loss: 2.6988 - val_accuracy: 0.0700
# Epoch 34/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.7645 - accuracy: 0.0813 - val_loss: 2.6944 - val_accuracy: 0.0700
# Epoch 35/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.6957 - accuracy: 0.0916 - val_loss: 2.7006 - val_accuracy: 0.0700
# Epoch 36/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.6744 - accuracy: 0.0844 - val_loss: 2.7019 - val_accuracy: 0.0700
# Epoch 37/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7600 - accuracy: 0.0911 - val_loss: 2.6966 - val_accuracy: 0.0733
# Epoch 38/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.9677 - accuracy: 0.0978 - val_loss: 2.7010 - val_accuracy: 0.0700
# Epoch 39/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7220 - accuracy: 0.0916 - val_loss: 2.7747 - val_accuracy: 0.0767
# Epoch 40/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7282 - accuracy: 0.0876 - val_loss: 2.7005 - val_accuracy: 0.0700
# Epoch 41/70
# 71/71 [==============================] - 13s 176ms/step - loss: 2.6651 - accuracy: 0.0813 - val_loss: 2.6996 - val_accuracy: 0.0733
# Epoch 42/70
# 71/71 [==============================] - 13s 176ms/step - loss: 2.9197 - accuracy: 0.0929 - val_loss: 2.7010 - val_accuracy: 0.0700
# Epoch 43/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7587 - accuracy: 0.0902 - val_loss: 2.7014 - val_accuracy: 0.0733
# Epoch 44/70
# 71/71 [==============================] - 13s 176ms/step - loss: 2.7628 - accuracy: 0.0911 - val_loss: 2.7012 - val_accuracy: 0.0767
# Epoch 45/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.8260 - accuracy: 0.0907 - val_loss: 2.7014 - val_accuracy: 0.0767
# Epoch 46/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.9710 - accuracy: 0.0938 - val_loss: 2.7001 - val_accuracy: 0.0733
# Epoch 47/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.6511 - accuracy: 0.0871 - val_loss: 2.7007 - val_accuracy: 0.0700
# Epoch 48/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.9804 - accuracy: 0.0924 - val_loss: 2.6764 - val_accuracy: 0.0867
# Epoch 49/70
# 71/71 [==============================] - 13s 176ms/step - loss: 2.8669 - accuracy: 0.0880 - val_loss: 2.7039 - val_accuracy: 0.0767
# Epoch 50/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.8371 - accuracy: 0.0844 - val_loss: 2.6975 - val_accuracy: 0.0700
# Epoch 51/70
# 71/71 [==============================] - 13s 177ms/step - loss: 3.0100 - accuracy: 0.0871 - val_loss: 2.6951 - val_accuracy: 0.0733
# Epoch 52/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.6960 - accuracy: 0.0907 - val_loss: 2.6977 - val_accuracy: 0.0700
# Epoch 53/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.9937 - accuracy: 0.0947 - val_loss: 2.6960 - val_accuracy: 0.0733
# Epoch 54/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.8369 - accuracy: 0.0836 - val_loss: 2.6937 - val_accuracy: 0.0700
# Epoch 55/70
# 71/71 [==============================] - 13s 177ms/step - loss: 3.4177 - accuracy: 0.0938 - val_loss: 2.6861 - val_accuracy: 0.0767
# Epoch 56/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7585 - accuracy: 0.0867 - val_loss: 2.7204 - val_accuracy: 0.0700
# Epoch 57/70
# 71/71 [==============================] - 13s 176ms/step - loss: 2.7801 - accuracy: 0.0902 - val_loss: 2.7015 - val_accuracy: 0.0700
# Epoch 58/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7390 - accuracy: 0.0942 - val_loss: 2.6981 - val_accuracy: 0.0733
# Epoch 59/70
# 71/71 [==============================] - 13s 177ms/step - loss: 3.0839 - accuracy: 0.0876 - val_loss: 2.6975 - val_accuracy: 0.0733
# Epoch 60/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7948 - accuracy: 0.0862 - val_loss: 2.6976 - val_accuracy: 0.0733
# Epoch 61/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.8860 - accuracy: 0.0844 - val_loss: 2.6991 - val_accuracy: 0.0733
# Epoch 62/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.7245 - accuracy: 0.0947 - val_loss: 2.7065 - val_accuracy: 0.0700
# Epoch 63/70
# 71/71 [==============================] - 13s 177ms/step - loss: 3.5107 - accuracy: 0.0813 - val_loss: 2.7038 - val_accuracy: 0.0700
# Epoch 64/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.8903 - accuracy: 0.0818 - val_loss: 2.7036 - val_accuracy: 0.0700
# Epoch 65/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7964 - accuracy: 0.0818 - val_loss: 2.7035 - val_accuracy: 0.0700
# Epoch 66/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7723 - accuracy: 0.0791 - val_loss: 2.6992 - val_accuracy: 0.0767
# Epoch 67/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.7356 - accuracy: 0.0862 - val_loss: 2.6990 - val_accuracy: 0.0733
# Epoch 68/70
# 71/71 [==============================] - 13s 177ms/step - loss: 2.6688 - accuracy: 0.0871 - val_loss: 2.6960 - val_accuracy: 0.0733
# Epoch 69/70
# 71/71 [==============================] - 13s 178ms/step - loss: 2.7101 - accuracy: 0.0911 - val_loss: 2.7044 - val_accuracy: 0.0700
# Epoch 70/70
# 71/71 [==============================] - 13s 176ms/step - loss: 2.7302 - accuracy: 0.0884 - val_loss: 2.7081 - val_accuracy: 0.0700

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.00      0.00      0.00        20
#             Garuda       0.00      0.00      0.00        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.00      0.00      0.00        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.00      0.00      0.00        20
#     Lord_Hayagriva       0.00      0.00      0.00        20
#         Lord_Indra       0.00      0.00      0.00        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.07      1.00      0.13        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       1.00      0.05      0.10        20
#    Shirdi_Sai_Baba       0.00      0.00      0.00        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.07       300
#          macro avg       0.07      0.07      0.01       300
#       weighted avg       0.07      0.07      0.01       300
#
#
# Accuracy = 7.000000000000001%
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-4) and 70 iterations, the highest accuracy obtained is 12%(approx) at (1, 10).**
