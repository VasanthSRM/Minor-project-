# %% [markdown]
# ## **SIFT + ANN (Max_keypoints and padding approach)**
# #### **lr=1*10^(-3), epochs=50, Accuracy = 6.67% (approx) at (1, 50) epochs range**
# #### **Test run - 1**

# %% [markdown]
# #### **Aim: To find suitable learning rate and epoch value.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Req. opencv 4.5+
# !pip uninstall opencv-python
# !pip install opencv-python

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def SIFT_test(dirs, labels, img_size):
    """Scale Invariant Feature Transform Test run for finding the maximum keypoints detected among all the images in the dataset"""
    
    max_key = 0
    
    for data_dir in dirs:
        for label in labels:
            path = os.path.join(data_dir, label)
            for img in os.listdir(path):
                #Reading the image in grayscale mode
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                   
                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) 

                #detecting keypoints
                sift = cv2.SIFT_create()
                keypoints = sift.detect(resized_arr, None)

                if (len(keypoints) > max_key):
                    max_key = len(keypoints)
                
    return max_key

# %%
def SIFT(image, max_key):
    """Scale Invariant Feature Transform for finding keypoints and computing descriptors"""
    
    sift = cv2.SIFT_create()
    keypoints, descriptors = sift.detectAndCompute(image, None)

    return np.pad(np.array(descriptors, dtype="i"), ((0, max_key-len(keypoints)), (0, 0)))[:max_key]

# %%
def dataset_creation(data_dir, labels, img_size, max_key):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image in grayscale mode
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                
                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) 

                #SIFT function call
                SIFT_img_desc = SIFT(resized_arr, max_key)
                
                data.append([SIFT_img_desc, class_num])
            except Exception as err:
                print("Error:\n",err)
    
    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))    
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test))

# %%
def build_model_ann(tot_classes, x_train):
    """Builds ANN model and prints model summary"""
    model = Sequential()
    
    model.add(Flatten(input_shape=x_train.shape[1:]))
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(1000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1527772607016024318
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11320098816
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10477173966960769471
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
dirs = ["Dataset_test_1/Train", "Dataset_test_1/Test"]
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 50
l_rate = 0.001

# %%
#Max keypoints detection
max_key = SIFT_test(dirs, labels, img_size)

#Train and Test data loading
train = dataset_creation("Dataset_test_1/Train", labels, img_size, max_key)
test = dataset_creation("Dataset_test_1/Test", labels, img_size, max_key)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

# %%
#Building ANN Model
model = build_model_ann(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 147712)            0
#
#  dense (Dense)               (None, 3000)              443139000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 1000)              3001000
#
#  dropout_1 (Dropout)         (None, 1000)              0
#
#  dense_2 (Dense)             (None, 15)                15015
#
# =================================================================
# Total params: 446,155,015
# Trainable params: 446,155,015
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/50
# 71/71 [==============================] - 14s 187ms/step - loss: 1394.7117 - accuracy: 0.0787 - val_loss: 7.3845 - val_accuracy: 0.0667
# Epoch 2/50
# 71/71 [==============================] - 13s 180ms/step - loss: 20.1826 - accuracy: 0.0622 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 3/50
# 71/71 [==============================] - 13s 180ms/step - loss: 6.3795 - accuracy: 0.0680 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 4/50
# 71/71 [==============================] - 13s 182ms/step - loss: 6.2756 - accuracy: 0.0604 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 5/50
# 71/71 [==============================] - 13s 182ms/step - loss: 4.4267 - accuracy: 0.0564 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 6/50
# 71/71 [==============================] - 13s 182ms/step - loss: 4.0631 - accuracy: 0.0604 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 7/50
# 71/71 [==============================] - 13s 182ms/step - loss: 5.8833 - accuracy: 0.0662 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 8/50
# 71/71 [==============================] - 13s 183ms/step - loss: 4.5415 - accuracy: 0.0644 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 9/50
# 71/71 [==============================] - 13s 184ms/step - loss: 3.7927 - accuracy: 0.0618 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 10/50
# 71/71 [==============================] - 13s 184ms/step - loss: 3.7482 - accuracy: 0.0636 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 11/50
# 71/71 [==============================] - 13s 184ms/step - loss: 3.1884 - accuracy: 0.0502 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 12/50
# 71/71 [==============================] - 13s 183ms/step - loss: 3.3149 - accuracy: 0.0667 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 13/50
# 71/71 [==============================] - 13s 183ms/step - loss: 3.2257 - accuracy: 0.0564 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 14/50
# 71/71 [==============================] - 13s 184ms/step - loss: 3.7168 - accuracy: 0.0573 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 15/50
# 71/71 [==============================] - 13s 183ms/step - loss: 3.3979 - accuracy: 0.0618 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 16/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.8782 - accuracy: 0.0618 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 17/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.9508 - accuracy: 0.0636 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 18/50
# 71/71 [==============================] - 13s 183ms/step - loss: 3.5288 - accuracy: 0.0609 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 19/50
# 71/71 [==============================] - 13s 182ms/step - loss: 5.1198 - accuracy: 0.0618 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 20/50
# 71/71 [==============================] - 13s 181ms/step - loss: 2.8448 - accuracy: 0.0596 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 21/50
# 71/71 [==============================] - 13s 182ms/step - loss: 3.3249 - accuracy: 0.0542 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 22/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.9024 - accuracy: 0.0596 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 23/50
# 71/71 [==============================] - 13s 183ms/step - loss: 3.1151 - accuracy: 0.0667 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 24/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.8491 - accuracy: 0.0618 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 25/50
# 71/71 [==============================] - 13s 182ms/step - loss: 3.0633 - accuracy: 0.0622 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 26/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.9421 - accuracy: 0.0627 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 27/50
# 71/71 [==============================] - 13s 182ms/step - loss: 3.2770 - accuracy: 0.0676 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 28/50
# 71/71 [==============================] - 13s 182ms/step - loss: 3.0290 - accuracy: 0.0564 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 29/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.7913 - accuracy: 0.0631 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 30/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.9402 - accuracy: 0.0667 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 31/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.9434 - accuracy: 0.0591 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 32/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.7625 - accuracy: 0.0547 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 33/50
# 71/71 [==============================] - 13s 182ms/step - loss: 3.0240 - accuracy: 0.0613 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 34/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.7378 - accuracy: 0.0671 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 35/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.7907 - accuracy: 0.0591 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 36/50
# 71/71 [==============================] - 13s 186ms/step - loss: 2.7507 - accuracy: 0.0618 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 37/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.7130 - accuracy: 0.0662 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 38/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.7334 - accuracy: 0.0622 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 39/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.7309 - accuracy: 0.0507 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 40/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.8005 - accuracy: 0.0591 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 41/50
# 71/71 [==============================] - 13s 182ms/step - loss: 3.1908 - accuracy: 0.0667 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 42/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.9841 - accuracy: 0.0556 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 43/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.9921 - accuracy: 0.0644 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 44/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.8109 - accuracy: 0.0529 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 45/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.8257 - accuracy: 0.0596 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 46/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.7793 - accuracy: 0.0596 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 47/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.9304 - accuracy: 0.0489 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 48/50
# 71/71 [==============================] - 13s 182ms/step - loss: 2.9123 - accuracy: 0.0604 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 49/50
# 71/71 [==============================] - 13s 185ms/step - loss: 3.0354 - accuracy: 0.0569 - val_loss: 2.7081 - val_accuracy: 0.0667
# Epoch 50/50
# 71/71 [==============================] - 13s 183ms/step - loss: 2.9687 - accuracy: 0.0547 - val_loss: 2.7081 - val_accuracy: 0.0667

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.00      0.00      0.00        20
#             Garuda       0.00      0.00      0.00        20
#      Goddess_Durga       0.00      0.00      0.00        20
#    Goddess_Lakshmi       0.00      0.00      0.00        20
# Goddess_Saraswathi       0.00      0.00      0.00        20
#        Lord_Ganesh       0.00      0.00      0.00        20
#       Lord_Hanuman       0.07      1.00      0.12        20
#     Lord_Hayagriva       0.00      0.00      0.00        20
#         Lord_Indra       0.00      0.00      0.00        20
#       Lord_Krishna       0.00      0.00      0.00        20
#        Lord_Muruga       0.00      0.00      0.00        20
#              Nandi       0.00      0.00      0.00        20
#            Nataraj       0.00      0.00      0.00        20
#    Shirdi_Sai_Baba       0.00      0.00      0.00        20
#           Shivling       0.00      0.00      0.00        20
#
#           accuracy                           0.07       300
#          macro avg       0.00      0.07      0.01       300
#       weighted avg       0.00      0.07      0.01       300
#
#
# Accuracy = 6.666666666666667%
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### **Result: For learning rate = 1*10^(-3) and 50 iterations, the highest accuracy obtained is 6.67%(approx) at (1, 50).**
