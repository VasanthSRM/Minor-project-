# %% [markdown]
# # **CLAHE + CNN Draft 2**
# #### **lr=1*10^(-4), epochs=70, Accuracy = 68.33% using CLAHE**
# #### **Test run - 2**

# %% [markdown]
# #### **Aim: To find the accuracy of the CLAHE + CNN model.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def CLAHE(image):
    """Contrast limited AHE"""
    #Convert BGR image to LAB
    lab_img= cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

    #Splitting the LAB image to L, A and B channels, respectively
    l, a, b = cv2.split(lab_img)

    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    clahe_img = clahe.apply(l)

    #Combine the CLAHE enhanced L-channel back with A and B channels
    updated_lab_img2 = cv2.merge((clahe_img,a,b))

    #Convert LAB image back to color (BGR)
    CLAHE_img = cv2.cvtColor(updated_lab_img2, cv2.COLOR_LAB2BGR)

    return CLAHE_img

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                
                #CLAHE function call
                CLAHE_img = CLAHE(resized_arr)

                data.append([CLAHE_img, class_num])
                
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6092545265700420876
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11320098816
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3205295651925863203
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 70
l_rate = 0.0001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 3000)              1731000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 1,915,439
# Trainable params: 1,915,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/70
# 71/71 [==============================] - 9s 91ms/step - loss: 2.7109 - accuracy: 0.0569 - val_loss: 2.7026 - val_accuracy: 0.1467
# Epoch 2/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.6889 - accuracy: 0.0978 - val_loss: 2.6060 - val_accuracy: 0.1967
# Epoch 3/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.5737 - accuracy: 0.1596 - val_loss: 2.2826 - val_accuracy: 0.2733
# Epoch 4/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.3919 - accuracy: 0.2476 - val_loss: 2.0858 - val_accuracy: 0.3500
# Epoch 5/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.2609 - accuracy: 0.2747 - val_loss: 1.9088 - val_accuracy: 0.3833
# Epoch 6/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.1611 - accuracy: 0.3182 - val_loss: 1.7429 - val_accuracy: 0.4533
# Epoch 7/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.0659 - accuracy: 0.3507 - val_loss: 1.7124 - val_accuracy: 0.4800
# Epoch 8/70
# 71/71 [==============================] - 6s 78ms/step - loss: 1.9903 - accuracy: 0.3773 - val_loss: 1.6213 - val_accuracy: 0.5000
# Epoch 9/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.8799 - accuracy: 0.4196 - val_loss: 1.4840 - val_accuracy: 0.5333
# Epoch 10/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.8249 - accuracy: 0.4236 - val_loss: 1.4510 - val_accuracy: 0.5300
# Epoch 11/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.7199 - accuracy: 0.4676 - val_loss: 1.4095 - val_accuracy: 0.5333
# Epoch 12/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.6245 - accuracy: 0.4973 - val_loss: 1.3833 - val_accuracy: 0.5600
# Epoch 13/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.5366 - accuracy: 0.5200 - val_loss: 1.3804 - val_accuracy: 0.5633
# Epoch 14/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.4299 - accuracy: 0.5684 - val_loss: 1.3042 - val_accuracy: 0.5833
# Epoch 15/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.3548 - accuracy: 0.5884 - val_loss: 1.2366 - val_accuracy: 0.5933
# Epoch 16/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.2462 - accuracy: 0.6102 - val_loss: 1.2380 - val_accuracy: 0.5933
# Epoch 17/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.1361 - accuracy: 0.6480 - val_loss: 1.2740 - val_accuracy: 0.6100
# Epoch 18/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.0422 - accuracy: 0.6751 - val_loss: 1.2428 - val_accuracy: 0.6067
# Epoch 19/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.9107 - accuracy: 0.7271 - val_loss: 1.1867 - val_accuracy: 0.6300
# Epoch 20/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.7965 - accuracy: 0.7516 - val_loss: 1.2233 - val_accuracy: 0.6333
# Epoch 21/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.7385 - accuracy: 0.7796 - val_loss: 1.2223 - val_accuracy: 0.6367
# Epoch 22/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.6558 - accuracy: 0.8022 - val_loss: 1.2226 - val_accuracy: 0.6767
# Epoch 23/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.5839 - accuracy: 0.8107 - val_loss: 1.2109 - val_accuracy: 0.6800
# Epoch 24/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.4489 - accuracy: 0.8573 - val_loss: 1.2790 - val_accuracy: 0.6633
# Epoch 25/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.4244 - accuracy: 0.8622 - val_loss: 1.3000 - val_accuracy: 0.6400
# Epoch 26/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.3820 - accuracy: 0.8782 - val_loss: 1.3294 - val_accuracy: 0.6867
# Epoch 27/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.2996 - accuracy: 0.9062 - val_loss: 1.3767 - val_accuracy: 0.6300
# Epoch 28/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2574 - accuracy: 0.9182 - val_loss: 1.4820 - val_accuracy: 0.6567
# Epoch 29/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2269 - accuracy: 0.9236 - val_loss: 1.5074 - val_accuracy: 0.6633
# Epoch 30/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1894 - accuracy: 0.9387 - val_loss: 1.5643 - val_accuracy: 0.6267
# Epoch 31/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1833 - accuracy: 0.9404 - val_loss: 1.5479 - val_accuracy: 0.6700
# Epoch 32/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1514 - accuracy: 0.9524 - val_loss: 1.4595 - val_accuracy: 0.6933
# Epoch 33/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1361 - accuracy: 0.9600 - val_loss: 1.5458 - val_accuracy: 0.7000
# Epoch 34/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1325 - accuracy: 0.9596 - val_loss: 1.4565 - val_accuracy: 0.7100
# Epoch 35/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1202 - accuracy: 0.9636 - val_loss: 1.6213 - val_accuracy: 0.6767
# Epoch 36/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0882 - accuracy: 0.9738 - val_loss: 1.6518 - val_accuracy: 0.6833
# Epoch 37/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0779 - accuracy: 0.9809 - val_loss: 1.6212 - val_accuracy: 0.6933
# Epoch 38/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1056 - accuracy: 0.9684 - val_loss: 1.6301 - val_accuracy: 0.6733
# Epoch 39/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0745 - accuracy: 0.9787 - val_loss: 1.7665 - val_accuracy: 0.6833
# Epoch 40/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0660 - accuracy: 0.9796 - val_loss: 1.7092 - val_accuracy: 0.6967
# Epoch 41/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0861 - accuracy: 0.9756 - val_loss: 1.7412 - val_accuracy: 0.7033
# Epoch 42/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0877 - accuracy: 0.9747 - val_loss: 1.7120 - val_accuracy: 0.6767
# Epoch 43/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0560 - accuracy: 0.9831 - val_loss: 1.7813 - val_accuracy: 0.6933
# Epoch 44/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0449 - accuracy: 0.9880 - val_loss: 1.8671 - val_accuracy: 0.6800
# Epoch 45/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0601 - accuracy: 0.9822 - val_loss: 1.8074 - val_accuracy: 0.6700
# Epoch 46/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0466 - accuracy: 0.9862 - val_loss: 1.8568 - val_accuracy: 0.6933
# Epoch 47/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0384 - accuracy: 0.9893 - val_loss: 1.9499 - val_accuracy: 0.6867
# Epoch 48/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0475 - accuracy: 0.9880 - val_loss: 1.9888 - val_accuracy: 0.6867
# Epoch 49/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0569 - accuracy: 0.9844 - val_loss: 1.9005 - val_accuracy: 0.6733
# Epoch 50/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0654 - accuracy: 0.9791 - val_loss: 1.9121 - val_accuracy: 0.6867
# Epoch 51/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0549 - accuracy: 0.9813 - val_loss: 2.0212 - val_accuracy: 0.6800
# Epoch 52/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0546 - accuracy: 0.9831 - val_loss: 2.1700 - val_accuracy: 0.6467
# Epoch 53/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0796 - accuracy: 0.9782 - val_loss: 1.9413 - val_accuracy: 0.6900
# Epoch 54/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0644 - accuracy: 0.9813 - val_loss: 1.7446 - val_accuracy: 0.6867
# Epoch 55/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0480 - accuracy: 0.9849 - val_loss: 1.8915 - val_accuracy: 0.6967
# Epoch 56/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0560 - accuracy: 0.9849 - val_loss: 2.0044 - val_accuracy: 0.6833
# Epoch 57/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0536 - accuracy: 0.9844 - val_loss: 1.7494 - val_accuracy: 0.7067
# Epoch 58/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0537 - accuracy: 0.9867 - val_loss: 1.9624 - val_accuracy: 0.6633
# Epoch 59/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0383 - accuracy: 0.9889 - val_loss: 1.9415 - val_accuracy: 0.6767
# Epoch 60/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0249 - accuracy: 0.9933 - val_loss: 1.8679 - val_accuracy: 0.7100
# Epoch 61/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0414 - accuracy: 0.9871 - val_loss: 1.7938 - val_accuracy: 0.7000
# Epoch 62/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0562 - accuracy: 0.9813 - val_loss: 2.1078 - val_accuracy: 0.6733
# Epoch 63/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0233 - accuracy: 0.9933 - val_loss: 1.9075 - val_accuracy: 0.7067
# Epoch 64/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0192 - accuracy: 0.9964 - val_loss: 1.8295 - val_accuracy: 0.6900
# Epoch 65/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0255 - accuracy: 0.9933 - val_loss: 1.9477 - val_accuracy: 0.7000
# Epoch 66/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0189 - accuracy: 0.9973 - val_loss: 1.8972 - val_accuracy: 0.7167
# Epoch 67/70
# 71/71 [==============================] - 6s 82ms/step - loss: 0.0198 - accuracy: 0.9947 - val_loss: 1.9224 - val_accuracy: 0.7167
# Epoch 68/70
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0346 - accuracy: 0.9907 - val_loss: 2.0941 - val_accuracy: 0.6833
# Epoch 69/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0593 - accuracy: 0.9813 - val_loss: 1.9921 - val_accuracy: 0.6833
# Epoch 70/70
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0623 - accuracy: 0.9827 - val_loss: 1.8869 - val_accuracy: 0.6833

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.77      0.85      0.81        20
#             Garuda       0.56      0.70      0.62        20
#      Goddess_Durga       1.00      0.90      0.95        20
#    Goddess_Lakshmi       0.45      0.50      0.48        20
# Goddess_Saraswathi       0.41      0.45      0.43        20
#        Lord_Ganesh       0.58      0.55      0.56        20
#       Lord_Hanuman       0.50      0.35      0.41        20
#     Lord_Hayagriva       0.76      0.65      0.70        20
#         Lord_Indra       0.77      1.00      0.87        20
#       Lord_Krishna       0.63      0.95      0.76        20
#        Lord_Muruga       0.90      0.45      0.60        20
#              Nandi       0.88      0.70      0.78        20
#            Nataraj       0.95      0.95      0.95        20
#    Shirdi_Sai_Baba       0.73      0.55      0.63        20
#           Shivling       0.58      0.70      0.64        20
#
#           accuracy                           0.68       300
#          macro avg       0.70      0.68      0.68       300
#       weighted avg       0.70      0.68      0.68       300
#
#
# Accuracy = 68.33333333333333%

# %% [markdown]
# #### **Result: The accuracy of the CLAHE + CNN model having learning rate = 1*10^(-4) and epochs = 70 is 68.33%.**
