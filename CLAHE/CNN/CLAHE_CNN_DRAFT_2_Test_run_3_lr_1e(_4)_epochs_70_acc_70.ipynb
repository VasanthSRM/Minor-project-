# %% [markdown]
# # **CLAHE + CNN Draft 2**
# #### **lr=1*10^(-4), epochs=70, Accuracy = 70% using CLAHE**
# #### **Test run - 3**

# %% [markdown]
# #### **Aim: To find the accuracy of the CLAHE + CNN model.**

# %% [markdown]
# #### **For mounting drive**

# %%
#For mounting GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Required modules**

# %%
#Importing necessary libraries
from zipfile import ZipFile
from tensorflow.python.client import device_lib
import platform
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
import cv2
import os
import sys
import numpy as np
import random

# %% [markdown]
# #### **Functions definition**

# %%
def extract_zip(file_name = "drive/MyDrive/Dataset_test_1.zip"):
    with ZipFile(file_name, "r") as zip:
        zip.extractall()
        print("Dataset Extracted")

# %%
def python_ver():
    print("\nPython version:\n")
    print(sys.version)

def device_info():
    print("\nDevice Info:\n")
    print(device_lib.list_local_devices())

def platform_info():
    print("\nPlatform Info:\n")
    print(platform.platform())
    print(platform.processor())

# %%
def CLAHE(image):
    """Contrast limited AHE"""
    #Convert BGR image to LAB
    lab_img= cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

    #Splitting the LAB image to L, A and B channels, respectively
    l, a, b = cv2.split(lab_img)

    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    clahe_img = clahe.apply(l)

    #Combine the CLAHE enhanced L-channel back with A and B channels
    updated_lab_img2 = cv2.merge((clahe_img,a,b))

    #Convert LAB image back to color (BGR)
    CLAHE_img = cv2.cvtColor(updated_lab_img2, cv2.COLOR_LAB2BGR)

    return CLAHE_img

# %%
def dataset_creation(data_dir, labels, img_size):
    """Loading data and shuffling"""
    data = [] 

    for class_num, label in enumerate(labels): 
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                #Reading the image
                img_arr = cv2.imread(os.path.join(path, img))

                #Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                
                #CLAHE function call
                CLAHE_img = CLAHE(resized_arr)

                data.append([CLAHE_img, class_num])
                
            except Exception as err:
                print("Error:\n",err)

    random.shuffle(data)
    return np.array(data)

# %%
def dataset_creation_train_stat(labels, train):
    """Plot initial data graph"""
    list_graph = []
    for i in train:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Train set")
    plt.show()


def dataset_creation_test_stat(labels, test):
    """Plot initial data graph"""
    list_graph = []
    for i in test:
        list_graph.append(labels[i[1]])
    
    sns.set_style('darkgrid')
    plt.figure(figsize=(25, 25))
    sns.countplot(list_graph)
    plt.title("Test set")
    plt.show()

# %%
def show_sample_train(labels, train, num_sample_img):
    """Plots sample images"""
    for _ in range(num_sample_img):
        i = random.randint(0, len(train)-1)
        plt.figure(figsize = (5,5))
        plt.imshow(cv2.cvtColor(train[i][0], cv2.COLOR_BGR2RGB))
        plt.title(labels[train[i][1]])

# %%
def train_test_data_split(train, test):
    """train and test"""
    x_train = []
    y_train = []
    x_test = []
    y_test = []

    for feature, label in train:
        x_train.append(feature)
        y_train.append(label)

    for feature, label in test:
        x_test.append(feature)
        y_test.append(label)

    return (x_train, y_train, x_test, y_test)

# %%
def normalize_array_conv_data(x_train, y_train, x_test, y_test):
    """Normalize and array conversion"""
    x_train = np.array(x_train) / 255
    x_test = np.array(x_test) / 255

    y_train = np.array(y_train)
    y_test = np.array(y_test)

    return (x_train, y_train, x_test, y_test)

# %%
def build_model_cnn(tot_classes, x_train):
    """Builds cnn model and prints model summary"""
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(3000,activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(tot_classes, activation="softmax"))

    model.summary()
    return model

# %%
def compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate):
    """Compiles and fits the model"""
    opt = Adam(learning_rate=l_rate)
    model.compile(optimizer = opt, loss = "sparse_categorical_crossentropy", metrics = ['accuracy'])
    history = model.fit(x_train, y_train, epochs = iterations, validation_data = (x_test, y_test))

    return (history, model)

# %%
def acc_plots(history, iterations):
    """Requires history and number of iterations"""
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(iterations)

    plt.figure(figsize=(15, 15))
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def acc_results(model, labels, x_test, y_test):
    """Prediction and test accuracy"""
    predictions = np.argmax(model.predict(x_test), axis=-1)
    print(classification_report(y_test, predictions, target_names = labels))
    print("\nAccuracy = "+str(accuracy_score(y_test, predictions)*100)+"%")

# %% [markdown]
# #### **Making Function calls and defining variables**

# %%
#Extracting Dataset
extract_zip("drive/MyDrive/Dataset_test_1.zip")

#Device and environment Info
python_ver()
device_info()
platform_info()
# Out:
# Dataset Extracted
#
# Python version:
#
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
#
# Device Info:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10702877022169772457
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11321147392
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3239605914970968140
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]
#
# Platform Info:
#
# Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# x86_64

# %%
#Variables
labels = ['Buddha', 'Garuda', 'Goddess_Durga', 'Goddess_Lakshmi', 'Goddess_Saraswathi', 'Lord_Ganesh', 
        'Lord_Hanuman', 'Lord_Hayagriva', 'Lord_Indra', 'Lord_Krishna', 'Lord_Muruga', 'Nandi', 'Nataraj', 
        'Shirdi_Sai_Baba', 'Shivling']
img_size = 224
tot_classes = len(labels)
num_sample_img = 3
iterations = 70
l_rate = 0.0001

# %%
#Data location
train = dataset_creation("Dataset_test_1/Train", labels, img_size)
test = dataset_creation("Dataset_test_1/Test", labels, img_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Stats
dataset_creation_train_stat(labels, train)
dataset_creation_test_stat(labels, test)
show_sample_train(labels, train, num_sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Training and testing data
x_train, y_train, x_test, y_test = train_test_data_split(train, test)

#Normalize and array conversion
x_train, y_train, x_test, y_test = normalize_array_conv_data(x_train, y_train, x_test, y_test)

# %%
#Building CNN Model
model = build_model_cnn(tot_classes, x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 3000)              1731000
#
#  dropout (Dropout)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 15)                45015
#
# =================================================================
# Total params: 1,915,439
# Trainable params: 1,915,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile and fit the model
history, model = compile_and_fit(model, x_train, y_train, x_test, y_test, iterations, l_rate)
# Out:
# Epoch 1/70
# 71/71 [==============================] - 9s 90ms/step - loss: 2.7112 - accuracy: 0.0653 - val_loss: 2.7047 - val_accuracy: 0.0700
# Epoch 2/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.7002 - accuracy: 0.0991 - val_loss: 2.6652 - val_accuracy: 0.1933
# Epoch 3/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.6006 - accuracy: 0.1467 - val_loss: 2.3052 - val_accuracy: 0.2533
# Epoch 4/70
# 71/71 [==============================] - 6s 78ms/step - loss: 2.4159 - accuracy: 0.2178 - val_loss: 2.1019 - val_accuracy: 0.3467
# Epoch 5/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.2705 - accuracy: 0.2667 - val_loss: 1.9370 - val_accuracy: 0.3733
# Epoch 6/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.1798 - accuracy: 0.3133 - val_loss: 1.8161 - val_accuracy: 0.4267
# Epoch 7/70
# 71/71 [==============================] - 6s 79ms/step - loss: 2.0954 - accuracy: 0.3449 - val_loss: 1.6784 - val_accuracy: 0.4933
# Epoch 8/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.9983 - accuracy: 0.3800 - val_loss: 1.6107 - val_accuracy: 0.5033
# Epoch 9/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.9159 - accuracy: 0.4276 - val_loss: 1.5219 - val_accuracy: 0.5433
# Epoch 10/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.8334 - accuracy: 0.4418 - val_loss: 1.4705 - val_accuracy: 0.5733
# Epoch 11/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.7288 - accuracy: 0.4764 - val_loss: 1.4154 - val_accuracy: 0.6000
# Epoch 12/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.6287 - accuracy: 0.5071 - val_loss: 1.3509 - val_accuracy: 0.6100
# Epoch 13/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.5243 - accuracy: 0.5333 - val_loss: 1.2836 - val_accuracy: 0.6300
# Epoch 14/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.4305 - accuracy: 0.5609 - val_loss: 1.3073 - val_accuracy: 0.6233
# Epoch 15/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.3360 - accuracy: 0.5880 - val_loss: 1.2505 - val_accuracy: 0.6567
# Epoch 16/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.2408 - accuracy: 0.6218 - val_loss: 1.2325 - val_accuracy: 0.6433
# Epoch 17/70
# 71/71 [==============================] - 6s 79ms/step - loss: 1.1263 - accuracy: 0.6507 - val_loss: 1.1911 - val_accuracy: 0.6533
# Epoch 18/70
# 71/71 [==============================] - 6s 80ms/step - loss: 1.0417 - accuracy: 0.6813 - val_loss: 1.2278 - val_accuracy: 0.6233
# Epoch 19/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.9246 - accuracy: 0.7124 - val_loss: 1.2113 - val_accuracy: 0.6733
# Epoch 20/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.8587 - accuracy: 0.7391 - val_loss: 1.2216 - val_accuracy: 0.6300
# Epoch 21/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.7483 - accuracy: 0.7751 - val_loss: 1.1523 - val_accuracy: 0.6800
# Epoch 22/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.6450 - accuracy: 0.7973 - val_loss: 1.2076 - val_accuracy: 0.7000
# Epoch 23/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.5881 - accuracy: 0.8129 - val_loss: 1.1968 - val_accuracy: 0.6467
# Epoch 24/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.5106 - accuracy: 0.8462 - val_loss: 1.1962 - val_accuracy: 0.6767
# Epoch 25/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.4513 - accuracy: 0.8684 - val_loss: 1.3057 - val_accuracy: 0.6533
# Epoch 26/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.3711 - accuracy: 0.8871 - val_loss: 1.2976 - val_accuracy: 0.6967
# Epoch 27/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2946 - accuracy: 0.9142 - val_loss: 1.4105 - val_accuracy: 0.6800
# Epoch 28/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.3075 - accuracy: 0.9018 - val_loss: 1.3381 - val_accuracy: 0.6700
# Epoch 29/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.2366 - accuracy: 0.9342 - val_loss: 1.3607 - val_accuracy: 0.6733
# Epoch 30/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1751 - accuracy: 0.9493 - val_loss: 1.3824 - val_accuracy: 0.6900
# Epoch 31/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1607 - accuracy: 0.9507 - val_loss: 1.4747 - val_accuracy: 0.6967
# Epoch 32/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1452 - accuracy: 0.9596 - val_loss: 1.4149 - val_accuracy: 0.7000
# Epoch 33/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1245 - accuracy: 0.9609 - val_loss: 1.4295 - val_accuracy: 0.6933
# Epoch 34/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1217 - accuracy: 0.9613 - val_loss: 1.5961 - val_accuracy: 0.6833
# Epoch 35/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.1180 - accuracy: 0.9662 - val_loss: 1.7196 - val_accuracy: 0.6500
# Epoch 36/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1113 - accuracy: 0.9671 - val_loss: 1.5473 - val_accuracy: 0.6900
# Epoch 37/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0935 - accuracy: 0.9733 - val_loss: 1.5057 - val_accuracy: 0.6933
# Epoch 38/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0866 - accuracy: 0.9778 - val_loss: 1.6869 - val_accuracy: 0.6900
# Epoch 39/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.1045 - accuracy: 0.9671 - val_loss: 1.6005 - val_accuracy: 0.6733
# Epoch 40/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0782 - accuracy: 0.9778 - val_loss: 1.7412 - val_accuracy: 0.6800
# Epoch 41/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0669 - accuracy: 0.9831 - val_loss: 1.7200 - val_accuracy: 0.6600
# Epoch 42/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0690 - accuracy: 0.9787 - val_loss: 1.7265 - val_accuracy: 0.6700
# Epoch 43/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0620 - accuracy: 0.9822 - val_loss: 1.8512 - val_accuracy: 0.6833
# Epoch 44/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0668 - accuracy: 0.9827 - val_loss: 1.8463 - val_accuracy: 0.6800
# Epoch 45/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0399 - accuracy: 0.9893 - val_loss: 1.8358 - val_accuracy: 0.6933
# Epoch 46/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0434 - accuracy: 0.9884 - val_loss: 1.7156 - val_accuracy: 0.6800
# Epoch 47/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0765 - accuracy: 0.9760 - val_loss: 1.7585 - val_accuracy: 0.6933
# Epoch 48/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0475 - accuracy: 0.9862 - val_loss: 1.9512 - val_accuracy: 0.6700
# Epoch 49/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0489 - accuracy: 0.9862 - val_loss: 1.8499 - val_accuracy: 0.6833
# Epoch 50/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0700 - accuracy: 0.9836 - val_loss: 1.6598 - val_accuracy: 0.7067
# Epoch 51/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0464 - accuracy: 0.9880 - val_loss: 1.8380 - val_accuracy: 0.6633
# Epoch 52/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0426 - accuracy: 0.9876 - val_loss: 1.9919 - val_accuracy: 0.6733
# Epoch 53/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0291 - accuracy: 0.9942 - val_loss: 2.0267 - val_accuracy: 0.6800
# Epoch 54/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0329 - accuracy: 0.9902 - val_loss: 2.0889 - val_accuracy: 0.6867
# Epoch 55/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0653 - accuracy: 0.9827 - val_loss: 1.9015 - val_accuracy: 0.6467
# Epoch 56/70
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0399 - accuracy: 0.9867 - val_loss: 1.9073 - val_accuracy: 0.6833
# Epoch 57/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0411 - accuracy: 0.9880 - val_loss: 1.9905 - val_accuracy: 0.7100
# Epoch 58/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0290 - accuracy: 0.9911 - val_loss: 1.9693 - val_accuracy: 0.7033
# Epoch 59/70
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0343 - accuracy: 0.9907 - val_loss: 2.0102 - val_accuracy: 0.6733
# Epoch 60/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0611 - accuracy: 0.9787 - val_loss: 1.9697 - val_accuracy: 0.6700
# Epoch 61/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0445 - accuracy: 0.9871 - val_loss: 1.9658 - val_accuracy: 0.6900
# Epoch 62/70
# 71/71 [==============================] - 6s 81ms/step - loss: 0.0466 - accuracy: 0.9907 - val_loss: 2.0186 - val_accuracy: 0.6767
# Epoch 63/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0426 - accuracy: 0.9844 - val_loss: 2.0536 - val_accuracy: 0.6967
# Epoch 64/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0228 - accuracy: 0.9960 - val_loss: 1.8820 - val_accuracy: 0.6933
# Epoch 65/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0365 - accuracy: 0.9884 - val_loss: 1.9354 - val_accuracy: 0.7133
# Epoch 66/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0563 - accuracy: 0.9844 - val_loss: 1.9241 - val_accuracy: 0.6900
# Epoch 67/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0347 - accuracy: 0.9893 - val_loss: 2.1597 - val_accuracy: 0.6967
# Epoch 68/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0452 - accuracy: 0.9898 - val_loss: 2.0016 - val_accuracy: 0.6700
# Epoch 69/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0488 - accuracy: 0.9871 - val_loss: 1.9231 - val_accuracy: 0.6867
# Epoch 70/70
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0341 - accuracy: 0.9911 - val_loss: 2.0953 - val_accuracy: 0.7000

# %%
#Plots
acc_plots(history, iterations)

# %%
#Results
acc_results(model, labels, x_test, y_test)
# Out:
#                     precision    recall  f1-score   support
#
#             Buddha       0.80      0.80      0.80        20
#             Garuda       0.67      0.70      0.68        20
#      Goddess_Durga       0.72      0.90      0.80        20
#    Goddess_Lakshmi       0.37      0.65      0.47        20
# Goddess_Saraswathi       0.73      0.40      0.52        20
#        Lord_Ganesh       0.72      0.65      0.68        20
#       Lord_Hanuman       0.62      0.40      0.48        20
#     Lord_Hayagriva       0.86      0.60      0.71        20
#         Lord_Indra       0.74      1.00      0.85        20
#       Lord_Krishna       1.00      0.75      0.86        20
#        Lord_Muruga       0.73      0.40      0.52        20
#              Nandi       0.89      0.85      0.87        20
#            Nataraj       0.86      0.95      0.90        20
#    Shirdi_Sai_Baba       0.52      0.75      0.61        20
#           Shivling       0.70      0.70      0.70        20
#
#           accuracy                           0.70       300
#          macro avg       0.73      0.70      0.70       300
#       weighted avg       0.73      0.70      0.70       300
#
#
# Accuracy = 70.0%

# %% [markdown]
# #### **Result: The accuracy of the CLAHE + CNN model having learning rate = 1*10^(-4) and epochs = 70 is 70%.**
